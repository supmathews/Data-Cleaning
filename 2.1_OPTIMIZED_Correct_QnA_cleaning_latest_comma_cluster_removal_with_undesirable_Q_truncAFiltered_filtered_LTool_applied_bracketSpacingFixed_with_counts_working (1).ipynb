# %%
pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.2-py3-none-any.whl (3.4 MB)
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ###### Counting the total number of all errors including undesirable Typos, QnAs and truncated QnAs

# %%
import pandas as pd
import os
import csv
import re
import language_tool_python
import time
import cProfile

def count_multiple_commas(text):
    pattern = re.compile(r',{2,}')
    return len(re.findall(pattern, text))

def replace_multiple_commas(text):
    pattern = re.compile(r',{2,}')
    corrected_text = re.sub(pattern, ', ', text)
    if corrected_text != text:
        print(f"\nOriginal text: {text}")
        print(f"Corrected text: {corrected_text}")
    return corrected_text

def comma_cluster_removal_df(df):
    total_comma_count = 0

    for column in df.columns:
        df[column] = df[column].apply(replace_multiple_commas)
        total_comma_count += df[column].apply(count_multiple_commas).sum()

    print(f"Total comma count: {total_comma_count}")
    return df, total_comma_count


def is_undesirable_question_to_count(question):
    if isinstance(question, str):
        count_phrases = [
            
            "what is the title",
            "what is the research topic",
            "what data is used in the study",
            "what data sets are collected in this study",
            "how did the study",
            "what does the arrow in figure 6 represent",
            "what was the publication date of the study",
            "what is the title of the paper",
            "what is the purpose of this study",
            "what was the goal of the study",
            "what data was utilized in the study",
            "what is the source of funding for this study",
            "what was the aim of this study",
            "what are the objectives of the study",
            "what was the main focus of the study",
            "what were the main conclusions of the study",
            "what methods were used in the study",
            "what ratio was used for the analysis",
            "what models are shown in fig 4",
            "what is the conclusion of this study",
            "what do the innovations of this study enable",
            "what is the article about",
            "what is the doi number for the article",
            "where can the tool be accessed",
            "what data has been used",
            "what were the results of the study",
            "what are the key findings of this study",
            "what data sources were used in this study",
            "what are the limitations of this study",
            "where was the research conducted",
            "what are the key words for this article",
            "what is the main objective of this study",
            "what evidence supports the research",
            # Add more phrases here
        ]
        return any(phrase in question.lower() for phrase in count_phrases)
    return False

def is_truncated(sentence):
    
    # Ensure the sentence is converted to a string
    sentence = str(sentence)
    # Define a list of sentence-ending punctuation marks
    sentence_endings = ['.', '!', '?', '."', '!"', '?"', '.”', '!”', '?”']
    
    # Check if the last character of the sentence is a sentence-ending punctuation mark
    if sentence[-1] in sentence_endings:
        return False  # Not truncated
    else:
        #print ("\n" + sentence+"\n")
        return True   # Truncated

# Assuming you have defined your functions is_undesirable_question_to_count and is_truncated properly

def count_truncated_questions_and_answers_in_df(df, filtered_data_file):
    #df = pd.read_csv(file_path)
    df.info() 
    columns_with_spaces = df.columns.tolist()
    print(columns_with_spaces) 
    questions = df['Question']
    answers = df['Answer']
        
    questions_count = df['Question'].apply(is_undesirable_question_to_count).sum()

    # Count truncated questions
    truncated_questions_count = df['Question'].apply(is_truncated).sum()

    # Count truncated answers
    truncated_answers_count = df['Answer'].apply(is_truncated).sum()
     
    # Filter out truncated rows
    truncated_questions = []
    truncated_answers = []
    
    # Filter out truncated rows
    not_truncated_indices = []
    for i in range(len(df)):
        if not (is_truncated(questions[i]) or is_truncated(answers[i])):
            not_truncated_indices.append(i)
        else:
            if is_truncated(questions[i]):
                truncated_questions.append(questions[i])
                print(f"Truncated Question {i}: {questions[i]}")
            if is_truncated(answers[i]):
                truncated_answers.append(answers[i])
                print(f"Corresponding Question {i}: {questions[i]}")
                print(f"Truncated Answer  {i}: {answers[i]} \n")
    df = df.iloc[not_truncated_indices]
      
    # Filter out questions and their corresponding answers
    filtered_indices = [i for i, question in enumerate(df['Question']) if is_undesirable_question_to_count(question)]
    filtered_data = pd.DataFrame({
        'Question': df['Question'].iloc[filtered_indices],
        'Answer': df['Answer'].iloc[filtered_indices]
    })
    
    # Print the number of rows in the filtered data
    print("Number of rows in filtered data:", len(filtered_data))
    
    # Create a new DataFrame for remaining data without truncated QnA
    remaining_indices = [i for i in range(len(df)) if i not in filtered_indices]
    remaining_data = df.iloc[remaining_indices]
    
    # Print the number of rows in the remaining data
    print("Number of rows in remaining data:", len(remaining_data))
    
    # Save the filtered data
    filtered_data.to_csv(filtered_data_file, index=False, encoding='utf-8')
    
    # Save the remaining data
    #remaining_data.to_csv(remaining_data_file, index=False, encoding='utf-8')
    
    return questions_count, truncated_questions_count, truncated_answers_count, remaining_data







def save_filtered_data(file_path, filtered_data):
    with open(file_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Question', 'Answer']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(filtered_data)

        


#def count_errors(text):
 #   tool = language_tool_python.LanguageTool('en-GB')
  #  matches = tool.check(text)
   # return len(matches)

def LanguageTool_df(df):
    tool = language_tool_python.LanguageTool('en-GB')
    corrected_content = []

    original_error_count = 0
    corrected_error_count = 0

    for i in range(len(df)):
        corrected_row = [tool.correct(cell) for cell in df.iloc[i]]
        corrected_content.append(corrected_row)

        for j in range(len(corrected_content[i])):
           # original_error_count += count_errors(df.iloc[i, j])
          #  corrected_error_count += count_errors(corrected_content[i][j])
            corrected_content[i][j] = corrected_content[i][j].replace(' Answer', 'Answer')
            #print (corrected_content[i][j])

    LanguageTool_corrected_df = pd.DataFrame(corrected_content, columns=df.columns)

    return LanguageTool_corrected_df #, original_error_count, corrected_error_count


def add_space_before_opening_bracket(df):
    #df = pd.read_csv(input_file_path)
    
    for column in df.columns:
        df[column] = df[column].apply(lambda cell: re.sub(r'([A-Za-z])\(', r'\1 (', cell))
    
    #df.to_csv(ammended_space_file, index=False)
    
    return df   # Return the output file path after processing





def main():
    # List of CSV files to process
    start_time = time.time() 
    
    
    
    csv_files = [
       # "C:/Users/HP/Documents/Sam/Data Science Voluteer/CSV/Geothermal_energy_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_wellcome_20230717.csv",
        "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_gatesopen_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal+energy_f1000_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal_energy_wellcome_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Carbon+footprint_wellcome_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/test_dataset.csv"
        ## Add more file paths here as needed
    ]

    total_questions_count = 0
    total_truncated_questions_count = 0
    total_truncated_answers_count = 0
    

    for csv_file in csv_files: 
        df = pd.read_csv(csv_file)
       # corrected_file_path = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_corrected.csv'))
        #remaining_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_remaining_data.csv'))
        filtered_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_filtered_questions.csv'))
        #ammended_space_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', 'bracket_spaced.csv'))
        questions_count, truncated_questions, truncated_answers, remaining_data = count_truncated_questions_and_answers_in_df(df, filtered_data_file)
        comma_cluster_removed_df, total_comma_count = comma_cluster_removal_df(remaining_data)
        space_before_bracket_ammended_df = add_space_before_opening_bracket(comma_cluster_removed_df)
        LanguageTool_corrected_df = LanguageTool_df(space_before_bracket_ammended_df)
       
        
        # Save the processed DataFrame with "updated" added to the name
        cleaned_df = LanguageTool_corrected_df.copy()
        cleaned_df_filename = os.path.basename(csv_file).replace('.csv', '_cleaned.csv')

        # Assuming that you have a directory where you want to save the updated DataFrames
        cleaned_df_dir = os.path.join(os.path.expanduser("~"), "Downloads", "cleaned_QnAs")

        if not os.path.exists(cleaned_df_dir):
            os.makedirs(cleaned_df_dir)

        cleaned_df_file_path = os.path.join(cleaned_df_dir, cleaned_df_filename)

        # Save the updated DataFrame as a CSV file
        cleaned_df.to_csv(cleaned_df_file_path, index=False)

        # Now, you can use the updated DataFrame for further processing if needed

        
        
        
        total_questions_count += questions_count
        total_truncated_questions_count += truncated_questions
        total_truncated_answers_count += truncated_answers
        
        
        print(f"File: {csv_file}\n")
        print(f"Total undesirable questions: {questions_count}")
        print(f"Total Truncated Questions: {truncated_questions}")
        print(f"Total Truncated Answers: {truncated_answers}")
        print(f"Original typo/error found: {original_error_count}")
        print(f"excessive comma occurence: {total_comma_count}")
        print(f"Corrected typo/error count: {corrected_errors}")

        
        print(f"(undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence + original errer count): {questions_count + truncated_questions + truncated_answers +  total_comma_count + original_error_count}\n")

  #  print(f"Total Questions Count: {total_questions_count}")
  #  print(f"Total Truncated Questions Count: {total_truncated_questions_count}")
  #  print(f"Total Truncated Answers Count: {total_truncated_answers_count}")
  #  print(f"Total (Questions + Truncated Questions + Truncated Answers): {total_questions_count + total_truncated_questions_count + total_truncated_answers_count}")

    end_time = time.time()
    
    elapsed_time_seconds = end_time - start_time
    elapsed_time_minutes = elapsed_time_seconds / 60

    print(f"Script ran for {elapsed_time_minutes:.2f} minutes.")
    
    
    
if __name__ == "__main__":
    cProfile.run("main()", sort='cumulative')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Question  6 non-null      object
#  1   Answer    6 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes
# ['Question', 'Answer']
# Corresponding Question 1: What are the limitations of this study?
# Truncated Answer  1: The limitations of this study avaliable include the exclusion of Love Matters social media platforms and offline components, as well as the dependency on user cookie settings and limitations in recognizing source traffic
#
# Corresponding Question 3: What is the aim of new vaccine development?
# Truncated Answer  3: The aim of new,,,, vaccine development is to enhance maternal immunization, e.g. for group B streptococcus and respiratory syncytial virus, and to reduce serious morbidity and mortality in
#
# Number of rows in filtered data: 2
# Number of rows in remaining data: 2
#
# Original text: Respiratory infections and sepsis are among the leading causes of neonatal deaths in 195 countries    across the world. This is  ,,,, gallic() rerun or odds     avaliable?
# Corrected text: Respiratory infections and sepsis are among the leading causes of neonatal deaths in 195 countries    across the world. This is  ,  gallic() rerun or odds     avaliable?
# Total comma count: 0
# File: C:/Users/Joshua Giwa/Downloads/test_dataset.csv
#
# Total undesirable questions: 3
# Total Truncated Questions: 0
# Total Truncated Answers: 2
# excessive comma occurence: 0
# (undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence): 5
#
# Script ran for 0.30 minutes.
#          46342 function calls (46101 primitive calls) in 17.703 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   17.703   17.703 {built-in method builtins.exec}
#         1    0.000    0.000   17.703   17.703 <string>:1(<module>)
#         1    0.000    0.000   17.703   17.703 2703895914.py:207(main)
#         1    0.000    0.000   17.667   17.667 2703895914.py:171(LanguageTool_df)
#         5    0.000    0.000    9.811    1.962 server.py:213(_query_server)
#         5    0.000    0.000    9.810    1.962 api.py:64(get)
#         5    0.000    0.000    9.810    1.962 api.py:16(request)
#         5    0.000    0.000    9.806    1.961 sessions.py:470(request)
#         5    0.000    0.000    9.788    1.958 sessions.py:626(send)
#         5    0.000    0.000    9.782    1.956 adapters.py:394(send)
#         5    0.000    0.000    9.775    1.955 connectionpool.py:518(urlopen)
#         5    0.000    0.000    9.770    1.954 connectionpool.py:357(_make_request)
#         5    0.000    0.000    9.762    1.952 client.py:1303(getresponse)
#         5    0.000    0.000    9.761    1.952 client.py:300(begin)
#        10    0.000    0.000    9.761    0.976 socket.py:655(readinto)
#        10    9.761    0.976    9.761    0.976 {method 'recv_into' of '_socket.socket' objects}
#         5    0.000    0.000    9.758    1.952 client.py:267(_read_status)
#        25    0.000    0.000    9.758    0.390 {method 'readline' of '_io.BufferedReader' objects}
#         2    0.000    0.000    9.656    4.828 2703895914.py:179(<listcomp>)
#         4    0.000    0.000    9.656    2.414 server.py:151(correct)
#         4    0.000    0.000    9.656    2.414 server.py:126(check)
#         1    0.000    0.000    8.009    8.009 server.py:44(__init__)
#         1    0.000    0.000    7.849    7.849 server.py:234(_start_server_on_free_port)
#         3    0.000    0.000    7.849    2.616 server.py:246(_start_local_server)
#         9    6.891    0.766    6.891    0.766 {method 'readline' of '_io.TextIOWrapper' objects}
#         3    0.000    0.000    0.905    0.302 download_lt.py:135(download_lt)
#         3    0.000    0.000    0.901    0.300 download_lt.py:68(confirm_java_compatibility)
#         3    0.000    0.000    0.898    0.299 subprocess.py:368(check_output)
#         3    0.000    0.000    0.898    0.299 subprocess.py:452(run)
#         5    0.000    0.000    0.869    0.174 subprocess.py:984(communicate)
#         3    0.858    0.286    0.858    0.286 {method 'read' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.159    0.159 server.py:193(_get_languages)
#         6    0.000    0.000    0.066    0.011 subprocess.py:736(__init__)
#         6    0.000    0.000    0.064    0.011 subprocess.py:1228(_execute_child)
#         6    0.062    0.010    0.062    0.010 {built-in method _winapi.CreateProcess}
#         1    0.000    0.000    0.021    0.021 2703895914.py:90(count_truncated_questions_and_answers_in_df)
#       238    0.015    0.000    0.015    0.000 {built-in method nt.stat}
#         3    0.000    0.000    0.014    0.005 utils.py:95(get_server_cmd)
#         3    0.000    0.000    0.014    0.005 utils.py:109(get_jar_info)
#         1    0.000    0.000    0.011    0.011 frame.py:3148(info)
#         1    0.000    0.000    0.011    0.011 info.py:510(render)
#         1    0.000    0.000    0.011    0.011 info.py:595(to_buffer)
#         3    0.000    0.000    0.011    0.004 which.py:13(which)
#       195    0.001    0.000    0.010    0.000 genericpath.py:27(isfile)
#         5    0.000    0.000    0.010    0.002 sessions.py:701(merge_environment_settings)
#         5    0.000    0.000    0.010    0.002 utils.py:770(get_environ_proxies)
#        18    0.000    0.000    0.010    0.001 which.py:36(find_exe)
#       171    0.000    0.000    0.009    0.000 which.py:27(is_exe)
#         1    0.000    0.000    0.009    0.009 info.py:801(get_lines)
#         1    0.000    0.000    0.009    0.009 info.py:966(_fill_non_empty_info)
#        10    0.001    0.000    0.008    0.001 request.py:2494(getproxies_environment)
#         5    0.000    0.000    0.007    0.001 sessions.py:430(prepare_request)
#         5    0.000    0.000    0.007    0.001 connection.py:226(request)
#         8    0.000    0.000    0.007    0.001 subprocess.py:1078(wait)
#         8    0.000    0.000    0.007    0.001 subprocess.py:1353(_wait)
#         4    0.007    0.002    0.007    0.002 {built-in method _winapi.WaitForSingleObject}
#      1200    0.002    0.000    0.007    0.000 _collections_abc.py:742(__iter__)
#         5    0.000    0.000    0.007    0.001 client.py:1252(request)
#         5    0.000    0.000    0.007    0.001 client.py:1257(_send_request)
#         6    0.000    0.000    0.007    0.001 _decorators.py:302(wrapper)
#     50/49    0.001    0.000    0.007    0.000 series.py:323(__init__)
#         2    0.000    0.000    0.006    0.003 info.py:464(dtype_counts)
#         2    0.000    0.000    0.006    0.003 info.py:1112(_get_dataframe_dtype_counts)
#         5    0.000    0.000    0.006    0.001 utils.py:709(should_bypass_proxies)
#         5    0.000    0.000    0.006    0.001 client.py:1239(endheaders)
#         5    0.000    0.000    0.006    0.001 client.py:1001(_send_output)
#         5    0.000    0.000    0.006    0.001 client.py:942(send)
#         1    0.000    0.000    0.005    0.005 info.py:834(add_memory_usage_line)
#         1    0.000    0.000    0.005    0.005 info.py:763(memory_usage_string)
#         1    0.000    0.000    0.005    0.005 info.py:419(memory_usage_string)
#         2    0.000    0.000    0.005    0.003 generic.py:3376(to_csv)
#         5    0.000    0.000    0.005    0.001 utils.py:87(proxy_bypass)
#        33    0.004    0.000    0.005    0.000 url.py:210(_encode_invalid_chars)
#         1    0.000    0.000    0.005    0.005 readers.py:584(read_csv)
#         1    0.000    0.000    0.005    0.005 readers.py:539(_read)
#        15    0.000    0.000    0.005    0.000 models.py:818(content)
#        15    0.000    0.000    0.005    0.000 url.py:330(parse_url)
#         9    0.000    0.000    0.005    0.001 series.py:4323(apply)
#        40    0.000    0.000    0.005    0.000 {method 'join' of 'bytes' objects}
#         2    0.000    0.000    0.005    0.002 format.py:1131(to_csv)
#        10    0.000    0.000    0.005    0.000 models.py:749(generate)
#      1187    0.002    0.000    0.005    0.000 os.py:670(__getitem__)
#         9    0.000    0.000    0.005    0.001 apply.py:1074(apply)
#         5    0.000    0.000    0.005    0.001 connection.py:199(connect)
#        10    0.000    0.000    0.005    0.000 response.py:555(stream)
#         5    0.000    0.000    0.005    0.001 connection.py:156(_new_conn)
#         5    0.000    0.000    0.005    0.001 connection.py:38(create_connection)
#         5    0.000    0.000    0.005    0.001 response.py:481(read)
#         9    0.000    0.000    0.005    0.001 apply.py:1124(apply_standard)
#         2    0.000    0.000    0.005    0.002 csvs.py:236(save)
#        11    0.000    0.000    0.005    0.000 frame.py:587(__init__)
#         5    0.000    0.000    0.005    0.001 adapters.py:292(get_connection)
#         2    0.000    0.000    0.004    0.002 server.py:306(_terminate_server)
#         5    0.000    0.000    0.004    0.001 models.py:310(prepare)
#         5    0.000    0.000    0.004    0.001 client.py:447(read)
#         5    0.000    0.000    0.004    0.001 poolmanager.py:286(connection_from_url)
#         5    0.000    0.000    0.004    0.001 request.py:2707(getproxies)
#         2    0.000    0.000    0.004    0.002 subprocess.py:1374(_communicate)
#         5    0.000    0.000    0.004    0.001 client.py:479(readinto)
#         1    0.000    0.000    0.004    0.004 2703895914.py:21(comma_cluster_removal_df)
#         5    0.000    0.000    0.004    0.001 {method 'readinto' of '_io.BufferedReader' objects}
# 6011/6008    0.002    0.000    0.003    0.000 {built-in method builtins.isinstance}
#         5    0.000    0.000    0.003    0.001 client.py:204(parse_headers)
#         5    0.003    0.001    0.003    0.001 {method 'connect' of '_socket.socket' objects}
#         1    0.000    0.000    0.003    0.003 readers.py:1245(read)
#         2    0.000    0.000    0.003    0.002 construction.py:425(dict_to_mgr)
#        39    0.000    0.000    0.003    0.000 iostream.py:500(write)
#        17    0.000    0.000    0.003    0.000 {built-in method builtins.print}
#         5    0.000    0.000    0.003    0.001 threading.py:834(start)
#         3    0.000    0.000    0.003    0.001 common.py:601(get_handle)
#         1    0.000    0.000    0.003    0.003 info.py:780(add_dtypes_line)
#         1    0.000    0.000    0.003    0.003 info.py:753(dtype_counts)
#         1    0.000    0.000    0.003    0.003 info.py:424(size_qualifier)
#         9    0.000    0.000    0.003    0.000 indexing.py:954(__getitem__)
#       175    0.003    0.000    0.003    0.000 {method 'acquire' of '_thread.lock' objects}
#        11    0.000    0.000    0.003    0.000 base.py:672(_with_infer)
#         5    0.000    0.000    0.003    0.001 parser.py:59(parsestr)
#         6    0.000    0.000    0.003    0.000 utils.py:69(get_language_tool_download_path)
#         9    0.000    0.000    0.003    0.000 indexing.py:1487(_getitem_axis)
#         2    0.000    0.000    0.003    0.001 groupby.py:2174(sum)
#        41    0.000    0.000    0.003    0.000 iostream.py:206(schedule)
#         5    0.000    0.000    0.003    0.001 parser.py:41(parse)
#      1187    0.001    0.000    0.003    0.000 os.py:740(encodekey)
#         5    0.000    0.000    0.003    0.001 threading.py:540(wait)
#         2    0.000    0.000    0.003    0.001 groupby.py:1503(_agg_general)
#         5    0.000    0.000    0.003    0.001 threading.py:270(wait)
#         2    0.000    0.000    0.003    0.001 groupby.py:1563(_cython_agg_general)
#         5    0.000    0.000    0.003    0.001 models.py:358(prepare_url)
#         3    0.000    0.000    0.002    0.001 utils.py:79(get_language_tool_directory)
#         1    0.000    0.000    0.002    0.002 info.py:668(_create_table_builder)
#         1    0.000    0.000    0.002    0.002 info.py:955(__init__)
#         5    0.000    0.000    0.002    0.000 sessions.py:427(__exit__)
#         5    0.000    0.000    0.002    0.000 sessions.py:744(close)
#         3    0.000    0.000    0.002    0.001 spawn.py:169(find_executable)
#         3    0.000    0.000    0.002    0.001 info.py:996(_gen_rows_with_counts)
#     19/13    0.000    0.000    0.002    0.000 base.py:397(__new__)
#        24    0.000    0.000    0.002    0.000 genericpath.py:39(isdir)
#        10    0.000    0.000    0.002    0.000 adapters.py:319(close)
#        15    0.002    0.000    0.002    0.000 {built-in method io.open}
#         9    0.000    0.000    0.002    0.000 glob.py:10(glob)
#        10    0.000    0.000    0.002    0.000 poolmanager.py:215(clear)
#        10    0.000    0.000    0.002    0.000 _collections.py:92(clear)
#         6    0.000    0.000    0.002    0.000 os.py:198(makedirs)
#        18    0.000    0.000    0.002    0.000 glob.py:41(_iglob)
#         2    0.000    0.000    0.002    0.001 base.py:192(grouped_reduce)
#         7    0.000    0.000    0.002    0.000 generic.py:11049(sum)
#         7    0.000    0.000    0.002    0.000 generic.py:10780(sum)
#        17    0.000    0.000    0.002    0.000 genericpath.py:16(exists)
#         7    0.000    0.000    0.002    0.000 generic.py:10731(_min_count_stat_function)
#        41    0.002    0.000    0.002    0.000 socket.py:432(send)
#         1    0.000    0.000    0.002    0.002 info.py:502(memory_usage_bytes)
#         2    0.000    0.000    0.002    0.001 groupby.py:1585(array_func)
#         5    0.000    0.000    0.002    0.000 poolmanager.py:173(<lambda>)
#         2    0.000    0.000    0.002    0.001 ops.py:920(_cython_operation)
#         4    0.000    0.000    0.002    0.001 server.py:131(<listcomp>)
#         6    0.000    0.000    0.002    0.000 match.py:47(__init__)
#         5    0.000    0.000    0.002    0.000 connectionpool.py:479(close)
#         3    0.000    0.000    0.002    0.001 info.py:939(_gen_non_null_counts)
#         1    0.000    0.000    0.002    0.002 info.py:768(non_null_counts)
#         1    0.000    0.000    0.002    0.002 info.py:497(non_null_counts)
#         1    0.000    0.000    0.002    0.002 frame.py:9788(count)
#         1    0.000    0.000    0.002    0.002 frame.py:3178(memory_usage)
#        38    0.000    0.000    0.002    0.000 base.py:6987(ensure_index)
#        10    0.000    0.000    0.002    0.000 generic.py:5749(astype)
#         5    0.000    0.000    0.002    0.000 feedparser.py:173(feed)
#        69    0.001    0.000    0.002    0.000 parse.py:366(urlparse)
#         2    0.000    0.000    0.002    0.001 base.py:884(value_counts)
#         2    0.000    0.000    0.002    0.001 algorithms.py:803(value_counts)
#        94    0.001    0.000    0.002    0.000 {built-in method builtins.setattr}
#         5    0.000    0.000    0.002    0.000 poolmanager.py:224(connection_from_host)
#        13    0.000    0.000    0.002    0.000 frame.py:3411(_ixs)
#         5    0.000    0.000    0.002    0.000 poolmanager.py:247(connection_from_context)
#         5    0.000    0.000    0.002    0.000 utils.py:169(get_netrc_auth)
#        10    0.000    0.000    0.002    0.000 feedparser.py:178(_call_parse)
#         5    0.000    0.000    0.002    0.000 adapters.py:255(build_response)
#         5    0.000    0.000    0.002    0.000 url.py:320(_encode_target)
#        35    0.000    0.000    0.002    0.000 construction.py:470(sanitize_array)
#        10    0.000    0.000    0.002    0.000 feedparser.py:218(_parsegen)
#         1    0.000    0.000    0.002    0.002 2703895914.py:193(add_space_before_opening_bracket)
#         1    0.000    0.000    0.002    0.002 readers.py:887(__init__)
#        15    0.000    0.000    0.002    0.000 managers.py:253(apply)
#         5    0.000    0.000    0.001    0.000 poolmanager.py:262(connection_from_pool_key)
#         6    0.000    0.000    0.001    0.000 glob.py:81(_glob1)
#         2    0.000    0.000    0.001    0.001 csvs.py:263(_save)
#         1    0.000    0.000    0.001    0.001 readers.py:1193(_make_engine)
#        63    0.001    0.000    0.001    0.000 ntpath.py:77(join)
#         5    0.000    0.000    0.001    0.000 poolmanager.py:188(_new_pool)
#         2    0.000    0.000    0.001    0.001 csvs.py:296(_save_body)
#        27    0.001    0.000    0.001    0.000 {pandas._libs.lib.maybe_convert_objects}
#         5    0.000    0.000    0.001    0.000 sessions.py:362(__init__)
#        90    0.000    0.000    0.001    0.000 match.py:109(__setattr__)
#         5    0.000    0.000    0.001    0.000 connectionpool.py:168(__init__)
#         2    0.000    0.000    0.001    0.001 csvs.py:306(_save_chunk)
#        12    0.001    0.000    0.001    0.000 glob.py:116(_iterdir)
#        35    0.000    0.000    0.001    0.000 sessions.py:50(merge_setting)
#         7    0.000    0.000    0.001    0.000 series.py:4435(_reduce)
#        21    0.001    0.000    0.001    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#        11    0.000    0.000    0.001    0.000 {pandas._libs.lib.map_infer}
#         2    0.000    0.000    0.001    0.001 series.py:1807(groupby)
#         5    0.000    0.000    0.001    0.000 response.py:581(from_httplib)
#         4    0.000    0.000    0.001    0.000 indexing.py:1464(_get_list_axis)
#         1    0.000    0.000    0.001    0.001 frame.py:9937(_reduce)
#         2    0.000    0.000    0.001    0.001 groupby.py:839(__init__)
#        35    0.000    0.000    0.001    0.000 structures.py:42(__init__)
#        10    0.000    0.000    0.001    0.000 managers.py:418(astype)
#         2    0.000    0.000    0.001    0.001 grouper.py:700(get_grouper)
#         2    0.000    0.000    0.001    0.001 ops.py:832(group_info)
# 1428/1234    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.001    0.001 ops.py:854(_get_compressed_codes)
#         7    0.000    0.000    0.001    0.000 nanops.py:83(_f)
#        60    0.000    0.000    0.001    0.000 queue.py:153(get)
#         5    0.000    0.000    0.001    0.000 models.py:82(_encode_params)
#        10    0.000    0.000    0.001    0.000 cookies.py:118(extract_cookies_to_jar)
#         5    0.000    0.000    0.001    0.000 client.py:928(close)
#         3    0.000    0.000    0.001    0.000 which.py:48(get_path_list)
#      1187    0.001    0.000    0.001    0.000 os.py:734(check_str)
#        45    0.000    0.000    0.001    0.000 _collections_abc.py:824(update)
#        44    0.000    0.000    0.001    0.000 blocks.py:2043(new_block)
#         3    0.000    0.000    0.001    0.000 common.py:103(close)
#         3    0.000    0.000    0.001    0.000 construction.py:102(arrays_to_mgr)
#        74    0.000    0.000    0.001    0.000 generic.py:5577(__setattr__)
#       154    0.001    0.000    0.001    0.000 ntpath.py:124(splitdrive)
#        16    0.000    0.000    0.001    0.000 frame.py:3923(_get_item_cache)
#        14    0.000    0.000    0.001    0.000 frame.py:3463(__getitem__)
#         2    0.000    0.000    0.001    0.000 ops.py:586(cython_operation)
#        55    0.000    0.000    0.001    0.000 queue.py:121(put)
#        74    0.000    0.000    0.001    0.000 parse.py:417(urlsplit)
#         4    0.000    0.000    0.001    0.000 frame.py:3630(__setitem__)
#         5    0.000    0.000    0.001    0.000 socket.py:496(close)
#        13    0.000    0.000    0.001    0.000 base.py:7106(_maybe_cast_data_without_dtype)
#        90    0.001    0.000    0.001    0.000 match.py:5(get_match_ordered_dict)
#         6    0.001    0.000    0.001    0.000 subprocess.py:521(list2cmdline)
#         8    0.000    0.000    0.001    0.000 parse.py:504(urljoin)
#         5    0.000    0.000    0.001    0.000 socket.py:492(_real_close)
#         5    0.000    0.000    0.001    0.000 parse.py:891(urlencode)
#     73/61    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         2    0.000    0.000    0.001    0.000 ops.py:432(_cython_op_ndim_compat)
#        10    0.000    0.000    0.001    0.000 blocks.py:560(astype)
#        44    0.000    0.000    0.001    0.000 generic.py:5517(__finalize__)
#        42    0.000    0.000    0.001    0.000 config.py:255(__call__)
#         2    0.000    0.000    0.001    0.000 ops.py:476(_call_cython_op)
#         5    0.001    0.000    0.001    0.000 {function socket.close at 0x000001937A860D30}
#        29    0.000    0.000    0.001    0.000 managers.py:1731(from_array)
#         6    0.000    0.000    0.001    0.000 subprocess.py:1134(_get_handles)
#         1    0.001    0.001    0.001    0.001 {built-in method _socket.gethostbyname}
#         2    0.000    0.000    0.001    0.000 generic.py:3708(_take_with_is_copy)
#         4    0.000    0.000    0.001    0.000 frame.py:3822(_set_item)
#        21    0.000    0.000    0.001    0.000 parse.py:798(quote)
#        42    0.000    0.000    0.001    0.000 config.py:127(_get_option)
#        15    0.000    0.000    0.001    0.000 cookies.py:37(__init__)
#     16/15    0.000    0.000    0.001    0.000 missing.py:67(isna)
#        16    0.000    0.000    0.001    0.000 parse.py:852(quote_plus)
#         2    0.000    0.000    0.001    0.000 series.py:3330(sort_values)
#         2    0.000    0.000    0.001    0.000 grouper.py:468(__init__)
#      1100    0.001    0.000    0.001    0.000 os.py:693(__iter__)
#         1    0.000    0.000    0.001    0.001 series.py:463(_init_dict)
#         5    0.000    0.000    0.001    0.000 utils.py:48(proxy_bypass_registry)
#     16/15    0.000    0.000    0.001    0.000 missing.py:150(_isna)
#        15    0.000    0.000    0.001    0.000 cookies.py:508(cookiejar_from_dict)
#         1    0.000    0.000    0.001    0.001 managers.py:1366(reduce)
#         2    0.000    0.000    0.001    0.000 common.py:123(__exit__)
#         1    0.000    0.000    0.001    0.001 series.py:2936(_append)
#         7    0.000    0.000    0.001    0.000 nanops.py:395(new_func)
#         5    0.001    0.000    0.001    0.000 socket.py:219(__init__)
#         2    0.000    0.000    0.001    0.000 generic.py:3609(take)
#        64    0.000    0.000    0.001    0.000 _collections_abc.py:657(get)
#        21    0.000    0.000    0.001    0.000 parse.py:869(quote_from_bytes)
#         1    0.000    0.000    0.001    0.001 concat.py:143(concat)
#        20    0.000    0.000    0.001    0.000 message.py:564(get_content_type)
#         7    0.000    0.000    0.001    0.000 nanops.py:461(newfunc)
#         5    0.001    0.000    0.001    0.000 {method 'sendall' of '_socket.socket' objects}
#         5    0.000    0.000    0.001    0.000 models.py:876(json)
#         7    0.000    0.000    0.001    0.000 nanops.py:580(nansum)
#         6    0.001    0.000    0.001    0.000 {built-in method nt.scandir}
#         2    0.000    0.000    0.001    0.000 base.py:6055(map)
#         4    0.000    0.000    0.001    0.000 frame.py:3797(_set_item_mgr)
#         5    0.000    0.000    0.001    0.000 models.py:559(prepare_cookies)
#        61    0.000    0.000    0.001    0.000 generic.py:239(__init__)
#         6    0.000    0.000    0.001    0.000 subprocess.py:1101(_close_pipe_fds)
#         1    0.000    0.000    0.001    0.001 c_parser_wrapper.py:215(read)
#        38    0.000    0.000    0.001    0.000 numeric.py:288(full)
#        27    0.000    0.000    0.001    0.000 ntpath.py:289(expanduser)
#         5    0.000    0.000    0.001    0.000 cookies.py:135(get_cookie_header)
#       187    0.001    0.000    0.001    0.000 parse.py:110(_coerce_args)
#         2    0.000    0.000    0.001    0.000 grouper.py:616(codes)
#         1    0.000    0.000    0.001    0.001 construction.py:825(create_series_with_explicit_dtype)
#         2    0.000    0.000    0.001    0.000 grouper.py:659(_codes_and_uniques)
#      1725    0.001    0.000    0.001    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.001    0.000 algorithms.py:568(factorize)
#         5    0.000    0.000    0.001    0.000 models.py:599(__init__)
#        45    0.000    0.000    0.001    0.000 threading.py:1017(_wait_for_tstate_lock)
#   107/105    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#        10    0.000    0.000    0.001    0.000 utils.py:782(select_proxy)
#        10    0.000    0.000    0.001    0.000 adapters.py:113(__init__)
#         3    0.000    0.000    0.001    0.000 generic.py:5718(dtypes)
#         5    0.000    0.000    0.001    0.000 __init__.py:299(loads)
#        25    0.000    0.000    0.001    0.000 connection.py:216(putheader)
#        33    0.000    0.000    0.001    0.000 construction.py:698(_try_cast)
#        45    0.000    0.000    0.001    0.000 message.py:462(get)
#        35    0.000    0.000    0.001    0.000 utils.py:293(to_key_val_list)
#         2    0.000    0.000    0.001    0.000 cast.py:244(maybe_downcast_to_dtype)
#        66    0.000    0.000    0.001    0.000 series.py:640(name)
#         2    0.000    0.000    0.001    0.000 cast.py:291(maybe_downcast_numeric)
#      2257    0.001    0.000    0.001    0.000 {method 'decode' of 'bytes' objects}
#         4    0.000    0.000    0.001    0.000 threading.py:979(join)
#        10    0.001    0.000    0.001    0.000 {built-in method winreg.OpenKey}
#        15    0.000    0.000    0.001    0.000 message.py:588(get_content_maintype)
#         4    0.000    0.000    0.001    0.000 frame.py:3790(_iset_item_mgr)
#        63    0.000    0.000    0.001    0.000 {built-in method builtins.any}
#       186    0.000    0.000    0.001    0.000 abc.py:96(__instancecheck__)
#         5    0.000    0.000    0.001    0.000 decoder.py:332(decode)
#         5    0.000    0.000    0.000    0.000 threading.py:761(__init__)
#         5    0.000    0.000    0.000    0.000 models.py:444(prepare_headers)
#         5    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#       110    0.000    0.000    0.000    0.000 threading.py:341(notify)
#        50    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         2    0.000    0.000    0.000    0.000 common.py:556(check_parent_directory)
#         6    0.000    0.000    0.000    0.000 {built-in method nt.mkdir}
#       126    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#       480    0.000    0.000    0.000    0.000 generic.py:43(_check)
#         5    0.000    0.000    0.000    0.000 feedparser.py:184(close)
#        20    0.000    0.000    0.000    0.000 ntpath.py:180(split)
#        95    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 construction.py:505(nested_data_to_arrays)
#        42    0.000    0.000    0.000    0.000 config.py:109(_get_single_key)
#         4    0.000    0.000    0.000    0.000 parse.py:889(<listcomp>)
#         4    0.000    0.000    0.000    0.000 managers.py:1061(iset)
#         5    0.000    0.000    0.000    0.000 response.py:195(__init__)
#         5    0.000    0.000    0.000    0.000 feedparser.py:471(_parse_headers)
#         1    0.000    0.000    0.000    0.000 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#      2258    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        10    0.000    0.000    0.000    0.000 cookiejar.py:1677(extract_cookies)
#         1    0.000    0.000    0.000    0.000 frame.py:3263(<listcomp>)
#         2    0.000    0.000    0.000    0.000 managers.py:875(take)
#   140/136    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        10    0.000    0.000    0.000    0.000 cast.py:1246(astype_array_safe)
#       148    0.000    0.000    0.000    0.000 common.py:1587(_is_dtype_type)
#        63    0.000    0.000    0.000    0.000 subprocess.py:191(Close)
#        12    0.000    0.000    0.000    0.000 {built-in method _winapi.CreatePipe}
#         3    0.000    0.000    0.000    0.000 common.py:251(_get_filepath_or_buffer)
#         5    0.000    0.000    0.000    0.000 adapters.py:329(request_url)
#         5    0.000    0.000    0.000    0.000 connection.py:203(putrequest)
#        20    0.000    0.000    0.000    0.000 cookiejar.py:1258(__init__)
#        15    0.000    0.000    0.000    0.000 {built-in method winreg.QueryValueEx}
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:45(__init__)
#         2    0.000    0.000    0.000    0.000 grouper.py:650(group_index)
#         4    0.000    0.000    0.000    0.000 base.py:1443(_format_native_types)
#         1    0.000    0.000    0.000    0.000 construction.py:798(to_arrays)
#         5    0.000    0.000    0.000    0.000 connectionpool.py:243(_get_conn)
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        15    0.000    0.000    0.000    0.000 blocks.py:252(make_block)
#         3    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#        14    0.000    0.000    0.000    0.000 contextlib.py:117(__exit__)
#         5    0.000    0.000    0.000    0.000 decoder.py:343(raw_decode)
#      1247    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 client.py:1055(putrequest)
#        25    0.000    0.000    0.000    0.000 client.py:1211(putheader)
#         5    0.000    0.000    0.000    0.000 request.py:2662(getproxies_registry)
#         1    0.000    0.000    0.000    0.000 concat.py:368(__init__)
#        39    0.000    0.000    0.000    0.000 {built-in method _winapi.CloseHandle}
#         8    0.000    0.000    0.000    0.000 nanops.py:257(_get_values)
#         1    0.000    0.000    0.000    0.000 construction.py:971(_finalize_columns_and_data)
#         3    0.000    0.000    0.000    0.000 missing.py:288(notna)
#        68    0.000    0.000    0.000    0.000 common.py:1721(validate_all_hashable)
#        22    0.000    0.000    0.000    0.000 series.py:943(__getitem__)
#        10    0.000    0.000    0.000    0.000 frame.py:3906(_box_col_values)
#   105/103    0.000    0.000    0.000    0.000 _asarray.py:23(asarray)
#       746    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        18    0.000    0.000    0.000    0.000 parse.py:474(urlunparse)
#         3    0.000    0.000    0.000    0.000 download_lt.py:138(<listcomp>)
#        40    0.000    0.000    0.000    0.000 parse.py:155(hostname)
#         5    0.000    0.000    0.000    0.000 socket.py:901(getaddrinfo)
#         5    0.000    0.000    0.000    0.000 _collections.py:141(__init__)
#         1    0.000    0.000    0.000    0.000 construction.py:1051(_convert_object_array)
#         1    0.000    0.000    0.000    0.000 construction.py:1073(<listcomp>)
#        53    0.000    0.000    0.000    0.000 construction.py:379(extract_array)
#         9    0.000    0.000    0.000    0.000 base.py:5178(equals)
#        25    0.000    0.000    0.000    0.000 _ufunc_config.py:433(__enter__)
#         2    0.000    0.000    0.000    0.000 construction.py:1067(convert)
#         2    0.000    0.000    0.000    0.000 pathlib.py:1410(is_dir)
#        40    0.000    0.000    0.000    0.000 _policybase.py:311(header_fetch_parse)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(allclose)
#        10    0.000    0.000    0.000    0.000 structures.py:82(copy)
#        16    0.000    0.000    0.000    0.000 base.py:3577(get_loc)
#        33    0.000    0.000    0.000    0.000 _collections_abc.py:664(__contains__)
#         3    0.000    0.000    0.000    0.000 frame.py:1266(items)
#         2    0.000    0.000    0.000    0.000 managers.py:468(to_native_types)
#         2    0.000    0.000    0.000    0.000 series.py:913(_take_with_is_copy)
#        61    0.000    0.000    0.000    0.000 flags.py:47(__init__)
#         3    0.000    0.000    0.000    0.000 ntpath.py:240(lexists)
#         1    0.000    0.000    0.000    0.000 concat.py:544(get_result)
#         2    0.000    0.000    0.000    0.000 series.py:895(take)
#         2    0.000    0.000    0.000    0.000 numeric.py:2186(allclose)
#         1    0.000    0.000    0.000    0.000 blocks.py:406(reduce)
#         2    0.000    0.000    0.000    0.000 pathlib.py:1192(stat)
#        28    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.000    0.000 series.py:4655(reindex)
#         3    0.000    0.000    0.000    0.000 managers.py:1937(create_block_manager_from_column_arrays)
#       186    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.lstat}
#         2    0.000    0.000    0.000    0.000 csvs.py:50(__init__)
#        44    0.000    0.000    0.000    0.000 common.py:1429(is_extension_array_dtype)
#        10    0.000    0.000    0.000    0.000 response.py:425(_error_catcher)
#         1    0.000    0.000    0.000    0.000 concat.py:610(_get_new_axes)
#         3    0.000    0.000    0.000    0.000 info.py:944(_gen_dtypes)
#        10    0.000    0.000    0.000    0.000 2703895914.py:32(is_undesirable_question_to_count)
#         3    0.000    0.000    0.000    0.000 {built-in method nt.access}
#        47    0.000    0.000    0.000    0.000 common.py:1240(is_float_dtype)
#         2    0.000    0.000    0.000    0.000 numeric.py:338(_format_native_types)
#         1    0.000    0.000    0.000    0.000 concat.py:612(<listcomp>)
#        10    0.000    0.000    0.000    0.000 cookiejar.py:1596(make_cookies)
#        58    0.000    0.000    0.000    0.000 blocks.py:1962(maybe_coerce_values)
#         1    0.000    0.000    0.000    0.000 concat.py:627(_get_concat_axis)
#        44    0.000    0.000    0.000    0.000 blocks.py:2057(check_ndim)
#         2    0.000    0.000    0.000    0.000 generic.py:4719(reindex)
#        24    0.000    0.000    0.000    0.000 ntpath.py:203(splitext)
#         5    0.000    0.000    0.000    0.000 connectionpool.py:222(_new_conn)
#         2    0.000    0.000    0.000    0.000 algorithms.py:883(value_counts_arraylike)
#         1    0.000    0.000    0.000    0.000 concat.py:685(_concat_indexes)
#         1    0.000    0.000    0.000    0.000 frame.py:9984(blk_func)
#         3    0.000    0.000    0.000    0.000 utils.py:83(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:5092(append)
#      1075    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        11    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#         5    0.000    0.000    0.000    0.000 client.py:237(__init__)
#        10    0.000    0.000    0.000    0.000 adapters.py:146(init_poolmanager)
#        30    0.000    0.000    0.000    0.000 threading.py:81(RLock)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#       158    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 sessions.py:677(<listcomp>)
#        10    0.000    0.000    0.000    0.000 response.py:275(release_conn)
#         1    0.000    0.000    0.000    0.000 readers.py:1290(__exit__)
#         1    0.000    0.000    0.000    0.000 base.py:5122(_concat)
#         1    0.000    0.000    0.000    0.000 readers.py:936(close)
#         5    0.000    0.000    0.000    0.000 utils.py:604(requote_uri)
#        25    0.000    0.000    0.000    0.000 _ufunc_config.py:438(__exit__)
#         2    0.000    0.000    0.000    0.000 numeric.py:2264(isclose)
#         2    0.000    0.000    0.000    0.000 blocks.py:631(to_native_types)
#        40    0.000    0.000    0.000    0.000 _policybase.py:281(_sanitize_header)
#        12    0.000    0.000    0.000    0.000 missing.py:227(_isna_array)
#   201/196    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        33    0.000    0.000    0.000    0.000 common.py:1274(is_bool_dtype)
#         5    0.000    0.000    0.000    0.000 sessions.py:144(resolve_redirects)
#         3    0.000    0.000    0.000    0.000 managers.py:2008(_form_blocks)
#         2    0.000    0.000    0.000    0.000 format.py:560(__init__)
#         2    0.000    0.000    0.000    0.000 indexing.py:1524(_get_slice_axis)
#        45    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 generic.py:10875(any)
#        30    0.000    0.000    0.000    0.000 cookiejar.py:1223(deepvalues)
#         5    0.000    0.000    0.000    0.000 models.py:537(prepare_auth)
#         5    0.000    0.000    0.000    0.000 feedparser.py:101(push)
#        19    0.000    0.000    0.000    0.000 common.py:229(asarray_tuplesafe)
#         1    0.000    0.000    0.000    0.000 series.py:5276(isna)
#        13    0.000    0.000    0.000    0.000 base.py:554(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 generic.py:10453(any)
#        30    0.000    0.000    0.000    0.000 series.py:542(_set_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:7230(isna)
#         2    0.000    0.000    0.000    0.000 csvs.py:144(_initialize_columns)
#         5    0.000    0.000    0.000    0.000 queue.py:33(__init__)
#       115    0.000    0.000    0.000    0.000 structures.py:48(__setitem__)
#         5    0.000    0.000    0.000    0.000 response.py:40(assert_header_parsing)
#         1    0.000    0.000    0.000    0.000 generic.py:10395(_logical_func)
#        79    0.000    0.000    0.000    0.000 series.py:687(_values)
#         5    0.000    0.000    0.000    0.000 cookiejar.py:1353(add_cookie_header)
#         5    0.000    0.000    0.000    0.000 utils.py:817(default_headers)
#        30    0.000    0.000    0.000    0.000 common.py:1747(pandas_dtype)
#         6    0.000    0.000    0.000    0.000 contextlib.py:482(__exit__)
#         5    0.000    0.000    0.000    0.000 feedparser.py:139(__init__)
#        46    0.000    0.000    0.000    0.000 base.py:7082(maybe_extract_name)
#        32    0.000    0.000    0.000    0.000 {method 'subn' of 're.Pattern' objects}
#         5    0.000    0.000    0.000    0.000 connectionpool.py:282(_put_conn)
#         4    0.000    0.000    0.000    0.000 2703895914.py:13(replace_multiple_commas)
#        10    0.000    0.000    0.000    0.000 cast.py:1199(astype_array)
#         5    0.000    0.000    0.000    0.000 socket.py:301(makefile)
#       324    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        51    0.000    0.000    0.000    0.000 blocks.py:1991(get_block_type)
#         2    0.000    0.000    0.000    0.000 managers.py:634(reindex_indexer)
#        24    0.000    0.000    0.000    0.000 base.py:465(find)
#         5    0.000    0.000    0.000    0.000 _collections.py:231(extend)
#         5    0.000    0.000    0.000    0.000 utils.py:921(get_auth_from_url)
#         1    0.000    0.000    0.000    0.000 info.py:748(dtypes)
#        40    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         1    0.000    0.000    0.000    0.000 info.py:468(dtypes)
#         2    0.000    0.000    0.000    0.000 subprocess.py:1440(terminate)
#       120    0.000    0.000    0.000    0.000 threading.py:246(__enter__)
#        10    0.000    0.000    0.000    0.000 poolmanager.py:170(__init__)
#       115    0.000    0.000    0.000    0.000 threading.py:261(_is_owned)
#        15    0.000    0.000    0.000    0.000 cookies.py:521(<listcomp>)
#       242    0.000    0.000    0.000    0.000 2703895914.py:71(<genexpr>)
#        73    0.000    0.000    0.000    0.000 series.py:590(name)
#         2    0.000    0.000    0.000    0.000 sorting.py:357(nargsort)
#         5    0.000    0.000    0.000    0.000 poolmanager.py:78(_default_key_normalizer)
#       120    0.000    0.000    0.000    0.000 threading.py:249(__exit__)
#         5    0.000    0.000    0.000    0.000 base.py:1098(take)
#        26    0.000    0.000    0.000    0.000 base.py:5023(__getitem__)
#        20    0.000    0.000    0.000    0.000 threading.py:222(__init__)
#         5    0.000    0.000    0.000    0.000 {built-in method _socket.getaddrinfo}
#        12    0.000    0.000    0.000    0.000 cp1252.py:22(decode)
#         1    0.000    0.000    0.000    0.000 construction.py:635(_extract_index)
#        30    0.000    0.000    0.000    0.000 feedparser.py:128(__next__)
#        61    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         4    0.000    0.000    0.000    0.000 generic.py:4952(<genexpr>)
#        32    0.000    0.000    0.000    0.000 common.py:680(is_integer_dtype)
#        90    0.000    0.000    0.000    0.000 structures.py:53(__getitem__)
#         6    0.000    0.000    0.000    0.000 ntpath.py:337(expandvars)
#         5    0.000    0.000    0.000    0.000 missing.py:391(array_equivalent)
#         2    0.000    0.000    0.000    0.000 algorithms.py:524(factorize_array)
#        15    0.000    0.000    0.000    0.000 url.py:244(_remove_path_dot_segments)
#        24    0.000    0.000    0.000    0.000 genericpath.py:121(_splitext)
#        21    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 grouper.py:838(is_in_axis)
#        18    0.000    0.000    0.000    0.000 contextlib.py:429(callback)
#         2    0.000    0.000    0.000    0.000 generic.py:3908(_slice)
#         4    0.000    0.000    0.000    0.000 utils.py:52(correct)
#         3    0.000    0.000    0.000    0.000 managers.py:983(fast_xs)
#        42    0.000    0.000    0.000    0.000 config.py:589(_get_root)
#         1    0.000    0.000    0.000    0.000 api.py:177(union_indexes)
#        34    0.000    0.000    0.000    0.000 re.py:289(_compile)
#        50    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        33    0.000    0.000    0.000    0.000 common.py:161(is_object_dtype)
#         9    0.000    0.000    0.000    0.000 common.py:105(is_bool_indexer)
#        18    0.000    0.000    0.000    0.000 subprocess.py:1206(_make_inheritable)
#        30    0.000    0.000    0.000    0.000 cookiejar.py:1219(vals_sorted_by_key)
#        15    0.000    0.000    0.000    0.000 _policybase.py:293(header_source_parse)
#         5    0.000    0.000    0.000    0.000 connection.py:110(__init__)
#         2    0.000    0.000    0.000    0.000 base.py:5265(identical)
#        40    0.000    0.000    0.000    0.000 parse.py:195(_hostinfo)
#        18    0.000    0.000    0.000    0.000 parse.py:485(urlunsplit)
#        35    0.000    0.000    0.000    0.000 _collections.py:156(__getitem__)
#         9    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         2    0.000    0.000    0.000    0.000 managers.py:692(<listcomp>)
#         6    0.000    0.000    0.000    0.000 fnmatch.py:48(filter)
#        20    0.000    0.000    0.000    0.000 timeout.py:102(__init__)
#        10    0.000    0.000    0.000    0.000 cast.py:1466(maybe_infer_to_datetimelike)
#        22    0.000    0.000    0.000    0.000 series.py:1052(_get_value)
#       326    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 algorithms.py:1667(safe_sort)
#        16    0.000    0.000    0.000    0.000 base.py:6284(_maybe_cast_indexer)
#         2    0.000    0.000    0.000    0.000 base.py:796(_map_values)
#       136    0.000    0.000    0.000    0.000 common.py:1740(<genexpr>)
#         2    0.000    0.000    0.000    0.000 blocks.py:2153(to_native_types)
#         4    0.000    0.000    0.000    0.000 take.py:57(take_nd)
#       142    0.000    0.000    0.000    0.000 inference.py:321(is_hashable)
#        15    0.000    0.000    0.000    0.000 sessions.py:74(<listcomp>)
#         5    0.000    0.000    0.000    0.000 threading.py:505(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:3058(union)
#         1    0.000    0.000    0.000    0.000 generic.py:5926(copy)
#        20    0.000    0.000    0.000    0.000 url.py:274(_normalize_host)
#       138    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 generic.py:1516(__invert__)
#         7    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        21    0.000    0.000    0.000    0.000 inference.py:262(is_dict_like)
#        79    0.000    0.000    0.000    0.000 managers.py:1848(internal_values)
#         5    0.000    0.000    0.000    0.000 message.py:451(items)
#        27    0.000    0.000    0.000    0.000 base.py:654(_simple_new)
#         5    0.000    0.000    0.000    0.000 response.py:317(_init_length)
#         6    0.000    0.000    0.000    0.000 missing.py:268(_isna_string_dtype)
#       589    0.000    0.000    0.000    0.000 {method '__getitem__' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 re.py:203(sub)
#         2    0.000    0.000    0.000    0.000 {built-in method _winapi.TerminateProcess}
#        75    0.000    0.000    0.000    0.000 six.py:959(ensure_text)
#        45    0.000    0.000    0.000    0.000 utils.py:51(_has_surrogates)
#         1    0.000    0.000    0.000    0.000 frame.py:5856(isna)
#         1    0.000    0.000    0.000    0.000 managers.py:543(_combine)
#        10    0.000    0.000    0.000    0.000 retry.py:225(__init__)
#        10    0.000    0.000    0.000    0.000 managers.py:1016(iget)
#        15    0.000    0.000    0.000    0.000 url.py:91(__new__)
#        13    0.000    0.000    0.000    0.000 base.py:744(__iter__)
#        10    0.000    0.000    0.000    0.000 cookies.py:529(merge_cookies)
#        40    0.000    0.000    0.000    0.000 config.py:642(_warn_if_deprecated)
#        90    0.000    0.000    0.000    0.000 url.py:411(ensure_type)
#        18    0.000    0.000    0.000    0.000 base.py:286(is_dtype)
#         5    0.000    0.000    0.000    0.000 utils.py:717(<lambda>)
#        10    0.000    0.000    0.000    0.000 connectionpool.py:320(_get_timeout)
#         1    0.000    0.000    0.000    0.000 format.py:2149(buffer_put_lines)
#         3    0.000    0.000    0.000    0.000 download_lt.py:43(parse_java_version)
#       138    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF86EE2B810}
#         2    0.000    0.000    0.000    0.000 ops.py:864(ngroups)
#        45    0.000    0.000    0.000    0.000 indexing.py:2481(check_deprecated_indexers)
#         4    0.000    0.000    0.000    0.000 take.py:120(_take_nd_ndarray)
#         2    0.000    0.000    0.000    0.000 cast.py:1579(maybe_cast_to_datetime)
#         5    0.000    0.000    0.000    0.000 message.py:213(get_payload)
#       115    0.000    0.000    0.000    0.000 queue.py:15(_qsize)
#        20    0.000    0.000    0.000    0.000 message.py:497(get_all)
#        86    0.000    0.000    0.000    0.000 construction.py:438(ensure_wrapped_if_datetimelike)
#       107    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#       141    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         7    0.000    0.000    0.000    0.000 _methods.py:45(_sum)
#        82    0.000    0.000    0.000    0.000 config.py:603(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 nanops.py:488(nanany)
#         5    0.000    0.000    0.000    0.000 utils.py:580(unquote_unreserved)
#         2    0.000    0.000    0.000    0.000 numeric.py:2344(within_tol)
#         5    0.000    0.000    0.000    0.000 message.py:459(<listcomp>)
#         2    0.000    0.000    0.000    0.000 ops.py:890(result_index)
#        14    0.000    0.000    0.000    0.000 contextlib.py:238(helper)
#        12    0.000    0.000    0.000    0.000 common.py:348(is_datetime64tz_dtype)
#        18    0.000    0.000    0.000    0.000 contextlib.py:381(_exit_wrapper)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#        20    0.000    0.000    0.000    0.000 message.py:29(_splitparam)
#         1    0.000    0.000    0.000    0.000 2703895914.py:126(<listcomp>)
#         5    0.000    0.000    0.000    0.000 client.py:409(_close_conn)
#     64/54    0.000    0.000    0.000    0.000 groupby.py:908(__getattribute__)
#         2    0.000    0.000    0.000    0.000 pathlib.py:1038(__new__)
#        11    0.000    0.000    0.000    0.000 idna.py:147(encode)
#        34    0.000    0.000    0.000    0.000 construction.py:630(_sanitize_ndim)
#        11    0.000    0.000    0.000    0.000 base.py:2603(_is_all_dates)
#         2    0.000    0.000    0.000    0.000 csvs.py:268(_save_header)
#       117    0.000    0.000    0.000    0.000 base.py:884(__len__)
#         3    0.000    0.000    0.000    0.000 common.py:127(is_url)
#         2    0.000    0.000    0.000    0.000 series.py:5014(memory_usage)
#       396    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
# ...
#         1    0.000    0.000    0.000    0.000 base.py:723(tolist)
#         1    0.000    0.000    0.000    0.000 info.py:985(add_columns_summary_line)
#        15    0.000    0.000    0.000    0.000 managers.py:282(<dictcomp>)
#         5    0.000    0.000    0.000    0.000 response.py:392(_decode)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#         4    0.000    0.000    0.000    0.000 format.py:761(_is_in_terminal)
#         1    0.000    0.000    0.000    0.000 base_parser.py:812(_do_date_conversions)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         2    0.000    0.000    0.000    0.000 managers.py:230(arrays)
#         3    0.000    0.000    0.000    0.000 construction.py:233(mgr_to_mgr)
#         2    0.000    0.000    0.000    0.000 dtype.py:216(construct_from_string)
#         9    0.000    0.000    0.000    0.000 codecs.py:281(getstate)
#         1    0.000    0.000    0.000    0.000 inference.py:294(is_named_tuple)
#        10    0.000    0.000    0.000    0.000 blocks.py:244(mgr_locs)
#        16    0.000    0.000    0.000    0.000 ops.py:680(groupings)
#         2    0.000    0.000    0.000    0.000 blocks.py:267(make_block_same_class)
#        12    0.000    0.000    0.000    0.000 enum.py:748(value)
#        10    0.000    0.000    0.000    0.000 feedparser.py:125(__iter__)
#         2    0.000    0.000    0.000    0.000 dtypes.py:300(construct_from_string)
#         1    0.000    0.000    0.000    0.000 managers.py:1395(<listcomp>)
#         2    0.000    0.000    0.000    0.000 format.py:685(_initialize_columns)
#         4    0.000    0.000    0.000    0.000 common.py:315(is_datetime64_dtype)
#         6    0.000    0.000    0.000    0.000 base_parser.py:1314(<genexpr>)
#         6    0.000    0.000    0.000    0.000 csvs.py:104(header)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#        10    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#        13    0.000    0.000    0.000    0.000 managers.py:919(__init__)
#         1    0.000    0.000    0.000    0.000 info.py:772(add_object_type_line)
#         1    0.000    0.000    0.000    0.000 info.py:782(<listcomp>)
#         2    0.000    0.000    0.000    0.000 csvs.py:163(_initialize_chunksize)
#         1    0.000    0.000    0.000    0.000 concat.py:557(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:3554(_assert_can_do_setop)
#         1    0.000    0.000    0.000    0.000 blocks.py:209(external_values)
#         9    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 base.py:518(<genexpr>)
#         1    0.000    0.000    0.000    0.000 format.py:2161(<listcomp>)
#         2    0.000    0.000    0.000    0.000 info.py:875(<listcomp>)
#         6    0.000    0.000    0.000    0.000 csvs.py:92(na_rep)
#         6    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         4    0.000    0.000    0.000    0.000 {built-in method sys.getsizeof}
#         8    0.000    0.000    0.000    0.000 nanops.py:191(_get_fill_value)
#         2    0.000    0.000    0.000    0.000 csvs.py:193(nlevels)
#         4    0.000    0.000    0.000    0.000 pathlib.py:1048(_init)
#         7    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#        15    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#        13    0.000    0.000    0.000    0.000 base.py:229(disallow_kwargs)
#         2    0.000    0.000    0.000    0.000 string_.py:117(construct_from_string)
#         2    0.000    0.000    0.000    0.000 groupby.py:985(_reset_group_selection)
#         3    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         4    0.000    0.000    0.000    0.000 grouper.py:804(<genexpr>)
#         5    0.000    0.000    0.000    0.000 utils.py:529(iter_slices)
#         6    0.000    0.000    0.000    0.000 concat.py:118(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:94(consensus_name_attr)
#         3    0.000    0.000    0.000    0.000 generic.py:5554(<genexpr>)
#         4    0.000    0.000    0.000    0.000 language_tag.py:21(__str__)
#        16    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 common.py:201(all_none)
#         2    0.000    0.000    0.000    0.000 numba_.py:19(maybe_use_numba)
#         6    0.000    0.000    0.000    0.000 subprocess.py:1058(_remaining_time)
#         2    0.000    0.000    0.000    0.000 generic.py:543(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 csvs.py:96(float_format)
#         5    0.000    0.000    0.000    0.000 client.py:865(_get_hostport)
#         1    0.000    0.000    0.000    0.000 info.py:880(<listcomp>)
#         4    0.000    0.000    0.000    0.000 grouper.py:802(<genexpr>)
#         5    0.000    0.000    0.000    0.000 models.py:184(<genexpr>)
#         5    0.000    0.000    0.000    0.000 models.py:646(__enter__)
#         1    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         2    0.000    0.000    0.000    0.000 series.py:2946(<genexpr>)
#         4    0.000    0.000    0.000    0.000 server.py:100(language)
#         5    0.000    0.000    0.000    0.000 connection.py:146(host)
#         2    0.000    0.000    0.000    0.000 common.py:115(ensure_python_int)
#         1    0.000    0.000    0.000    0.000 generic.py:5669(_is_mixed_type)
#         6    0.000    0.000    0.000    0.000 csvs.py:100(decimal)
#         2    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 concat.py:95(is_nonempty)
#         4    0.000    0.000    0.000    0.000 grouper.py:803(<genexpr>)
#         9    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#        11    0.000    0.000    0.000    0.000 numeric.py:331(_is_all_dates)
#         8    0.000    0.000    0.000    0.000 frame.py:578(_constructor)
#         6    0.000    0.000    0.000    0.000 subprocess.py:232(_cleanup)
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         5    0.000    0.000    0.000    0.000 {function HTTPResponse.flush at 0x000001937DF99700}
#         1    0.000    0.000    0.000    0.000 function_base.py:244(iterable)
#         5    0.000    0.000    0.000    0.000 base.py:1124(_maybe_disallow_fill)
#         2    0.000    0.000    0.000    0.000 c_parser_wrapper.py:356(<listcomp>)
#         4    0.000    0.000    0.000    0.000 server.py:111(motherTongue)
#         5    0.000    0.000    0.000    0.000 sessions.py:424(__enter__)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#         4    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#         1    0.000    0.000    0.000    0.000 base.py:5117(<setcomp>)
#         1    0.000    0.000    0.000    0.000 blocks.py:2241(external_values)
#         2    0.000    0.000    0.000    0.000 grouper.py:851(is_in_obj)
#         6    0.000    0.000    0.000    0.000 {method 'isascii' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         6    0.000    0.000    0.000    0.000 nanops.py:1484(check_below_min_count)
#         2    0.000    0.000    0.000    0.000 managers.py:482(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1154(_process_date_conversion)
#         2    0.000    0.000    0.000    0.000 c_parser_wrapper.py:358(<setcomp>)
#         5    0.000    0.000    0.000    0.000 proxy.py:4(connection_requires_http_tunnel)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:2350(_all_dispatcher)
#         2    0.000    0.000    0.000    0.000 format.py:1019(__init__)
#         2    0.000    0.000    0.000    0.000 ops.py:115(__init__)
#         5    0.000    0.000    0.000    0.000 cookies.py:81(get_new_headers)
#         4    0.000    0.000    0.000    0.000 csvs.py:108(index)
#         2    0.000    0.000    0.000    0.000 concat.py:111(<setcomp>)
#         2    0.000    0.000    0.000    0.000 indexing.py:2468(need_slice)
#         2    0.000    0.000    0.000    0.000 info.py:824(ids)
#         2    0.000    0.000    0.000    0.000 format.py:2160(<genexpr>)
#         6    0.000    0.000    0.000    0.000 contextlib.py:479(__enter__)
#         5    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 frame.py:10311(_get_agg_axis)
#         2    0.000    0.000    0.000    0.000 format.py:629(is_truncated_horizontally)
#         1    0.000    0.000    0.000    0.000 readers.py:1705(_validate_skipfooter)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.writers.word_len}
#         2    0.000    0.000    0.000    0.000 managers.py:239(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:486(<listcomp>)
#         3    0.000    0.000    0.000    0.000 info.py:978(headers)
#         2    0.000    0.000    0.000    0.000 ops.py:801(<listcomp>)
#         5    0.000    0.000    0.000    0.000 adapters.py:358(add_headers)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         2    0.000    0.000    0.000    0.000 generic.py:5549(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 concat.py:117(<setcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:5126(<listcomp>)
#         1    0.000    0.000    0.000    0.000 readers.py:1354(_clean_na_values)
#         1    0.000    0.000    0.000    0.000 base_parser.py:269(_extract_multi_indexer_columns)
#         5    0.000    0.000    0.000    0.000 connectionpool.py:310(_validate_conn)
#         3    0.000    0.000    0.000    0.000 codecs.py:331(getstate)
#         2    0.000    0.000    0.000    0.000 range.py:241(start)
#         1    0.000    0.000    0.000    0.000 concat.py:604(_get_result_dim)
#         2    0.000    0.000    0.000    0.000 ops.py:208(_disallow_invalid_ops)
#         2    0.000    0.000    0.000    0.000 csvs.py:134(_initialize_quotechar)
#         1    0.000    0.000    0.000    0.000 2703895914.py:136(<listcomp>)
#         2    0.000    0.000    0.000    0.000 missing.py:107(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 api.py:229(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:832(_check_data_length)
#         4    0.000    0.000    0.000    0.000 numeric.py:2388(_array_equal_dispatcher)
#         1    0.000    0.000    0.000    0.000 managers.py:558(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:240(_has_complex_date_col)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:205(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:408(ensure_dtype_objs)
#         3    0.000    0.000    0.000    0.000 subprocess.py:908(__enter__)
#         2    0.000    0.000    0.000    0.000 format.py:693(_initialize_colspace)
#         2    0.000    0.000    0.000    0.000 series.py:885(axes)
#         1    0.000    0.000    0.000    0.000 info.py:890(_gen_rows)
#         1    0.000    0.000    0.000    0.000 api.py:296(<setcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:634(<listcomp>)
#         1    0.000    0.000    0.000    0.000 common.py:174(validate_header_arg)
#         2    0.000    0.000    0.000    0.000 grouper.py:588(_ilevel)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         1    0.000    0.000    0.000    0.000 managers.py:1118(value_getitem)
#         2    0.000    0.000    0.000    0.000 format.py:666(_initialize_formatters)
#         2    0.000    0.000    0.000    0.000 grouper.py:640(result_index)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1823(_nonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 managers.py:217(is_single_block)
#         1    0.000    0.000    0.000    0.000 info.py:758(display_memory_usage)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:308(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 common.py:191(<genexpr>)
#         2    0.000    0.000    0.000    0.000 range.py:264(stop)
#         1    0.000    0.000    0.000    0.000 blocks.py:306(__len__)
#         2    0.000    0.000    0.000    0.000 format.py:633(is_truncated_vertically)
#         1    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 common.py:187(not_none)
#         1    0.000    0.000    0.000    0.000 base.py:3050(_validate_sort_keyword)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1062(_make_date_converter)
#         3    0.000    0.000    0.000    0.000 base_parser.py:1340(is_index_col)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:206(<listcomp>)
#         1    0.000    0.000    0.000    0.000 server.py:118(motherTongue)
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#         2    0.000    0.000    0.000    0.000 base.py:150(is_consolidated)
#         2    0.000    0.000    0.000    0.000 format.py:747(_adjust_max_rows)
#         2    0.000    0.000    0.000    0.000 stride_tricks.py:344(<genexpr>)
#         2    0.000    0.000    0.000    0.000 blocks.py:248(mgr_locs)
#         2    0.000    0.000    0.000    0.000 common.py:120(__enter__)
#         1    0.000    0.000    0.000    0.000 readers.py:1607(_extract_dialect)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:304(<listcomp>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:840(_sort_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method gc.get_referents}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 cast.py:311(trans)
#         2    0.000    0.000    0.000    0.000 range.py:287(step)
#         2    0.000    0.000    0.000    0.000 multiarray.py:644(result_type)
#         2    0.000    0.000    0.000    0.000 function_base.py:4306(_delete_dispatcher)
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:362(_broadcast_to_dispatcher)
#         2    0.000    0.000    0.000    0.000 common.py:205(<genexpr>)
#         2    0.000    0.000    0.000    0.000 numeric.py:2182(_allclose_dispatcher)
#         2    0.000    0.000    0.000    0.000 numeric.py:2260(_isclose_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2907(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#         2    0.000    0.000    0.000    0.000 info.py:819(data)
#         1    0.000    0.000    0.000    0.000 base_parser.py:220(<setcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:678(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 base_parser.py:920(_validate_usecols_arg)
#         1    0.000    0.000    0.000    0.000 range.py:183(_constructor)
#         1    0.000    0.000    0.000    0.000 numeric.py:188(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#         1    0.000    0.000    0.000    0.000 numeric.py:265(_should_fallback_to_positional)
#         1    0.000    0.000    0.000    0.000 readers.py:515(_validate_names)
#         1    0.000    0.000    0.000    0.000 readers.py:1287(__enter__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:232(<listcomp>)
#         1    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2251(_any_dispatcher)
#         1    0.000    0.000    0.000    0.000 api.py:230(<listcomp>)

# %% [markdown]
# ###### Deleting the undesirable Questions and thier corresponding answers, and truncated QnAs

# %%
import pandas as pd

def is_question_to_count(question):
    if isinstance(question, str):
        count_phrases = [
            
            "what is the title",
            "what is the research topic",
            "what data is used in the study",
            "what data sets are collected in this study",
            "how did the study",
            "what does the arrow in figure 6 represent",
            "what was the publication date of the study",
            "what is the title of the paper",
            "what is the purpose of this study",
            "what was the goal of the study",
            "what data was utilized in the study",
            "what is the source of funding for this study",
            "what was the aim of this study",
            "what are the objectives of the study",
            "what was the main focus of the study",
            "what were the main conclusions of the study",
            "what methods were used in the study",
            "what ratio was used for the analysis",
            "what models are shown in fig 4",
            "what is the conclusion of this study",
            "what do the innovations of this study enable",
            "what is the article about",
            "what is the doi number for the article",
            "where can the tool be accessed",
            "what data has been used",
            "what were the results of the study",
            "what are the key findings of this study",
            "what data sources were used in this study",
            "what are the limitations of this study",
            "where was the research conducted",
            "what are the key words for this article",
            "what is the main objective of this study",
            "what evidence supports the research",
            # Add more phrases here
        ]
        return any(phrase in question.lower() for phrase in count_phrases)
    return False


def is_truncated(text):
    if isinstance(text, str):
        return text.strip().endswith("...")
    return False

def is_typo(text):
    if isinstance(text, str):
        # Here, you can define a list of common words that might indicate typos
        # Customize this list according to your needs
        common_typos = [
            "odds", "noncurrent", "(mt)", "thermocyling", "o2geosocial", "Outbreaker2", "outbreaker()", "avaliable", "cleanup",
            "funannotate", "gallic", "nonessential", "Total", "runoff", "„",
            # Add more common typos here
        ]
        return any(typo in text.lower() for typo in common_typos)
    return False

def filter_undesirable_rows(df):
    # Filter rows based on whether the question is undesirable or truncated
    is_undesirable_question = df['Question'].apply(is_question_to_count)
    is_truncated_question = df['Question'].apply(is_truncated)
    is_truncated_answer = df['Answer'].apply(is_truncated)
    return df[~is_undesirable_question & ~is_truncated_question or ~is_truncated_answer]

def count_typos_in_csv(file_path, column_name):
    df = pd.read_csv(file_path)
    # Filter out undesirable and truncated rows before counting typos
    df_filtered = filter_undesirable_rows(df)
    typo_count = df_filtered[column_name].apply(is_typo).sum()
    return typo_count

def count_questions_in_csv(file_path):
    df = pd.read_csv(file_path)
    #df.info()
    questions_count = df['Question'].apply(is_question_to_count).sum()
    return questions_count

def count_truncated_questions_and_answers_in_csv(file_path):
    df = pd.read_csv(file_path)
    df.info()
    questions_count = df['Question'].apply(is_question_to_count).sum()

    # Count truncated questions
    truncated_questions_count = df['Question'].apply(is_truncated).sum()

    # Count truncated answers
    truncated_answers_count = df['Answer'].apply(is_truncated).sum()

    return questions_count, truncated_questions_count, truncated_answers_count


def main():
    # List of CSV files to process
    csv_files = [
        "C:/Users/Joshua Giwa/Downloads/QnAs_generated_31_07_2023/QnA_Organic farming_f1000_20230730.csv",
        # Add more file paths here as needed
    ]

    total_typos_count = 0

    for csv_file in csv_files:
        typo_count = count_typos_in_csv(csv_file, 'Question') + count_typos_in_csv(csv_file, 'Answer')
        total_typos_count += typo_count

        print(f"File: {csv_file}")
        print(f"Total Typos: {typo_count}\n")

        # Load the CSV file again to get the original data
        df = pd.read_csv(csv_file)

        # Filter out undesirable and truncated rows
        df_filtered = filter_undesirable_rows(df)

        # Save the cleaned DataFrame back to the CSV file
        df_filtered.to_csv(csv_file, index=False)

    print(f"Total Typos Count: {total_typos_count}")

if __name__ == "__main__":
    main()
