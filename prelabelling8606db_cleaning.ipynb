# %% [markdown]
# ### Counting the total number of all errors including undesirable Typos, QnAs and truncated QnAs

# %%
pip install language_tool_python

# %%
import pandas as pd
import os
import csv
import re
import language_tool_python
import time
import cProfile

def count_multiple_commas(text):
    if isinstance(text, str):
        pattern = re.compile(r',{2,}')
        return len(re.findall(pattern, text))
    else:
        return text

def replace_multiple_commas(text):
    if isinstance(text, str):
        pattern = re.compile(r',{2,}')
        corrected_text = re.sub(pattern, ', ', text)
        if corrected_text != text:
            print(f"\nOriginal text: {text}")
            print(f"Corrected text: {corrected_text}")
        return corrected_text
    else:
        return text

def comma_cluster_removal_df(df):
    total_comma_count = 0

    for column in df.columns:
        df[column] = df[column].apply(replace_multiple_commas)
        total_comma_count += df[column].apply(count_multiple_commas).sum()

    print(f"Total comma count: {total_comma_count}")
    return df, total_comma_count


def is_undesirable_question_to_count(question):
    if isinstance(question, str):
        count_phrases = [
            
            "what is the title",
            "what is the research topic",
            "what data is used in the study",
            "what data sets are collected in this study",
            "how did the study",
            "what does the arrow in figure 6 represent",
            "what was the publication date of the study",
            "what is the title of the paper",
            "what is the purpose of this study",
            "what was the goal of the study",
            "what data was utilized in the study",
            "what is the source of funding for this study",
            "what was the aim of this study",
            "what are the objectives of the study",
            "what was the main focus of the study",
            "what were the main conclusions of the study",
            "what methods were used in the study",
            "what ratio was used for the analysis",
            "what models are shown in fig 4",
            "what is the conclusion of this study",
            "what do the innovations of this study enable",
            "what is the article about",
            "what is the doi number for the article",
            "where can the tool be accessed",
            "what data has been used",
            "what were the results of the study",
            "what are the key findings of this study",
            "what data sources were used in this study",
            "what are the limitations of this study",
            "where was the research conducted",
            "what are the key words for this article",
            "what is the main objective of this study",
            "what evidence supports the research",
            # Add more phrases here
        ]
        return any(phrase in question.lower() for phrase in count_phrases)
    return False

def is_truncated(sentence):
    
    # Ensure the sentence is converted to a string
    sentence = str(sentence)
    # Define a list of sentence-ending punctuation marks
    sentence_endings = ['.', '!', '?', '."', '!"', '?"', '.”', '!”', '?”']
    
    # Check if the last character of the sentence is a sentence-ending punctuation mark
    if sentence[-1] in sentence_endings:
        return False  # Not truncated
    else:
        print ("\n" + sentence+"\n")
        return True   # Truncated

# Assuming you have defined your functions is_undesirable_question_to_count and is_truncated properly

def count_truncated_questions_and_answers_in_df(df, filtered_data_file):
    #df = pd.read_csv(file_path)
    df.info() 
    columns_with_spaces = df.columns.tolist()
    print(columns_with_spaces) 
    questions = df['Question']
    answers = df['Answer']
        
    questions_count = df['Question'].apply(is_undesirable_question_to_count).sum()

    # Count truncated questions
    truncated_questions_count = df['Question'].apply(is_truncated).sum()

    # Count truncated answers
    truncated_answers_count = df['Answer'].apply(is_truncated).sum()
     
    # Filter out truncated rows
    truncated_questions = []
    truncated_answers = []
    
    # Filter out truncated rows
    not_truncated_indices = []
    for i in range(len(df)):
        if not (is_truncated(questions[i]) or is_truncated(answers[i])):
            not_truncated_indices.append(i)
        else:
            if is_truncated(questions[i]):
                truncated_questions.append(questions[i])
                print(f"Truncated Question {i}: {questions[i]}")
            if is_truncated(answers[i]):
                truncated_answers.append(answers[i])
                print(f"Corresponding Question {i}: {questions[i]}")
                print(f"Truncated Answer  {i}: {answers[i]} \n")
    df = df.iloc[not_truncated_indices]
      
    # Filter out questions and their corresponding answers
    filtered_indices = [i for i, question in enumerate(df['Question']) if is_undesirable_question_to_count(question)]
    filtered_data = pd.DataFrame({
        'Question': df['Question'].iloc[filtered_indices],
        'Answer': df['Answer'].iloc[filtered_indices]
    })
    
    # Print the number of rows in the filtered data
    print("Number of rows in filtered data:", len(filtered_data))
    
    # Create a new DataFrame for remaining data without truncated QnA
    remaining_indices = [i for i in range(len(df)) if i not in filtered_indices]
    remaining_data = df.iloc[remaining_indices]
    
    # Print the number of rows in the remaining data
    print("Number of rows in remaining data:", len(remaining_data))
    
    # Save the filtered data
    filtered_data.to_csv(filtered_data_file, index=False, encoding='utf-8')
    
    # Save the remaining data
    #remaining_data.to_csv(remaining_data_file, index=False, encoding='utf-8')
    
    return questions_count, truncated_questions_count, truncated_answers_count, remaining_data



def save_filtered_data(file_path, filtered_data):
    with open(file_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Question', 'Answer']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(filtered_data)

        


#def count_errors(text):
 #   tool = language_tool_python.LanguageTool('en-GB')
  #  matches = tool.check(text)
   # return len(matches)

def LanguageTool_df(df):
    tool = language_tool_python.LanguageTool('en-GB')
    corrected_content = []

    for i in range(len(df)):
        corrected_row = []
        for cell in df.iloc[i]:
            if isinstance(cell, str):  # Check if the cell is a string
                corrected_cell = tool.correct(cell)
                corrected_cell = corrected_cell.replace(' Answer', 'Answer')
                corrected_row.append(corrected_cell)
            else:
                corrected_row.append(cell)  # If not a string, keep the original value
        corrected_content.append(corrected_row)

    LanguageTool_corrected_df = pd.DataFrame(corrected_content, columns=df.columns)

    return LanguageTool_corrected_df


def add_space_before_opening_bracket(df):
    #df = pd.read_csv(input_file_path)
    
    for column in df.columns:
        df[column] = df[column].apply(lambda cell: re.sub(r'([A-Za-z])\(', r'\1 (', cell) if isinstance(cell, str) else cell)
    
    #df.to_csv(ammended_space_file, index=False)
    
    return df   # Return the output file path after processing

def add_full_stops(df):
# function to add full stops to the end of each “Answer” column.
    df['Answer']=df['Answer'].apply(lambda answer: answer.strip()+  '.' if isinstance(answer,str) else answer)
    return df
 
def main():
    # List of CSV files to process
    start_time = time.time() 
    
    
    
    csv_files = [
       # "C:/Users/HP/Documents/Sam/Data Science Voluteer/CSV/Geothermal_energy_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_gatesopen_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal+energy_f1000_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal_energy_wellcome_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Carbon+footprint_wellcome_20230717.csv",
       ## "C:/Users/Joshua Giwa/Downloads/test_dataset.csv"
        "C:/Users/LolaPwasanga/Downloads/datarecords.csv"
        ## Add more file paths here as needed
    ]

    total_questions_count = 0
    total_truncated_questions_count = 0
    total_truncated_answers_count = 0
    

    for csv_file in csv_files: 
        df = pd.read_csv(csv_file)
        
        df = add_full_stops(df)
       # corrected_file_path = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_corrected.csv'))
        #remaining_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_remaining_data.csv'))
        filtered_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_filtered_questions.csv'))
        #ammended_space_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', 'bracket_spaced.csv'))
        questions_count, truncated_questions, truncated_answers, remaining_data = count_truncated_questions_and_answers_in_df(df, filtered_data_file)
        comma_cluster_removed_df, total_comma_count = comma_cluster_removal_df(remaining_data)
        space_before_bracket_ammended_df = add_space_before_opening_bracket(comma_cluster_removed_df)
        LanguageTool_corrected_df = LanguageTool_df(space_before_bracket_ammended_df)
       
        
        # Save the processed DataFrame with "updated" added to the name
        cleaned_df = LanguageTool_corrected_df.copy()
        cleaned_df_filename = os.path.basename(csv_file).replace('.csv', '_cleaned.csv')

        # Assuming that you have a directory where you want to save the updated DataFrames
        cleaned_df_dir = os.path.join(os.path.expanduser("~"), "Downloads", "cleaned_QnAs")

        if not os.path.exists(cleaned_df_dir):
            os.makedirs(cleaned_df_dir)

        cleaned_df_file_path = os.path.join(cleaned_df_dir, cleaned_df_filename)

        # Save the updated DataFrame as a CSV file
        cleaned_df.to_csv(cleaned_df_file_path, index=False)

        # Now, you can use the updated DataFrame for further processing if needed

        
        
        
        total_questions_count += questions_count
        total_truncated_questions_count += truncated_questions
        total_truncated_answers_count += truncated_answers
        
        
        print(f"File: {csv_file}\n")
        print(f"Total undesirable questions: {questions_count}")
        print(f"Total Truncated Questions: {truncated_questions}")
        print(f"Total Truncated Answers: {truncated_answers}")
       # print(f"Original typo/error found: {original_error_count}")
        print(f"excessive comma occurence: {total_comma_count}")
        #print(f"Corrected typo/error count: {corrected_errors}")

        
        print(f"(undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence): {questions_count + truncated_questions + truncated_answers +  total_comma_count}\n")

    print(f"Total Questions Count: {total_questions_count}")
    print(f"Total Truncated Questions Count: {total_truncated_questions_count}")
    print(f"Total Truncated Answers Count: {total_truncated_answers_count}")
    print(f"Total (Questions + Truncated Questions + Truncated Answers): {total_questions_count + total_truncated_questions_count + total_truncated_answers_count}")

    end_time = time.time()
    
    elapsed_time_seconds = end_time - start_time
    elapsed_time_minutes = elapsed_time_seconds / 60

    print(f"Script ran for {elapsed_time_minutes:.2f} minutes.")
    
    
    
if __name__ == "__main__":
    cProfile.run("main()", sort='cumulative')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1460 non-null   object
#  1   Question     1460 non-null   object
#  2   Answer       1458 non-null   object
#  3   topic_name   1460 non-null   object
#  4   topic_words  1460 non-null   object
#  5   Riya         1460 non-null   object
#  6
#             1 non-null      object
#  7   Lola         1458 non-null   object
#  8   Suman        1460 non-null   object
#  9   Narunja      1430 non-null   object
#  10  Simon        0 non-null      float64
#  11  Sapna        1460 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 137.0+ KB
# ['id', 'Question', 'Answer', 'topic_name', 'topic_words', 'Riya', '\n', 'Lola', 'Suman', 'Narunja', 'Simon', 'Sapna']
#
# nan
#
#
# nan
#
#
# nan
#
#
# nan
#
# Corresponding Question 84: What is the research topic of the paper by Lu et al 2017?
# Truncated Answer  84: nan
#
#
# nan
#
#
# nan
#
# Corresponding Question 173: Who conducted the Arctic freshwater fish productivity and colonization study?
# Truncated Answer  173: nan
#
# Number of rows in filtered data: 50
# Number of rows in remaining data: 1408
#
# Original text: The procedure for calculating the Hurst exponent involves dividing the time series {NDVI} = 1, 2,, n into sub-series Vt, and for each sub-series, t = 1,2,3,,.
# Corrected text: The procedure for calculating the Hurst exponent involves dividing the time series {NDVI} = 1, 2,  n into sub-series Vt, and for each sub-series, t = 1,2,3, .
# Total comma count: 0.0
# File: C:/Users/LolaPwasanga/Downloads/datarecords.csv
#
# Total undesirable questions: 51
# Total Truncated Questions: 0
# Total Truncated Answers: 2
# excessive comma occurence: 0.0
# (undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence): 53.0
#
# Total Questions Count: 51
# Total Truncated Questions Count: 0
# Total Truncated Answers Count: 2
# Total (Questions + Truncated Questions + Truncated Answers): 53
# Script ran for 12.63 minutes.
#          70653863 function calls (70620825 primitive calls) in 757.536 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  757.718  757.718 {built-in method builtins.exec}
#         1    0.001    0.001  757.718  757.718 <string>:1(<module>)
#         1    0.001    0.001  757.717  757.717 3699664769.py:208(main)
#         1    0.154    0.154  753.031  753.031 3699664769.py:173(LanguageTool_df)
#     14050    0.108    0.000  714.414    0.051 server.py:151(correct)
#     14050    0.488    0.000  713.790    0.051 server.py:126(check)
#     14051    0.162    0.000  700.490    0.050 server.py:213(_query_server)
#     14051    0.184    0.000  696.879    0.050 api.py:62(get)
#     14051    0.174    0.000  696.695    0.050 api.py:14(request)
#     14051    0.306    0.000  694.124    0.049 sessions.py:502(request)
#     14051    0.453    0.000  658.624    0.047 sessions.py:673(send)
#     14051    0.327    0.000  653.642    0.047 adapters.py:434(send)
#     14051    0.491    0.000  640.986    0.046 connectionpool.py:533(urlopen)
#     14051    0.610    0.000  630.522    0.045 connectionpool.py:378(_make_request)
#     14051    0.158    0.000  610.736    0.043 client.py:1334(getresponse)
#     14051    0.378    0.000  609.860    0.043 client.py:311(begin)
#     29889    0.176    0.000  606.044    0.020 socket.py:692(readinto)
#     29889  605.798    0.020  605.798    0.020 {method 'recv_into' of '_socket.socket' objects}
#     14051    0.395    0.000  605.338    0.043 client.py:278(_read_status)
#     70255    0.280    0.000  604.930    0.009 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000   36.223   36.223 server.py:44(__init__)
#         1    0.000    0.000   35.842   35.842 server.py:234(_start_server_on_free_port)
#         9    0.001    0.000   35.842    3.982 server.py:246(_start_local_server)
#        27   22.076    0.818   22.076    0.818 {method 'readline' of '_io.TextIOWrapper' objects}
#     14051    0.179    0.000   21.735    0.002 sessions.py:751(merge_environment_settings)
#     14051    0.063    0.000   21.047    0.001 utils.py:824(get_environ_proxies)
#     28102    3.716    0.000   18.566    0.001 request.py:2499(getproxies_environment)
#     14051    0.156    0.000   18.549    0.001 connection.py:231(request)
#     14051    0.058    0.000   18.055    0.001 client.py:1283(request)
#     14051    0.297    0.000   17.997    0.001 client.py:1288(_send_request)
#     14051    0.051    0.000   15.740    0.001 client.py:1270(endheaders)
#     14051    0.083    0.000   15.689    0.001 client.py:1032(_send_output)
#     14051    0.147    0.000   15.592    0.001 client.py:971(send)
#   3765668    3.662    0.000   15.182    0.000 <frozen _collections_abc>:859(__iter__)
#         9    0.051    0.006   13.348    1.483 download_lt.py:135(download_lt)
#     14051    0.291    0.000   13.332    0.001 sessions.py:459(prepare_request)
#         9    0.001    0.000   13.266    1.474 download_lt.py:68(confirm_java_compatibility)
#         9    0.001    0.000   13.232    1.470 subprocess.py:417(check_output)
#         9    0.000    0.000   13.231    1.470 subprocess.py:506(run)
#        17    0.000    0.000   12.937    0.761 subprocess.py:1165(communicate)
#         9   12.729    1.414   12.729    1.414 {method 'read' of '_io.TextIOWrapper' objects}
#     14051    0.159    0.000   11.375    0.001 utils.py:764(should_bypass_proxies)
#     14051    0.115    0.000   10.463    0.001 utils.py:112(proxy_bypass)
#     98355    7.945    0.000   10.206    0.000 url.py:210(_encode_invalid_chars)
#   3583234    4.359    0.000    9.886    0.000 <frozen os>:674(__getitem__)
#     14051    0.055    0.000    9.609    0.001 request.py:2716(getproxies)
#     42153    0.920    0.000    9.598    0.000 url.py:333(parse_url)
#     14051    0.097    0.000    9.081    0.001 adapters.py:331(get_connection)
#     14050    0.038    0.000    9.016    0.001 server.py:131(<listcomp>)
#     15795    0.274    0.000    8.978    0.001 match.py:47(__init__)
#    236929    6.711    0.000    8.256    0.000 {built-in method builtins.setattr}
#     14051    0.069    0.000    8.184    0.001 poolmanager.py:287(connection_from_url)
#     14051    0.061    0.000    8.120    0.001 connection.py:204(connect)
#     14051    0.098    0.000    7.982    0.001 connection.py:161(_new_conn)
#     14051    0.214    0.000    7.884    0.001 connection.py:37(create_connection)
#     14051    7.312    0.001    7.312    0.001 {method 'sendall' of '_socket.socket' objects}
#     14051    0.138    0.000    7.087    0.001 models.py:352(prepare)
#     14051    5.650    0.000    5.650    0.000 {method 'connect' of '_socket.socket' objects}
#   3583234    2.836    0.000    5.526    0.000 <frozen os>:748(encodekey)
#     14051    0.244    0.000    4.236    0.000 models.py:410(prepare_url)
#     14051    0.199    0.000    3.934    0.000 client.py:224(parse_headers)
#     14051    0.050    0.000    3.850    0.000 poolmanager.py:225(connection_from_host)
#     14051    0.334    0.000    3.805    0.000 utils.py:199(get_netrc_auth)
#     14051    0.086    0.000    3.773    0.000 poolmanager.py:248(connection_from_context)
#     42153    0.106    0.000    3.679    0.000 models.py:887(content)
#    112408    0.125    0.000    3.559    0.000 {method 'join' of 'bytes' objects}
#     29494    0.064    0.000    3.434    0.000 models.py:812(generate)
#     14051    0.171    0.000    3.426    0.000 parser.py:59(parsestr)
#     14051    0.079    0.000    3.379    0.000 models.py:944(json)
#     29494    0.062    0.000    3.363    0.000 response.py:607(stream)
#     14051    0.119    0.000    3.255    0.000 parser.py:41(parse)
#     15443    0.199    0.000    3.251    0.000 response.py:535(read)
#     14051    0.119    0.000    3.189    0.000 poolmanager.py:263(connection_from_pool_key)
#     14051    0.065    0.000    3.152    0.000 url.py:323(_encode_target)
#     14051    0.076    0.000    3.104    0.000 weakref.py:585(__call__)
#     14051    0.211    0.000    3.020    0.000 connectionpool.py:1124(_close_pool_connections)
#       5/3    0.000    0.000    2.895    0.965 _decorators.py:170(wrapper)
#     14051    0.158    0.000    2.879    0.000 poolmanager.py:189(_new_pool)
#     30004    2.711    0.000    2.711    0.000 {built-in method nt.stat}
#     28121    0.096    0.000    2.694    0.000 <frozen genericpath>:16(exists)
#     14051    0.369    0.000    2.691    0.000 connectionpool.py:176(__init__)
#        11    0.352    0.032    2.448    0.223 frame.py:609(__init__)
#     15443    0.043    0.000    2.277    0.000 response.py:487(_fp_read)
#     14051    0.040    0.000    2.255    0.000 feedparser.py:173(feed)
#     15443    0.195    0.000    2.234    0.000 client.py:450(read)
#     14051    0.164    0.000    2.186    0.000 adapters.py:294(build_response)
#     28102    0.077    0.000    2.124    0.000 feedparser.py:178(_call_parse)
#   3583234    1.654    0.000    2.062    0.000 <frozen os>:742(check_str)
#     28102    0.336    0.000    2.047    0.000 feedparser.py:218(_parsegen)
# 6980483/6980422    1.313    0.000    1.946    0.000 {built-in method builtins.isinstance}
#     14051    0.187    0.000    1.939    0.000 sessions.py:391(__init__)
#     98357    0.341    0.000    1.914    0.000 sessions.py:61(merge_setting)
#   3484648    1.853    0.000    1.853    0.000 <frozen os>:697(__iter__)
#     15443    0.419    0.000    1.813    0.000 {method 'read' of '_io.BufferedReader' objects}
#    168633    0.989    0.000    1.794    0.000 parse.py:374(urlparse)
#     14051    0.054    0.000    1.706    0.000 __init__.py:299(loads)
#       7/6    0.043    0.006    1.700    0.283 _decorators.py:323(wrapper)
#     98357    0.297    0.000    1.663    0.000 structures.py:40(__init__)
#     14051    0.174    0.000    1.651    0.000 models.py:106(_encode_params)
#     14051    0.084    0.000    1.632    0.000 decoder.py:332(decode)
#         1    0.010    0.010    1.623    1.623 readers.py:854(read_csv)
#     14051    1.580    0.000    1.594    0.000 models.py:906(text)
#     14051    0.081    0.000    1.587    0.000 client.py:957(close)
#    154561    0.707    0.000    1.575    0.000 queue.py:122(put)
#     14051    0.205    0.000    1.555    0.000 response.py:633(from_httplib)
#    236925    0.690    0.000    1.545    0.000 match.py:109(__setattr__)
#         1    0.066    0.066    1.541    1.541 readers.py:571(_read)
#    126459    0.594    0.000    1.463    0.000 <frozen _collections_abc>:941(update)
#     14051    1.461    0.000    1.461    0.000 decoder.py:343(raw_decode)
#     14051    0.041    0.000    1.395    0.000 socket.py:499(close)
#    168612    0.600    0.000    1.394    0.000 queue.py:154(get)
#     14051    0.028    0.000    1.354    0.000 socket.py:495(_real_close)
#     14051    1.326    0.000    1.326    0.000 {function socket.close at 0x000001A5492F2340}
#     14051    0.158    0.000    1.282    0.000 parse.py:937(urlencode)
#         2    0.000    0.000    1.242    0.621 generic.py:3536(to_csv)
#         2    0.000    0.000    1.242    0.621 format.py:1139(to_csv)
#         2    0.000    0.000    1.242    0.621 csvs.py:236(save)
#     28102    0.140    0.000    1.142    0.000 cookies.py:124(extract_cookies_to_jar)
#         1    0.013    0.013    1.135    1.135 readers.py:1762(read)
#     70255    0.190    0.000    1.130    0.000 connection.py:221(putheader)
#     56200    0.177    0.000    1.099    0.000 parse.py:895(quote_plus)
#     14051    0.213    0.000    1.060    0.000 models.py:484(prepare_headers)
#         2    0.000    0.000    1.036    0.518 csvs.py:263(_save)
#         2    0.000    0.000    1.036    0.518 csvs.py:296(_save_body)
#         2    0.000    0.000    1.036    0.518 csvs.py:306(_save_chunk)
#     70251    0.115    0.000    1.015    0.000 parse.py:841(quote)
#     28102    0.164    0.000    0.959    0.000 utils.py:836(select_proxy)
#     14051    0.045    0.000    0.957    0.000 models.py:611(prepare_cookies)
#         2    0.014    0.007    0.946    0.473 construction.py:423(dict_to_mgr)
#     42153    0.197    0.000    0.929    0.000 cookies.py:521(cookiejar_from_dict)
#     14051    0.141    0.000    0.929    0.000 utils.py:76(proxy_bypass_registry)
#     14051    0.915    0.000    0.915    0.000 socket.py:220(__init__)
#    155980    0.297    0.000    0.913    0.000 <frozen _collections_abc>:771(get)
#     14051    0.082    0.000    0.909    0.000 cookies.py:140(get_cookie_header)
#     98357    0.324    0.000    0.891    0.000 utils.py:340(to_key_val_list)
#         1    0.003    0.003    0.891    0.891 3699664769.py:96(count_truncated_questions_and_answers_in_df)
#     14051    0.066    0.000    0.890    0.000 adapters.py:370(request_url)
#     70251    0.262    0.000    0.880    0.000 parse.py:917(quote_from_bytes)
#     14060    0.277    0.000    0.865    0.000 parse.py:539(urljoin)
#     42153    0.129    0.000    0.860    0.000 cookies.py:35(__init__)
#    236925    0.855    0.000    0.855    0.000 match.py:5(get_match_ordered_dict)
#     28102    0.201    0.000    0.834    0.000 adapters.py:135(__init__)
# 1586/1584    0.011    0.000    0.793    0.001 series.py:342(__init__)
#     70255    0.468    0.000    0.783    0.000 client.py:1242(putheader)
#     14051    0.048    0.000    0.764    0.000 connectionpool.py:261(_get_conn)
#     56204    0.189    0.000    0.763    0.000 message.py:591(get_content_type)
#     14051    0.204    0.000    0.756    0.000 models.py:659(__init__)
#     14051    0.063    0.000    0.744    0.000 connection.py:208(putrequest)
#     14051    0.149    0.000    0.718    0.000 client.py:248(__init__)
#    112408    0.304    0.000    0.718    0.000 parse.py:164(hostname)
#    379400    0.710    0.000    0.710    0.000 {method 'match' of 're.Pattern' objects}
#   5262785    0.709    0.000    0.709    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.707    0.707 frame.py:3434(info)
#   3886964    0.686    0.000    0.686    0.000 {method 'upper' of 'str' objects}
#      1415    0.014    0.000    0.683    0.000 indexing.py:1059(__getitem__)
#    277298    0.619    0.000    0.682    0.000 parse.py:119(_coerce_args)
#         1    0.474    0.474    0.679    0.679 construction.py:496(nested_data_to_arrays)
#     14051    0.196    0.000    0.668    0.000 client.py:1086(putrequest)
#         1    0.000    0.000    0.665    0.665 info.py:509(render)
#         1    0.000    0.000    0.664    0.664 info.py:594(to_buffer)
#      1415    0.022    0.000    0.659    0.000 indexing.py:1592(_getitem_axis)
#   3692110    0.655    0.000    0.655    0.000 {method 'lower' of 'str' objects}
#     14051    0.089    0.000    0.643    0.000 socket.py:945(getaddrinfo)
#        48    0.001    0.000    0.640    0.013 managers.py:301(apply)
#         2    0.000    0.000    0.626    0.313 managers.py:497(to_native_types)
#         3    0.000    0.000    0.626    0.209 blocks.py:538(to_native_types)
#     98354    0.355    0.000    0.626    0.000 {method 'subn' of 're.Pattern' objects}
#         3    0.023    0.008    0.626    0.209 blocks.py:2282(to_native_types)
#     56204    0.244    0.000    0.623    0.000 cookiejar.py:1261(__init__)
#     42162    0.147    0.000    0.614    0.000 parse.py:509(urlunparse)
#    112408    0.310    0.000    0.613    0.000 message.py:489(get)
#    393509    0.218    0.000    0.612    0.000 <frozen abc>:117(__instancecheck__)
#        18    0.001    0.000    0.606    0.034 subprocess.py:807(__init__)
#     28102    0.071    0.000    0.599    0.000 structures.py:76(copy)
#     14051    0.135    0.000    0.599    0.000 queue.py:34(__init__)
#     14051    0.238    0.000    0.593    0.000 response.py:201(__init__)
#        18    0.001    0.000    0.589    0.033 subprocess.py:1436(_execute_child)
#        18    0.584    0.032    0.584    0.032 {built-in method _winapi.CreateProcess}
#    309122    0.257    0.000    0.582    0.000 threading.py:359(notify)
#     14051    0.431    0.000    0.569    0.000 socket.py:303(makefile)
#     28131    0.249    0.000    0.569    0.000 <frozen ntpath>:319(expanduser)
#     28102    0.559    0.000    0.559    0.000 {built-in method winreg.OpenKey}
#     14051    0.261    0.000    0.558    0.000 feedparser.py:471(_parse_headers)
#      1460    0.028    0.000    0.553    0.000 frame.py:3703(_ixs)
#     29516    0.090    0.000    0.551    0.000 contextlib.py:141(__exit__)
#     14051    0.121    0.000    0.544    0.000 connectionpool.py:240(_new_conn)
#     28102    0.139    0.000    0.541    0.000 cookiejar.py:1680(extract_cookies)
#     42153    0.056    0.000    0.540    0.000 message.py:615(get_content_maintype)
#         1    0.000    0.000    0.539    0.539 info.py:800(get_lines)
#         1    0.000    0.000    0.539    0.539 info.py:965(_fill_non_empty_info)
#     14051    0.055    0.000    0.526    0.000 feedparser.py:184(close)
#   5387918    0.525    0.000    0.525    0.000 {built-in method builtins.ord}
#        40    0.000    0.000    0.517    0.013 series.py:4661(apply)
#     14050    0.441    0.000    0.516    0.000 utils.py:52(correct)
#        40    0.001    0.000    0.516    0.013 apply.py:1108(apply)
# 590133/576082    0.397    0.000    0.515    0.000 {method 'encode' of 'str' objects}
#        40    0.001    0.000    0.515    0.013 apply.py:1159(apply_standard)
#     73084    0.075    0.000    0.512    0.000 {built-in method builtins.next}
#     42153    0.511    0.000    0.511    0.000 {built-in method winreg.QueryValueEx}
#        42    0.037    0.001    0.494    0.012 {pandas._libs.lib.map_infer}
#     14051    0.430    0.000    0.488    0.000 poolmanager.py:79(_default_key_normalizer)
#         1    0.000    0.000    0.465    0.465 series.py:486(_init_dict)
#     14051    0.122    0.000    0.464    0.000 _collections.py:141(__init__)
#     14051    0.039    0.000    0.462    0.000 utils.py:659(requote_uri)
#         1    0.000    0.000    0.460    0.460 3699664769.py:203(add_full_stops)
#     14051    0.021    0.000    0.456    0.000 sessions.py:456(__exit__)
#     14051    0.064    0.000    0.435    0.000 sessions.py:796(close)
#     15795    0.429    0.000    0.429    0.000 match.py:57(<listcomp>)
#    323173    0.359    0.000    0.428    0.000 structures.py:46(__setitem__)
#     30886    0.041    0.000    0.424    0.000 response.py:431(_error_catcher)
#     14051    0.084    0.000    0.408    0.000 request.py:2667(getproxies_registry)
#         2    0.406    0.203    0.406    0.203 {pandas._libs.writers.write_csv_rows}
#      1409    0.083    0.000    0.403    0.000 managers.py:1078(fast_xs)
#     14051    0.166    0.000    0.398    0.000 cookiejar.py:1356(add_cookie_header)
#     14051    0.068    0.000    0.398    0.000 utils.py:898(default_headers)
#    393509    0.394    0.000    0.394    0.000 {built-in method _abc._abc_instancecheck}
#      4068    0.280    0.000    0.392    0.000 parse.py:935(<listcomp>)
#     10281    0.205    0.000    0.390    0.000 parse.py:452(urlsplit)
#     28102    0.051    0.000    0.385    0.000 response.py:281(release_conn)
#     56204    0.089    0.000    0.385    0.000 utils.py:1032(check_header_validity)
#     14051    0.305    0.000    0.381    0.000 {built-in method _socket.getaddrinfo}
#         1    0.000    0.000    0.380    0.380 server.py:193(_get_languages)
#        29    0.375    0.013    0.375    0.013 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.373    0.187 info.py:463(dtype_counts)
#         2    0.000    0.000    0.373    0.187 info.py:1111(_get_dataframe_dtype_counts)
#     56204    0.170    0.000    0.372    0.000 timeout.py:101(__init__)
#         1    0.000    0.000    0.371    0.371 info.py:779(add_dtypes_line)
#         1    0.000    0.000    0.371    0.371 info.py:752(dtype_counts)
#     28102    0.073    0.000    0.366    0.000 adapters.py:360(close)
#     14051    0.119    0.000    0.365    0.000 connection.py:115(__init__)
#     28102    0.096    0.000    0.362    0.000 adapters.py:173(init_poolmanager)
#     70275    0.108    0.000    0.362    0.000 <frozen _collections_abc>:778(__contains__)
#    112408    0.261    0.000    0.359    0.000 parse.py:205(_hostinfo)
#     42170    0.353    0.000    0.353    0.000 threading.py:236(__init__)
#     42153    0.227    0.000    0.350    0.000 url.py:244(_remove_path_dot_segments)
#     28102    0.140    0.000    0.349    0.000 cookiejar.py:1599(make_cookies)
#     14051    0.031    0.000    0.343    0.000 models.py:589(prepare_auth)
#    112408    0.072    0.000    0.342    0.000 _policybase.py:311(header_fetch_parse)
#         1    0.036    0.036    0.338    0.338 readers.py:1395(__init__)
#     14051    0.170    0.000    0.336    0.000 feedparser.py:139(__init__)
#     14051    0.048    0.000    0.334    0.000 connectionpool.py:300(_put_conn)
#         3    0.000    0.000    0.330    0.110 construction.py:100(arrays_to_mgr)
#         3    0.000    0.000    0.327    0.109 managers.py:2182(create_block_manager_from_column_arrays)
#    309139    0.198    0.000    0.326    0.000 threading.py:279(_is_owned)
#         1    0.000    0.000    0.322    0.322 3699664769.py:27(comma_cluster_removal_df)
#         1    0.000    0.000    0.320    0.320 construction.py:881(create_series_with_explicit_dtype)
#     84306    0.316    0.000    0.316    0.000 threading.py:90(RLock)
#    323190    0.198    0.000    0.309    0.000 threading.py:264(__enter__)
#     14051    0.126    0.000    0.308    0.000 _collections.py:231(extend)
#     14051    0.085    0.000    0.304    0.000 utils.py:1016(get_auth_from_url)
#     42162    0.172    0.000    0.303    0.000 parse.py:520(urlunsplit)
#    252918    0.250    0.000    0.302    0.000 structures.py:51(__getitem__)
# 1160122/1141223    0.273    0.000    0.298    0.000 {built-in method builtins.len}
#         2    0.065    0.032    0.297    0.149 groupby.py:2435(sum)
#    112408    0.152    0.000    0.296    0.000 utils.py:1043(_validate_header_part)
#    224811    0.223    0.000    0.295    0.000 six.py:1014(ensure_text)
#     14051    0.235    0.000    0.293    0.000 utils.py:635(unquote_unreserved)
#    309210    0.290    0.000    0.290    0.000 {method 'acquire' of '_thread.lock' objects}
#     90077    0.097    0.000    0.290    0.000 {built-in method builtins.any}
#     28102    0.046    0.000    0.286    0.000 poolmanager.py:216(clear)
#     28102    0.042    0.000    0.282    0.000 connectionpool.py:341(_get_timeout)
#     14051    0.078    0.000    0.275    0.000 models.py:85(path_url)
#     14051    0.094    0.000    0.273    0.000 response.py:40(assert_header_parsing)
#    219417    0.174    0.000    0.271    0.000 url.py:223(<lambda>)
#        81    0.001    0.000    0.271    0.003 series.py:565(_set_axis)
#    112408    0.136    0.000    0.270    0.000 _policybase.py:281(_sanitize_header)
#     14051    0.022    0.000    0.270    0.000 sessions.py:725(<listcomp>)
#        12    0.081    0.007    0.269    0.022 base.py:2752(_is_all_dates)
#    168713    0.268    0.000    0.268    0.000 {method 'search' of 're.Pattern' objects}
#     28102    0.127    0.000    0.266    0.000 poolmanager.py:171(__init__)
#        45    0.001    0.000    0.264    0.006 frame.py:3758(__getitem__)
#    323190    0.211    0.000    0.262    0.000 threading.py:267(__exit__)
#     14051    0.160    0.000    0.261    0.000 client.py:206(_read_headers)
#     14051    0.120    0.000    0.259    0.000 feedparser.py:101(push)
#         1    0.187    0.187    0.258    0.258 base.py:2381(is_unique)
#     56204    0.145    0.000    0.257    0.000 url.py:274(_normalize_host)
#     84306    0.111    0.000    0.251    0.000 feedparser.py:128(__next__)
#    252918    0.108    0.000    0.251    0.000 url.py:416(ensure_type)
#     42153    0.154    0.000    0.250    0.000 url.py:91(__new__)
#     14051    0.040    0.000    0.248    0.000 sessions.py:159(resolve_redirects)
#     42153    0.061    0.000    0.245    0.000 sessions.py:84(<listcomp>)
#       145    0.000    0.000    0.242    0.002 base.py:7277(ensure_index)
#     28102    0.160    0.000    0.240    0.000 _collections.py:92(clear)
#     14051    0.044    0.000    0.240    0.000 utils.py:772(get_proxy)
#     20/17    0.000    0.000    0.237    0.014 missing.py:108(isna)
#     20/17    0.000    0.000    0.237    0.014 missing.py:191(_isna)
#        16    0.001    0.000    0.235    0.015 missing.py:268(_isna_array)
#         8    0.000    0.000    0.235    0.029 missing.py:309(_isna_string_dtype)
#         4    0.235    0.059    0.235    0.059 {pandas._libs.missing.isnaobj2d}
#     28102    0.058    0.000    0.235    0.000 timeout.py:184(clone)
#     28102    0.195    0.000    0.233    0.000 retry.py:243(__init__)
#     14051    0.151    0.000    0.230    0.000 client.py:838(__init__)
#    112408    0.168    0.000    0.229    0.000 <frozen _collections_abc>:790(items)
#    323173    0.163    0.000    0.228    0.000 queue.py:15(_qsize)
#     28102    0.083    0.000    0.227    0.000 cookies.py:542(merge_cookies)
#    323208    0.226    0.000    0.226    0.000 {method 'startswith' of 'str' objects}
#     14051    0.024    0.000    0.220    0.000 client.py:412(_close_conn)
#     42153    0.144    0.000    0.212    0.000 _policybase.py:293(header_source_parse)
#        11    0.004    0.000    0.207    0.019 base.py:708(_with_infer)
#     29516    0.082    0.000    0.207    0.000 contextlib.py:287(helper)
#     14051    0.016    0.000    0.206    0.000 parse.py:338(geturl)
#     14051    0.121    0.000    0.206    0.000 response.py:323(_init_length)
#         1    0.201    0.201    0.205    0.205 construction.py:790(to_arrays)
#         3    0.000    0.000    0.205    0.068 common.py:645(get_handle)
#        25    0.000    0.000    0.204    0.008 frame.py:3955(__setitem__)
#     99749    0.174    0.000    0.204    0.000 _collections.py:156(__getitem__)
#         1    0.000    0.000    0.204    0.204 generic.py:11598(any)
#         1    0.005    0.005    0.204    0.204 generic.py:11166(any)
#        39    0.204    0.005    0.204    0.005 {built-in method io.open}
#      1409    0.004    0.000    0.204    0.000 base.py:210(interleaved_dtype)
#        25    0.000    0.000    0.204    0.008 frame.py:4164(_set_item)
#    168612    0.184    0.000    0.202    0.000 timeout.py:122(_validate_timeout)
#        25    0.000    0.000    0.200    0.008 frame.py:4139(_set_item_mgr)
#      1409    0.027    0.000    0.200    0.000 cast.py:1589(find_common_type)
#         1    0.080    0.080    0.199    0.199 generic.py:11108(_logical_func)
#        25    0.000    0.000    0.199    0.008 frame.py:4132(_iset_item_mgr)
#     28103    0.151    0.000    0.198    0.000 idna.py:145(encode)
#        25    0.137    0.005    0.198    0.008 managers.py:1183(iset)
#     14051    0.063    0.000    0.196    0.000 {method 'close' of '_io.BufferedReader' objects}
#     28100    0.027    0.000    0.189    0.000 __init__.py:178(sub)
#        10    0.188    0.019    0.188    0.019 {built-in method pandas._libs.lib.is_datetime_array}
#    379377    0.186    0.000    0.186    0.000 structures.py:58(<genexpr>)
#     56204    0.149    0.000    0.185    0.000 message.py:524(get_all)
#     14051    0.035    0.000    0.184    0.000 message.py:478(items)
#         1    0.075    0.075    0.182    0.182 readers.py:1703(_make_engine)
#         8    0.000    0.000    0.178    0.022 server.py:306(_terminate_server)
#         1    0.000    0.000    0.178    0.178 c_parser_wrapper.py:218(read)
#         8    0.000    0.000    0.177    0.022 subprocess.py:1601(_communicate)
#        17    0.000    0.000    0.176    0.010 threading.py:938(start)
#     14051    0.035    0.000    0.173    0.000 connection.py:100(_set_socket_options)
#     14050    0.135    0.000    0.170    0.000 server.py:133(_create_params)
#         3    0.169    0.056    0.170    0.057 managers.py:2253(_form_blocks)
#     28102    0.059    0.000    0.168    0.000 socket.py:99(_intenum_converter)
#         1    0.000    0.000    0.168    0.168 info.py:833(add_memory_usage_line)
#         1    0.000    0.000    0.168    0.168 info.py:762(memory_usage_string)
#         1    0.000    0.000    0.168    0.168 info.py:418(memory_usage_string)
#     14051    0.051    0.000    0.166    0.000 connectionpool.py:82(__init__)
#         2    0.000    0.000    0.166    0.083 groupby.py:1699(_agg_general)
#         2    0.000    0.000    0.166    0.083 groupby.py:1759(_cython_agg_general)
#         2    0.000    0.000    0.165    0.083 base.py:192(grouped_reduce)
#         2    0.000    0.000    0.165    0.083 groupby.py:1789(array_func)
#         2    0.000    0.000    0.165    0.083 ops.py:1020(_cython_operation)
#    235356    0.164    0.000    0.164    0.000 {method 'split' of 'str' objects}
#        17    0.000    0.000    0.162    0.010 threading.py:604(wait)
#        17    0.000    0.000    0.162    0.010 threading.py:288(wait)
#     84306    0.144    0.000    0.161    0.000 cookiejar.py:1227(deepvalues)
#         1    0.160    0.160    0.160    0.160 inference.py:394(is_dataclass)
#         5    0.018    0.004    0.158    0.032 managers.py:1864(_consolidate_inplace)
#    379802    0.158    0.000    0.158    0.000 {built-in method builtins.hasattr}
#         1    0.147    0.147    0.156    0.156 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#     14051    0.032    0.000    0.155    0.000 models.py:631(prepare_hooks)
#         1    0.000    0.000    0.155    0.155 3699664769.py:193(add_space_before_opening_bracket)
#     14051    0.046    0.000    0.150    0.000 message.py:486(<listcomp>)
#     14051    0.073    0.000    0.149    0.000 utils.py:538(get_encoding_from_headers)
#    154561    0.118    0.000    0.148    0.000 queue.py:18(_put)
#     84306    0.129    0.000    0.146    0.000 structures.py:57(__iter__)
#         2    0.001    0.000    0.144    0.072 series.py:5077(reindex)
#         2    0.021    0.010    0.143    0.072 generic.py:5044(reindex)
#    235156    0.141    0.000    0.141    0.000 {built-in method __new__ of type object at 0x00007FFA80FDA4B0}
#         3    0.000    0.000    0.140    0.047 managers.py:2319(_consolidate)
#     84306    0.130    0.000    0.140    0.000 feedparser.py:78(readline)
#         6    0.139    0.023    0.140    0.023 managers.py:2361(_merge_blocks)
#     14051    0.138    0.000    0.138    0.000 {method 'setsockopt' of '_socket.socket' objects}
#     16896    0.029    0.000    0.138    0.000 3699664769.py:9(count_multiple_commas)
#     56204    0.104    0.000    0.137    0.000 message.py:29(_splitparam)
#     14051    0.065    0.000    0.137    0.000 models.py:495(prepare_body)
#     42153    0.038    0.000    0.136    0.000 cookies.py:534(<listcomp>)
#     14051    0.067    0.000    0.136    0.000 message.py:243(get_payload)
#     14051    0.049    0.000    0.135    0.000 timeout.py:168(from_float)
#     16896    0.018    0.000    0.135    0.000 3699664769.py:197(<lambda>)
#     16896    0.029    0.000    0.133    0.000 3699664769.py:16(replace_multiple_commas)
#    154561    0.107    0.000    0.132    0.000 queue.py:21(_get)
#     14051    0.086    0.000    0.132    0.000 socket.py:769(close)
#     28102    0.065    0.000    0.131    0.000 __init__.py:1467(debug)
#     28102    0.067    0.000    0.130    0.000 sessions.py:801(mount)
#         1    0.000    0.000    0.125    0.125 info.py:667(_create_table_builder)
#         1    0.000    0.000    0.125    0.125 info.py:954(__init__)
#    126459    0.083    0.000    0.125    0.000 utils.py:51(_has_surrogates)
#     29516    0.099    0.000    0.125    0.000 contextlib.py:104(__init__)
#        13    0.000    0.000    0.125    0.010 info.py:995(_gen_rows_with_counts)
#    208083    0.124    0.000    0.124    0.000 {built-in method builtins.getattr}
#        13    0.000    0.000    0.123    0.009 info.py:938(_gen_non_null_counts)
#         1    0.000    0.000    0.123    0.123 info.py:767(non_null_counts)
#         1    0.000    0.000    0.123    0.123 info.py:496(non_null_counts)
#         1    0.000    0.000    0.123    0.123 frame.py:10623(count)
#     14051    0.049    0.000    0.123    0.000 models.py:207(register_hook)
#        17    0.011    0.001    0.122    0.007 series.py:4773(_reduce)
#    228929    0.122    0.000    0.122    0.000 {method 'join' of 'str' objects}
#     70270    0.093    0.000    0.121    0.000 __init__.py:272(_compile)
#         1    0.000    0.000    0.120    0.120 readers.py:1527(_clean_options)
#     19/13    0.098    0.005    0.120    0.009 base.py:430(__new__)
#         1    0.119    0.119    0.119    0.119 common.py:183(validate_header_arg)
#     56204    0.119    0.000    0.119    0.000 cookiejar.py:884(__init__)
#     98354    0.118    0.000    0.118    0.000 {method 'decode' of 'bytearray' objects}
#     14051    0.108    0.000    0.118    0.000 weakref.py:568(__init__)
#     14051    0.074    0.000    0.114    0.000 sessions.py:782(get_adapter)
# 18581/18579    0.014    0.000    0.113    0.000 {built-in method builtins.all}
#     28102    0.056    0.000    0.112    0.000 _collections.py:47(__init__)
#     14051    0.029    0.000    0.112    0.000 connectionpool.py:1106(_normalize_host)
#   1022292    0.112    0.000    0.112    0.000 {method '__getitem__' of 'dict' objects}
#     42153    0.070    0.000    0.112    0.000 _collections.py:215(add)
#    323190    0.111    0.000    0.111    0.000 {method '__enter__' of '_thread.lock' objects}
#     28100    0.095    0.000    0.111    0.000 {method 'sub' of 're.Pattern' objects}
#     14051    0.052    0.000    0.111    0.000 client.py:417(close)
#     14051    0.027    0.000    0.110    0.000 sessions.py:107(get_redirect_target)
#    393428    0.110    0.000    0.110    0.000 {method 'partition' of 'str' objects}
#     28102    0.066    0.000    0.110    0.000 enum.py:685(__call__)
#     28102    0.108    0.000    0.108    0.000 {method 'settimeout' of '_socket.socket' objects}
#     28102    0.053    0.000    0.108    0.000 cookies.py:358(update)
#      1408    0.008    0.000    0.107    0.000 numerictypes.py:597(find_common_type)
#         1    0.000    0.000    0.106    0.106 info.py:501(memory_usage_bytes)
#         1    0.000    0.000    0.106    0.106 frame.py:3464(memory_usage)
#         1    0.076    0.076    0.106    0.106 c_parser_wrapper.py:49(__init__)
#     14051    0.079    0.000    0.105    0.000 models.py:258(__init__)
#     14051    0.105    0.000    0.105    0.000 feedparser.py:53(__init__)
#    542309    0.104    0.000    0.104    0.000 {method 'append' of 'list' objects}
#     42153    0.069    0.000    0.102    0.000 hooks.py:15(default_hooks)
#         9    0.000    0.000    0.102    0.011 utils.py:95(get_server_cmd)
#         9    0.000    0.000    0.101    0.011 utils.py:109(get_jar_info)
#     14051    0.035    0.000    0.101    0.000 retry.py:468(is_retry)
#     14051    0.098    0.000    0.098    0.000 socket.py:680(__init__)
#     15443    0.046    0.000    0.098    0.000 response.py:375(_init_decoder)
#     14051    0.051    0.000    0.098    0.000 cookiejar.py:1734(clear_expired_cookies)
#     70255    0.058    0.000    0.098    0.000 client.py:1290(<genexpr>)
#      2816    0.066    0.000    0.094    0.000 numerictypes.py:573(_can_coerce_all)
#         2    0.000    0.000    0.094    0.047 ops.py:668(cython_operation)
#         2    0.000    0.000    0.094    0.047 ops.py:493(_cython_op_ndim_compat)
#         2    0.094    0.047    0.094    0.047 ops.py:537(_call_cython_op)
#         9    0.000    0.000    0.093    0.010 which.py:13(which)
#     14051    0.052    0.000    0.092    0.000 feedparser.py:70(close)
#         1    0.000    0.000    0.091    0.091 parse.py:913(_byte_quoter_factory)
#         1    0.073    0.073    0.091    0.091 parse.py:828(__init__)
#    140510    0.078    0.000    0.089    0.000 connection.py:223(<genexpr>)
#      2918    0.004    0.000    0.089    0.000 3699664769.py:38(is_undesirable_question_to_count)
#      1809    0.003    0.000    0.088    0.000 <frozen genericpath>:27(isfile)
#     70255    0.088    0.000    0.088    0.000 {method 'fullmatch' of 're.Pattern' objects}
#        41    0.000    0.000    0.087    0.002 generic.py:6076(astype)
#     14051    0.071    0.000    0.086    0.000 _collections.py:61(__setitem__)
#     29516    0.043    0.000    0.085    0.000 contextlib.py:132(__enter__)
#     28102    0.084    0.000    0.084    0.000 message.py:150(__init__)
#     14051    0.025    0.000    0.083    0.000 models.py:770(is_redirect)
#     10276    0.049    0.000    0.083    0.000 parse.py:413(_splitnetloc)
#     98354    0.081    0.000    0.081    0.000 {method 'count' of 'bytes' objects}
#         4    0.000    0.000    0.080    0.020 generic.py:5277(<genexpr>)
#         2    0.059    0.029    0.080    0.040 base.py:5551(identical)
#     14051    0.053    0.000    0.080    0.000 feedparser.py:197(_new_message)
#       171    0.001    0.000    0.080    0.000 common.py:1433(is_extension_array_dtype)
#     14050    0.013    0.000    0.079    0.000 __init__.py:208(findall)
#        93    0.002    0.000    0.079    0.001 base.py:494(find)
#     14051    0.042    0.000    0.077    0.000 connection.py:196(_prepare_conn)
#     84306    0.061    0.000    0.076    0.000 client.py:1011(_output)
#     28102    0.045    0.000    0.076    0.000 {function SocketIO.close at 0x000001A5492F2F20}
#     28102    0.074    0.000    0.074    0.000 {method 'readlines' of '_io._IOBase' objects}
#     14051    0.038    0.000    0.074    0.000 models.py:335(__init__)
#    323226    0.072    0.000    0.072    0.000 {method 'pop' of 'dict' objects}
#         2    0.070    0.035    0.071    0.035 base.py:881(_engine)
#         2    0.000    0.000    0.071    0.035 ops.py:936(has_dropped_na)
#         2    0.000    0.000    0.071    0.035 ops.py:944(group_info)
#         2    0.000    0.000    0.071    0.035 ops.py:966(_get_compressed_codes)
#     84306    0.070    0.000    0.070    0.000 cookiejar.py:1753(__iter__)
#         2    0.000    0.000    0.070    0.035 grouper.py:615(codes)
#         2    0.000    0.000    0.070    0.035 grouper.py:658(_codes_and_uniques)
#         2    0.001    0.000    0.070    0.035 algorithms.py:593(factorize)
#     97207    0.052    0.000    0.069    0.000 3699664769.py:77(<genexpr>)
#     14051    0.051    0.000    0.069    0.000 _collections.py:54(__getitem__)
#         2    0.068    0.034    0.068    0.034 dtypes.py:1185(construct_from_string)
#         2    0.024    0.012    0.067    0.034 algorithms.py:1795(safe_sort)
#     14051    0.022    0.000    0.067    0.000 models.py:709(__exit__)
#         2    0.067    0.033    0.067    0.033 numba_.py:18(maybe_use_numba)
#     14103    0.066    0.000    0.066    0.000 {built-in method _thread.allocate_lock}
#         6    0.066    0.011    0.066    0.011 cast.py:1763(construct_1d_object_array_from_listlike)
#     28102    0.066    0.000    0.066    0.000 __init__.py:1734(isEnabledFor)
#       135    0.003    0.000    0.066    0.000 which.py:36(find_exe)
#     14051    0.061    0.000    0.065    0.000 retry.py:448(_is_method_retryable)
#     14051    0.041    0.000    0.064    0.000 cookiejar.py:1297(_cookie_attrs)
#    219453    0.064    0.000    0.064    0.000 {method 'group' of 're.Match' objects}
#     28102    0.049    0.000    0.063    0.000 sessions.py:807(<listcomp>)
#     70255    0.054    0.000    0.063    0.000 _internal_utils.py:25(to_native_string)
#     56204    0.056    0.000    0.062    0.000 _collections.py:187(__iter__)
#     14051    0.036    0.000    0.062    0.000 models.py:394(prepare_method)
#     97313    0.062    0.000    0.062    0.000 {method 'find' of 'str' objects}
#     70251    0.061    0.000    0.061    0.000 {method 'rstrip' of 'bytes' objects}
#     14051    0.021    0.000    0.061    0.000 client.py:383(_check_close)
#     43940    0.061    0.000    0.061    0.000 socket.py:731(readable)
#      1656    0.002    0.000    0.061    0.000 which.py:27(is_exe)
#    112408    0.060    0.000    0.060    0.000 <frozen _collections_abc>:812(__init__)
#     14051    0.054    0.000    0.059    0.000 parse.py:659(unquote)
#         1    0.059    0.059    0.059    0.059 info.py:327(_sizeof_fmt)
#         1    0.058    0.058    0.058    0.058 readers.py:1954(_refine_defaults_read)
#         1    0.000    0.000    0.058    0.058 frame.py:3554(<listcomp>)
#    254674    0.058    0.000    0.058    0.000 {method 'items' of 'dict' objects}
#        12    0.000    0.000    0.056    0.005 series.py:5436(memory_usage)
#        12    0.000    0.000    0.056    0.005 base.py:1102(_memory_usage)
#        24    0.000    0.000    0.056    0.002 series.py:743(array)
#        76    0.055    0.001    0.056    0.001 _ufunc_config.py:430(__enter__)
#        24    0.000    0.000    0.056    0.002 managers.py:2073(array_values)
#        24    0.055    0.002    0.056    0.002 blocks.py:1908(array_values)
#     14051    0.024    0.000    0.056    0.000 parse.py:156(username)
#        83    0.001    0.000    0.055    0.001 construction.py:493(sanitize_array)
#     28102    0.035    0.000    0.055    0.000 connection.py:242(<genexpr>)
#     28102    0.041    0.000    0.054    0.000 six.py:642(itervalues)
#     29889    0.033    0.000    0.053    0.000 {method '_checkReadable' of '_io._IOBase' objects}
#         1    0.001    0.001    0.053    0.053 nanops.py:496(nanany)
#     14051    0.014    0.000    0.052    0.000 <frozen _collections_abc>:815(__len__)
#        82    0.000    0.000    0.052    0.001 construction.py:744(_try_cast)
#     28111    0.015    0.000    0.051    0.000 __init__.py:225(compile)
#    323190    0.051    0.000    0.051    0.000 {method '__exit__' of '_thread.lock' objects}
#    154561    0.050    0.000    0.050    0.000 {method 'rpartition' of 'str' objects}
#     14051    0.036    0.000    0.050    0.000 adapters.py:237(cert_verify)
#    277298    0.049    0.000    0.049    0.000 parse.py:108(_noop)
#   166/160    0.011    0.000    0.049    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     29494    0.027    0.000    0.049    0.000 response.py:9(is_fp_closed)
#     84136    0.048    0.000    0.048    0.000 {method 'replace' of 'str' objects}
#     28102    0.036    0.000    0.048    0.000 feedparser.py:122(pushlines)
#     14051    0.046    0.000    0.048    0.000 models.py:795(iter_content)
#     56204    0.047    0.000    0.047    0.000 {method 'acquire' of '_thread.RLock' objects}
#     84306    0.047    0.000    0.047    0.000 {method 'groups' of 're.Match' objects}
#     14051    0.046    0.000    0.046    0.000 queue.py:12(_init)
#         1    0.002    0.002    0.046    0.046 3699664769.py:132(<listcomp>)
#         1    0.000    0.000    0.046    0.046 series.py:3142(_append)
#     14051    0.030    0.000    0.045    0.000 models.py:1023(close)
#     42153    0.037    0.000    0.045    0.000 message.py:506(set_raw)
#      3055    0.013    0.000    0.045    0.000 generic.py:5904(__setattr__)
#        11    0.000    0.000    0.044    0.004 warnings.py:130(filterwarnings)
#        23    0.000    0.000    0.044    0.002 warnings.py:181(_add_filter)
#        23    0.044    0.002    0.044    0.002 {method 'remove' of 'list' objects}
#     28102    0.044    0.000    0.044    0.000 enum.py:1091(__new__)
#    140764    0.043    0.000    0.043    0.000 {method 'get' of 'dict' objects}
#    168612    0.042    0.000    0.042    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         1    0.041    0.041    0.041    0.041 info.py:455(__init__)
#     14051    0.032    0.000    0.041    0.000 utils.py:513(_parse_content_type_header)
#      1519    0.016    0.000    0.041    0.000 blocks.py:2172(new_block)
#        13    0.041    0.003    0.041    0.003 {method 'take' of 'numpy.ndarray' objects}
#     14051    0.022    0.000    0.041    0.000 client.py:1234(_validate_host)
#     14051    0.040    0.000    0.040    0.000 {method 'Close' of 'PyHKEY' objects}
#        23    0.040    0.002    0.040    0.002 warnings.py:466(__enter__)
#         2    0.001    0.000    0.039    0.019 series.py:1963(groupby)
#     14051    0.027    0.000    0.038    0.000 response.py:699(closed)
#     28102    0.038    0.000    0.038    0.000 adapters.py:73(__init__)
#         2    0.001    0.000    0.038    0.019 groupby.py:922(__init__)
#         2    0.001    0.000    0.038    0.019 grouper.py:702(get_grouper)
#     28102    0.031    0.000    0.038    0.000 retry.py:301(<listcomp>)
#        11    0.001    0.000    0.037    0.003 blocks.py:1920(delete)
#         2    0.000    0.000    0.037    0.018 base.py:894(value_counts)
#     66487    0.037    0.000    0.037    0.000 {method 'lstrip' of 'str' objects}
#         3    0.036    0.012    0.036    0.012 {pandas._libs.lib.is_all_arraylike}
#         2    0.000    0.000    0.036    0.018 algorithms.py:920(value_counts)
#      2984    0.036    0.000    0.036    0.000 {pandas._libs.lib.is_scalar}
#        22    0.000    0.000    0.036    0.002 <__array_function__ internals>:177(delete)
#         2    0.000    0.000    0.036    0.018 grouper.py:840(is_in_axis)
#        22    0.035    0.002    0.036    0.002 function_base.py:5054(delete)
#         2    0.000    0.000    0.036    0.018 grouper.py:927(_is_label_like)
#     14051    0.024    0.000    0.035    0.000 _internal_utils.py:38(unicode_is_ascii)
#         2    0.027    0.013    0.035    0.018 missing.py:357(notna)
#     14051    0.025    0.000    0.035    0.000 connection.py:192(_is_using_tunnel)
#     42153    0.034    0.000    0.034    0.000 {method 'setdefault' of 'collections.OrderedDict' objects}
#     28102    0.024    0.000    0.034    0.000 connection.py:132(host)
#     14050    0.034    0.000    0.034    0.000 {method 'findall' of 're.Pattern' objects}
#     28102    0.022    0.000    0.034    0.000 message.py:211(is_multipart)
#      1415    0.008    0.000    0.034    0.000 common.py:96(is_bool_indexer)
#     56206    0.033    0.000    0.033    0.000 {built-in method time.time}
#         2    0.033    0.017    0.033    0.017 algorithms.py:1010(value_counts_arraylike)
#     58988    0.033    0.000    0.033    0.000 client.py:440(isclosed)
#     56233    0.033    0.000    0.033    0.000 {method 'endswith' of 'str' objects}
#         2    0.033    0.016    0.033    0.016 missing.py:910(clean_reindex_fill_method)
#         9    0.001    0.000    0.033    0.004 spawn.py:75(find_executable)
#     42153    0.033    0.000    0.033    0.000 hooks.py:16(<dictcomp>)
#      2930    0.010    0.000    0.032    0.000 series.py:966(__getitem__)
#     14051    0.027    0.000    0.032    0.000 hooks.py:22(dispatch_hook)
#         1    0.006    0.006    0.032    0.032 concat.py:146(concat)
#     42153    0.032    0.000    0.032    0.000 utils.py:206(<genexpr>)
#     14051    0.014    0.000    0.032    0.000 client.py:1226(_validate_path)
#     14051    0.026    0.000    0.032    0.000 parse.py:193(_userinfo)
#    110104    0.031    0.000    0.031    0.000 {method 'strip' of 'str' objects}
#     56204    0.031    0.000    0.031    0.000 {method 'count' of 'str' objects}
#     14051    0.023    0.000    0.031    0.000 feedparser.py:210(_pop_message)
#     28321    0.027    0.000    0.031    0.000 {method 'extend' of 'list' objects}
#        26    0.000    0.000    0.031    0.001 subprocess.py:1259(wait)
#        26    0.021    0.001    0.031    0.001 subprocess.py:1580(_wait)
#     14051    0.027    0.000    0.031    0.000 client.py:429(flush)
#         1    0.001    0.001    0.031    0.031 generic.py:5996(_is_mixed_type)
#     28158    0.023    0.000    0.030    0.000 <frozen ntpath>:35(_get_bothseps)
#    154636    0.030    0.000    0.030    0.000 {method 'append' of 'collections.deque' objects}
#      1409    0.006    0.000    0.029    0.000 indexing.py:1539(_validate_integer)
#         1    0.000    0.000    0.029    0.029 base_parser.py:88(__init__)
#         1    0.000    0.000    0.029    0.029 base.py:1005(nunique)
#     14051    0.019    0.000    0.029    0.000 timeout.py:198(start_connect)
#     14051    0.028    0.000    0.028    0.000 socket.py:489(_decref_socketios)
#         1    0.028    0.028    0.028    0.028 base_parser.py:1056(_make_date_converter)
#     14051    0.020    0.000    0.028    0.000 message.py:330(set_payload)
#      4224    0.004    0.000    0.028    0.000 cast.py:1635(<genexpr>)
#        18    0.000    0.000    0.028    0.002 utils.py:69(get_language_tool_download_path)
#        72    0.000    0.000    0.028    0.000 <frozen genericpath>:39(isdir)
#     14051    0.023    0.000    0.027    0.000 sessions.py:91(merge_hooks)
#        13    0.013    0.001    0.027    0.002 {method 'any' of 'numpy.ndarray' objects}
#     14051    0.022    0.000    0.027    0.000 cookiejar.py:1290(_cookies_for_request)
#     14051    0.020    0.000    0.027    0.000 poolmanager.py:303(_merge_pool_kwargs)
# ...
#         3    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#        31    0.000    0.000    0.000    0.000 base.py:1734(name)
#        25    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         4    0.000    0.000    0.000    0.000 {built-in method sys.getsizeof}
#         2    0.000    0.000    0.000    0.000 construction.py:488(<listcomp>)
#        22    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#        18    0.000    0.000    0.000    0.000 {method '__exit__' of 'nt.ScandirIterator' objects}
#        33    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 base.py:3198(_get_reconciled_name_object)
#        56    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 managers.py:1240(value_getitem)
#        27    0.000    0.000    0.000    0.000 <frozen codecs>:281(getstate)
#         7    0.000    0.000    0.000    0.000 info.py:479(ids)
#         4    0.000    0.000    0.000    0.000 base_parser.py:1308(<genexpr>)
#         8    0.000    0.000    0.000    0.000 frame.py:600(_constructor)
#         4    0.000    0.000    0.000    0.000 range.py:323(<genexpr>)
#         4    0.000    0.000    0.000    0.000 groupby.py:4116(_reindex_output)
#         1    0.000    0.000    0.000    0.000 base_parser.py:358(_maybe_make_multi_index_columns)
#         1    0.000    0.000    0.000    0.000 base.py:721(tolist)
#         5    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 pathlib.py:147(splitroot)
#        19    0.000    0.000    0.000    0.000 subprocess.py:1563(_internal_poll)
#         1    0.000    0.000    0.000    0.000 base_parser.py:258(_extract_multi_indexer_columns)
#         2    0.000    0.000    0.000    0.000 grouper.py:569(name)
#        11    0.000    0.000    0.000    0.000 blocks.py:275(__len__)
#         3    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         3    0.000    0.000    0.000    0.000 common.py:1102(_maybe_memory_map)
#        36    0.000    0.000    0.000    0.000 subprocess.py:1311(_on_error_fd_closer)
#         6    0.000    0.000    0.000    0.000 base.py:6582(_validate_indexer)
#         2    0.000    0.000    0.000    0.000 ops.py:742(__init__)
#         1    0.000    0.000    0.000    0.000 info.py:984(add_columns_summary_line)
#         4    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         4    0.000    0.000    0.000    0.000 concat.py:110(<genexpr>)
#         2    0.000    0.000    0.000    0.000 ops.py:903(names)
#         2    0.000    0.000    0.000    0.000 common.py:99(_maybe_match_name)
#         1    0.000    0.000    0.000    0.000 server.py:204(_start_server_if_needed)
#        35    0.000    0.000    0.000    0.000 multiarray.py:152(concatenate)
#         2    0.000    0.000    0.000    0.000 series.py:3152(<genexpr>)
#         1    0.000    0.000    0.000    0.000 info.py:919(<listcomp>)
#         7    0.000    0.000    0.000    0.000 <frozen codecs>:331(getstate)
#         1    0.000    0.000    0.000    0.000 base.py:5356(_getitem_slice)
#         2    0.000    0.000    0.000    0.000 ops.py:204(_get_cython_vals)
#         2    0.000    0.000    0.000    0.000 server.py:303(_server_is_alive)
#         2    0.000    0.000    0.000    0.000 dtypes.py:303(construct_from_string)
#         4    0.000    0.000    0.000    0.000 grouper.py:806(<genexpr>)
#        17    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 format.py:793(truncate)
#         2    0.000    0.000    0.000    0.000 ops.py:283(_get_output_shape)
#        13    0.000    0.000    0.000    0.000 base.py:574(_ensure_array)
#        12    0.000    0.000    0.000    0.000 c_parser_wrapper.py:365(<setcomp>)
#         2    0.000    0.000    0.000    0.000 info.py:871(header_column_widths)
#         9    0.000    0.000    0.000    0.000 subprocess.py:481(__init__)
#         2    0.000    0.000    0.000    0.000 common.py:116(ensure_python_int)
#         4    0.000    0.000    0.000    0.000 concat.py:92(is_nonempty)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:314(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:578(<listcomp>)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:208(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 typing.py:349(inner)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1148(_process_date_conversion)
#         1    0.000    0.000    0.000    0.000 info.py:781(<listcomp>)
#        14    0.000    0.000    0.000    0.000 managers.py:997(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         3    0.000    0.000    0.000    0.000 construction.py:231(mgr_to_mgr)
#         2    0.000    0.000    0.000    0.000 format.py:736(_calc_max_rows_fitted)
#        33    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 common.py:192(all_none)
#        13    0.000    0.000    0.000    0.000 base.py:241(disallow_kwargs)
#        16    0.000    0.000    0.000    0.000 nanops.py:1492(check_below_min_count)
#         2    0.000    0.000    0.000    0.000 pathlib.py:523(_format_parsed_parts)
#         2    0.000    0.000    0.000    0.000 generic.py:547(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 managers.py:511(<genexpr>)
#         2    0.000    0.000    0.000    0.000 csvs.py:193(nlevels)
#        24    0.000    0.000    0.000    0.000 subprocess.py:1239(_remaining_time)
#         6    0.000    0.000    0.000    0.000 base.py:555(<genexpr>)
#         1    0.000    0.000    0.000    0.000 info.py:771(add_object_type_line)
#         3    0.000    0.000    0.000    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#         1    0.000    0.000    0.000    0.000 managers.py:1575(<listcomp>)
#         1    0.000    0.000    0.000    0.000 common.py:85(consensus_name_attr)
#         2    0.000    0.000    0.000    0.000 format.py:725(_calc_max_cols_fitted)
#         2    0.000    0.000    0.000    0.000 ops.py:314(_get_result_dtype)
#         4    0.000    0.000    0.000    0.000 grouper.py:804(<genexpr>)
#        18    0.000    0.000    0.000    0.000 subprocess.py:259(_cleanup)
#        22    0.000    0.000    0.000    0.000 function_base.py:5050(_delete_dispatcher)
#         2    0.000    0.000    0.000    0.000 missing.py:107(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:318(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:5402(<setcomp>)
#         2    0.000    0.000    0.000    0.000 csvs.py:130(_get_index_label_flat)
#         3    0.000    0.000    0.000    0.000 generic.py:5881(<genexpr>)
#         2    0.000    0.000    0.000    0.000 managers.py:655(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 concat.py:117(<genexpr>)
#         4    0.000    0.000    0.000    0.000 format.py:769(_is_in_terminal)
#        16    0.000    0.000    0.000    0.000 ops.py:762(groupings)
#        18    0.000    0.000    0.000    0.000 contextlib.py:345(__enter__)
#         2    0.000    0.000    0.000    0.000 groupby.py:1092(_reset_group_selection)
#         2    0.000    0.000    0.000    0.000 concat.py:108(<setcomp>)
#        20    0.000    0.000    0.000    0.000 nanops.py:195(_get_fill_value)
#        11    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#         6    0.000    0.000    0.000    0.000 csvs.py:104(header)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.writers.word_len}
#         2    0.000    0.000    0.000    0.000 base.py:413(_engine_type)
#         1    0.000    0.000    0.000    0.000 base.py:5411(<listcomp>)
#         2    0.000    0.000    0.000    0.000 info.py:823(ids)
#         4    0.000    0.000    0.000    0.000 csvs.py:108(index)
#         1    0.000    0.000    0.000    0.000 common.py:178(not_none)
#         6    0.000    0.000    0.000    0.000 csvs.py:92(na_rep)
#         3    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         4    0.000    0.000    0.000    0.000 base.py:728(_constructor)
#         2    0.000    0.000    0.000    0.000 pathlib.py:515(_from_parsed_parts)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:209(<listcomp>)
#         3    0.000    0.000    0.000    0.000 function_base.py:346(iterable)
#         1    0.000    0.000    0.000    0.000 managers.py:587(<listcomp>)
#         2    0.000    0.000    0.000    0.000 info.py:874(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         2    0.000    0.000    0.000    0.000 format.py:691(_initialize_columns)
#         2    0.000    0.000    0.000    0.000 format.py:2181(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:229(_has_complex_date_col)
#         2    0.000    0.000    0.000    0.000 csvs.py:163(_initialize_chunksize)
#         1    0.000    0.000    0.000    0.000 info.py:879(<listcomp>)
#         6    0.000    0.000    0.000    0.000 csvs.py:96(float_format)
#         5    0.000    0.000    0.000    0.000 base.py:1194(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 concat.py:655(<listcomp>)
#         1    0.000    0.000    0.000    0.000 info.py:889(_gen_rows)
#         3    0.000    0.000    0.000    0.000 managers.py:2381(<listcomp>)
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#         2    0.000    0.000    0.000    0.000 algorithms.py:855(resolve_na_sentinel)
#         1    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#        18    0.000    0.000    0.000    0.000 contextlib.py:543(__enter__)
#         2    0.000    0.000    0.000    0.000 concat.py:109(<setcomp>)
#         2    0.000    0.000    0.000    0.000 grouper.py:857(is_in_obj)
#        16    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 stride_tricks.py:345(<genexpr>)
#         8    0.000    0.000    0.000    0.000 managers.py:1882(ndim)
#         6    0.000    0.000    0.000    0.000 csvs.py:100(decimal)
#         1    0.000    0.000    0.000    0.000 base_parser.py:834(_check_data_length)
#         2    0.000    0.000    0.000    0.000 range.py:247(start)
#         3    0.000    0.000    0.000    0.000 base_parser.py:1334(is_index_col)
#         2    0.000    0.000    0.000    0.000 csvs.py:134(_initialize_quotechar)
#         2    0.000    0.000    0.000    0.000 ops.py:122(__init__)
#         2    0.000    0.000    0.000    0.000 ops.py:905(<listcomp>)
#         3    0.000    0.000    0.000    0.000 common.py:182(<genexpr>)
#         1    0.000    0.000    0.000    0.000 managers.py:233(is_single_block)
#         1    0.000    0.000    0.000    0.000 range.py:541(equals)
#         4    0.000    0.000    0.000    0.000 numeric.py:2403(_array_equal_dispatcher)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 missing.py:636(maybe_fill)
#         2    0.000    0.000    0.000    0.000 concat.py:116(<setcomp>)
#         2    0.000    0.000    0.000    0.000 generic.py:5876(<genexpr>)
#         2    0.000    0.000    0.000    0.000 indexing.py:2643(need_slice)
#         3    0.000    0.000    0.000    0.000 info.py:977(headers)
#         1    0.000    0.000    0.000    0.000 construction.py:482(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#         5    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 multiarray.py:1130(putmask)
#         2    0.000    0.000    0.000    0.000 range.py:270(stop)
#         2    0.000    0.000    0.000    0.000 format.py:639(is_truncated_vertically)
#         1    0.000    0.000    0.000    0.000 readers.py:2132(_extract_dialect)
#         1    0.000    0.000    0.000    0.000 concat.py:625(_get_result_dim)
#         2    0.000    0.000    0.000    0.000 format.py:1027(__init__)
#         2    0.000    0.000    0.000    0.000 grouper.py:639(result_index)
#         1    0.000    0.000    0.000    0.000 common.py:651(resolve_numeric_only)
#         2    0.000    0.000    0.000    0.000 format.py:635(is_truncated_horizontally)
#         2    0.000    0.000    0.000    0.000 grouper.py:587(_ilevel)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1034(_argsort_dispatcher)
#         1    0.000    0.000    0.000    0.000 base_parser.py:924(_validate_usecols_arg)
#         1    0.000    0.000    0.000    0.000 info.py:757(display_memory_usage)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#         9    0.000    0.000    0.000    0.000 subprocess.py:1089(__enter__)
#         2    0.000    0.000    0.000    0.000 ops.py:241(_disallow_invalid_ops)
#         1    0.000    0.000    0.000    0.000 base_parser.py:209(<setcomp>)
#         1    0.000    0.000    0.000    0.000 server.py:118(motherTongue)
#         1    0.000    0.000    0.000    0.000 {built-in method gc.get_referents}
#         3    0.000    0.000    0.000    0.000 stride_tricks.py:363(_broadcast_to_dispatcher)
#         2    0.000    0.000    0.000    0.000 common.py:196(<genexpr>)
#         2    0.000    0.000    0.000    0.000 range.py:293(step)
#         1    0.000    0.000    0.000    0.000 concat.py:701(_maybe_check_integrity)
#         2    0.000    0.000    0.000    0.000 format.py:701(_initialize_colspace)
#         1    0.000    0.000    0.000    0.000 range.py:189(_constructor)
#         3    0.000    0.000    0.000    0.000 blocks.py:217(mgr_locs)
#         2    0.000    0.000    0.000    0.000 readers.py:517(validate_integer)
#         2    0.000    0.000    0.000    0.000 series.py:1274(_clear_item_cache)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:2328(_any_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1888(_nonzero_dispatcher)
#         2    0.000    0.000    0.000    0.000 format.py:672(_initialize_formatters)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#         2    0.000    0.000    0.000    0.000 base.py:148(is_consolidated)
#         2    0.000    0.000    0.000    0.000 common.py:129(__enter__)
#         2    0.000    0.000    0.000    0.000 format.py:755(_adjust_max_rows)
#         2    0.000    0.000    0.000    0.000 info.py:818(data)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2950(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 readers.py:1812(__enter__)
#         3    0.000    0.000    0.000    0.000 shape_base.py:19(_atleast_1d_dispatcher)
#         1    0.000    0.000    0.000    0.000 base.py:3209(_validate_sort_keyword)
#         1    0.000    0.000    0.000    0.000 numeric.py:181(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 readers.py:547(_validate_names)
#         1    0.000    0.000    0.000    0.000 base_parser.py:221(<listcomp>)
#         1    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#         1    0.000    0.000    0.000    0.000 numeric.py:216(_should_fallback_to_positional)
#         1    0.000    0.000    0.000    0.000 api.py:281(<listcomp>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:874(_sort_dispatcher)
