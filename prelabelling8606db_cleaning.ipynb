# %% [markdown]
# ### Counting the total number of all errors including undesirable Typos, QnAs and truncated QnAs

# %%
# !pip install language_tool_python spacy textblob
# Out:
# Requirement already satisfied: language_tool_python in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (2.7.1)
# Requirement already satisfied: spacy in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (3.6.1)
# Requirement already satisfied: textblob in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (0.17.1)
# Requirement already satisfied: requests in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from language_tool_python) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from language_tool_python) (4.66.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (6.3.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (1.25.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (2.3.0)
# Requirement already satisfied: jinja2 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: nltk>=3.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from nltk>=3.1->textblob) (2023.8.8)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from requests->language_tool_python) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from requests->language_tool_python) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from requests->language_tool_python) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from requests->language_tool_python) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.1)
# Requirement already satisfied: colorama in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from tqdm->language_tool_python) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from jinja2->spacy) (2.1.3)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 640.0 kB/s eta 0:00:20
#      --------------------------------------- 0.1/12.8 MB 525.1 kB/s eta 0:00:25
#      --------------------------------------- 0.1/12.8 MB 655.4 kB/s eta 0:00:20
#      --------------------------------------- 0.1/12.8 MB 722.1 kB/s eta 0:00:18
#       -------------------------------------- 0.2/12.8 MB 930.9 kB/s eta 0:00:14
#       -------------------------------------- 0.2/12.8 MB 935.2 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 962.4 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 965.4 kB/s eta 0:00:13
#      - -------------------------------------- 0.3/12.8 MB 1.0 MB/s eta 0:00:13
#      - ------------------------------------- 0.3/12.8 MB 941.3 kB/s eta 0:00:14
#      - ------------------------------------- 0.3/12.8 MB 941.3 kB/s eta 0:00:14
#      - ------------------------------------- 0.4/12.8 MB 843.6 kB/s eta 0:00:15
#      - ------------------------------------- 0.4/12.8 MB 867.4 kB/s eta 0:00:15
#      - ------------------------------------- 0.5/12.8 MB 912.9 kB/s eta 0:00:14
#      - ------------------------------------- 0.5/12.8 MB 917.3 kB/s eta 0:00:14
#      - ------------------------------------- 0.5/12.8 MB 921.2 kB/s eta 0:00:14
#      - ------------------------------------- 0.6/12.8 MB 924.8 kB/s eta 0:00:14
#      - ------------------------------------- 0.6/12.8 MB 936.6 kB/s eta 0:00:14
#      -- ------------------------------------ 0.7/12.8 MB 968.9 kB/s eta 0:00:13
#      -- ------------------------------------ 0.7/12.8 MB 968.5 kB/s eta 0:00:13
#      -- ------------------------------------ 0.7/12.8 MB 969.4 kB/s eta 0:00:13
#      -- ------------------------------------ 0.8/12.8 MB 963.6 kB/s eta 0:00:13
#      -- ------------------------------------ 0.8/12.8 MB 946.4 kB/s eta 0:00:13
#      -- ------------------------------------ 0.8/12.8 MB 958.5 kB/s eta 0:00:13
#      -- ------------------------------------ 0.9/12.8 MB 972.0 kB/s eta 0:00:13
#      -- ------------------------------------ 0.9/12.8 MB 977.8 kB/s eta 0:00:13
#      -- ------------------------------------ 1.0/12.8 MB 978.2 kB/s eta 0:00:13
#      --- ------------------------------------ 1.0/12.8 MB 1.0 MB/s eta 0:00:12
#      --- ------------------------------------ 1.1/12.8 MB 1.0 MB/s eta 0:00:12
#      --- ------------------------------------ 1.1/12.8 MB 1.0 MB/s eta 0:00:12
kB/s eta 0:00:02
#      --------------------------------- ---- 11.4/12.8 MB 932.6 kB/s eta 0:00:02
#      --------------------------------- ---- 11.4/12.8 MB 936.6 kB/s eta 0:00:02
#      ---------------------------------- --- 11.5/12.8 MB 939.4 kB/s eta 0:00:02
#      ---------------------------------- --- 11.5/12.8 MB 939.4 kB/s eta 0:00:02
#      ---------------------------------- --- 11.6/12.8 MB 939.3 kB/s eta 0:00:02
#      ---------------------------------- --- 11.6/12.8 MB 940.7 kB/s eta 0:00:02
#      ---------------------------------- --- 11.6/12.8 MB 940.7 kB/s eta 0:00:02
#      ---------------------------------- --- 11.7/12.8 MB 940.7 kB/s eta 0:00:02
#      ---------------------------------- --- 11.7/12.8 MB 942.1 kB/s eta 0:00:02
#      ---------------------------------- --- 11.7/12.8 MB 940.7 kB/s eta 0:00:02
#      ---------------------------------- --- 11.8/12.8 MB 939.4 kB/s eta 0:00:02
#      ---------------------------------- --- 11.8/12.8 MB 939.3 kB/s eta 0:00:02
#      ----------------------------------- -- 11.8/12.8 MB 936.6 kB/s eta 0:00:02
#      ----------------------------------- -- 11.8/12.8 MB 935.2 kB/s eta 0:00:02
#      ----------------------------------- -- 11.9/12.8 MB 935.3 kB/s eta 0:00:01
#      ----------------------------------- -- 11.9/12.8 MB 935.3 kB/s eta 0:00:01
#      ----------------------------------- -- 12.0/12.8 MB 939.3 kB/s eta 0:00:01
#      ----------------------------------- -- 12.0/12.8 MB 962.8 kB/s eta 0:00:01
#      ----------------------------------- -- 12.0/12.8 MB 961.4 kB/s eta 0:00:01
#      ----------------------------------- -- 12.1/12.8 MB 962.8 kB/s eta 0:00:01
#      ----------------------------------- -- 12.1/12.8 MB 962.8 kB/s eta 0:00:01
#      ----------------------------------- -- 12.1/12.8 MB 962.8 kB/s eta 0:00:01
#      ----------------------------------- -- 12.1/12.8 MB 961.4 kB/s eta 0:00:01
#      ------------------------------------ - 12.2/12.8 MB 968.5 kB/s eta 0:00:01
#      ------------------------------------ - 12.2/12.8 MB 967.1 kB/s eta 0:00:01
#      ------------------------------------ - 12.2/12.8 MB 969.9 kB/s eta 0:00:01
#      ------------------------------------ - 12.2/12.8 MB 969.9 kB/s eta 0:00:01
#      ------------------------------------ - 12.2/12.8 MB 964.3 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 972.8 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 969.9 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 969.9 kB/s eta 0:00:01
#      ------------------------------------ - 12.4/12.8 MB 975.7 kB/s eta 0:00:01
#      ------------------------------------ - 12.4/12.8 MB 972.9 kB/s eta 0:00:01
#      ------------------------------------ - 12.5/12.8 MB 977.1 kB/s eta 0:00:01
#      ------------------------------------ - 12.5/12.8 MB 974.3 kB/s eta 0:00:01
#      -------------------------------------  12.5/12.8 MB 983.1 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 984.6 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 984.6 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 986.0 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 993.5 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 993.5 kB/s eta 0:00:01
#      -------------------------------------  12.8/12.8 MB 996.5 kB/s eta 0:00:01
#      -------------------------------------  12.8/12.8 MB 998.0 kB/s eta 0:00:01
#      -------------------------------------- 12.8/12.8 MB 994.2 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.3.0)
# Requirement already satisfied: jinja2 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: colorama in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mathews\miniconda3\envs\tf\lib\site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import os
import csv
import re
import language_tool_python
import time
import cProfile
from textblob import TextBlob
import spacy

def count_multiple_commas(text):
    if isinstance(text, str):
        pattern = re.compile(r',{2,}')
        return len(re.findall(pattern, text))
    else:
        return text

def replace_multiple_commas(text):
    if isinstance(text, str):
        pattern = re.compile(r',{2,}')
        corrected_text = re.sub(pattern, ', ', text)
        if corrected_text != text:
            print(f"\nOriginal text: {text}")
            print(f"Corrected text: {corrected_text}")
        return corrected_text
    else:
        return text

def comma_cluster_removal_df(df):
    total_comma_count = 0

    for column in df.columns:
        df[column] = df[column].apply(replace_multiple_commas)
        total_comma_count += df[column].apply(count_multiple_commas).sum()

    print(f"Total comma count: {total_comma_count}")
    return df, total_comma_count


def is_undesirable_question_to_count(question):
    if isinstance(question, str):
        count_phrases = [
            
            "what is the title",
            "what is the research topic",
            "what data is used in the study",
            "what data sets are collected in this study",
            "how did the study",
            "what does the arrow in figure 6 represent",
            "what was the publication date of the study",
            "what is the title of the paper",
            "what is the purpose of this study",
            "what was the goal of the study",
            "what data was utilized in the study",
            "what is the source of funding for this study",
            "what was the aim of this study",
            "what are the objectives of the study",
            "what was the main focus of the study",
            "what were the main conclusions of the study",
            "what methods were used in the study",
            "what ratio was used for the analysis",
            "what models are shown in fig 4",
            "what is the conclusion of this study",
            "what do the innovations of this study enable",
            "what is the article about",
            "what is the doi number for the article",
            "where can the tool be accessed",
            "what data has been used",
            "what were the results of the study",
            "what are the key findings of this study",
            "what data sources were used in this study",
            "what are the limitations of this study",
            "where was the research conducted",
            "what are the key words for this article",
            "what is the main objective of this study",
            "what evidence supports the research",
            # Add more phrases here
        ]
        return any(phrase in question.lower() for phrase in count_phrases)
    return False

def is_truncated(sentence):
    
    # Ensure the sentence is converted to a string
    sentence = str(sentence)
    # Define a list of sentence-ending punctuation marks
    sentence_endings = ['.', '!', '?', '."', '!"', '?"', '.”', '!”', '?”']
    
    # Check if the last character of the sentence is a sentence-ending punctuation mark
    if sentence[-1] in sentence_endings:
        return False  # Not truncated
    else:
        print ("\n" + sentence+"\n")
        return True   # Truncated

# Assuming you have defined your functions is_undesirable_question_to_count and is_truncated properly

def count_truncated_questions_and_answers_in_df(df, filtered_data_file):
    #df = pd.read_csv(file_path)
    df.info() 
    columns_with_spaces = df.columns.tolist()
    print(columns_with_spaces) 
    questions = df['Question']
    answers = df['Answer']
        
    questions_count = df['Question'].apply(is_undesirable_question_to_count).sum()

    # Count truncated questions
    truncated_questions_count = df['Question'].apply(is_truncated).sum()

    # Count truncated answers
    truncated_answers_count = df['Answer'].apply(is_truncated).sum()
     
    # Filter out truncated rows
    truncated_questions = []
    truncated_answers = []
    
    # Filter out truncated rows
    not_truncated_indices = []
    for i in range(len(df)):
        if not (is_truncated(questions[i]) or is_truncated(answers[i])):
            not_truncated_indices.append(i)
        else:
            if is_truncated(questions[i]):
                truncated_questions.append(questions[i])
                print(f"Truncated Question {i}: {questions[i]}")
            if is_truncated(answers[i]):
                truncated_answers.append(answers[i])
                print(f"Corresponding Question {i}: {questions[i]}")
                print(f"Truncated Answer  {i}: {answers[i]} \n")
    df = df.iloc[not_truncated_indices]
      
    # Filter out questions and their corresponding answers
    filtered_indices = [i for i, question in enumerate(df['Question']) if is_undesirable_question_to_count(question)]
    filtered_data = pd.DataFrame({
        'Question': df['Question'].iloc[filtered_indices],
        'Answer': df['Answer'].iloc[filtered_indices]
    })
    
    # Print the number of rows in the filtered data
    print("Number of rows in filtered data:", len(filtered_data))
    
    # Create a new DataFrame for remaining data without truncated QnA
    remaining_indices = [i for i in range(len(df)) if i not in filtered_indices]
    remaining_data = df.iloc[remaining_indices]
    
    # Print the number of rows in the remaining data
    print("Number of rows in remaining data:", len(remaining_data))
    
    # Save the filtered data
    filtered_data.to_csv(filtered_data_file, index=False, encoding='utf-8')
    
    # Save the remaining data
    #remaining_data.to_csv(remaining_data_file, index=False, encoding='utf-8')
    
    return questions_count, truncated_questions_count, truncated_answers_count, remaining_data



def save_filtered_data(file_path, filtered_data):
    with open(file_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Question', 'Answer']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(filtered_data)

        


#def count_errors(text):
 #   tool = language_tool_python.LanguageTool('en-GB')
  #  matches = tool.check(text)
   # return len(matches)

def LanguageTool_df(df):
    tool = language_tool_python.LanguageTool('en-GB')
    corrected_content = []

    for i in range(len(df)):
        corrected_row = []
        for cell in df.iloc[i]:
            if isinstance(cell, str):  # Check if the cell is a string
                corrected_cell = tool.correct(cell)
                corrected_cell = corrected_cell.replace(' Answer', 'Answer')
                corrected_row.append(corrected_cell)
            else:
                corrected_row.append(cell)  # If not a string, keep the original value
        corrected_content.append(corrected_row)

    LanguageTool_corrected_df = pd.DataFrame(corrected_content, columns=df.columns)

    return LanguageTool_corrected_df


def add_space_before_opening_bracket(df):
    #df = pd.read_csv(input_file_path)
    
    for column in df.columns:
        df[column] = df[column].apply(lambda cell: re.sub(r'([A-Za-z])\(', r'\1 (', cell) if isinstance(cell, str) else cell)
    
    #df.to_csv(ammended_space_file, index=False)
    
    return df   # Return the output file path after processing


# Function to correct the truncated starting word of the answers
def correct_truncated_start_word(text: str) -> str:
    
    # Load the spaCy English model
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)

    # Checking if the start token is capitalized or not
    if doc[0].is_title == False:
        blob = TextBlob(str(doc[0]))    # get the textblob object to correct the word
        words = text.split()            # word list to join them later on
        corrected_word = str(blob.correct())    # corrected blob is converted back to string
        corrected_text = corrected_word+ " " + " ".join(words[1:])
        return corrected_text.capitalize()
    
    return text


def add_full_stops(df):
# function to add full stops to the end of each “Answer” column.
    df['Answer']=df['Answer'].apply(lambda answer: answer.strip()+  '.' if isinstance(answer,str) else answer)
    return df
 
def main():
    # List of CSV files to process
    start_time = time.time() 
    
    
    
    csv_files = [
       # "C:/Users/HP/Documents/Sam/Data Science Voluteer/CSV/Geothermal_energy_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_gatesopen_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal+energy_f1000_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal_energy_wellcome_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Carbon+footprint_wellcome_20230717.csv",
       ## "C:/Users/Joshua Giwa/Downloads/test_dataset.csv"
        #"C:/Users/LolaPwasanga/Downloads/datarecords.csv"
        '8606.csv'
        ## Add more file paths here as needed
    ]

    total_questions_count = 0
    total_truncated_questions_count = 0
    total_truncated_answers_count = 0
    

    for csv_file in csv_files: 
        df = pd.read_csv(csv_file)
        
        #df = add_full_stops(df)

        # Removing any punctuation if any from the start of the answer
        df['Answer'] = df['Answer'].str.replace(r'^[\.\:\- ]*', '', regex=True)     # regex to replace the punctuations from the start of the answer

        # Correcting answers that are truncated in the start of the answer
        df['Answer'] = df['Answer'].apply(correct_truncated_start_word)


       # corrected_file_path = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_corrected.csv'))
        #remaining_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_remaining_data.csv'))
        filtered_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_filtered_questions.csv'))
        #ammended_space_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', 'bracket_spaced.csv'))
        questions_count, truncated_questions, truncated_answers, remaining_data = count_truncated_questions_and_answers_in_df(df, filtered_data_file)
        comma_cluster_removed_df, total_comma_count = comma_cluster_removal_df(remaining_data)
        space_before_bracket_ammended_df = add_space_before_opening_bracket(comma_cluster_removed_df)
        LanguageTool_corrected_df = LanguageTool_df(space_before_bracket_ammended_df)
       
        
        # Save the processed DataFrame with "updated" added to the name
        cleaned_df = LanguageTool_corrected_df.copy()
        cleaned_df_filename = os.path.basename(csv_file).replace('.csv', '_cleaned.csv')

        # Assuming that you have a directory where you want to save the updated DataFrames
        cleaned_df_dir = os.path.join(os.path.expanduser("~"), "Downloads", "cleaned_QnAs")

        if not os.path.exists(cleaned_df_dir):
            os.makedirs(cleaned_df_dir)

        cleaned_df_file_path = os.path.join(cleaned_df_dir, cleaned_df_filename)

        # Save the updated DataFrame as a CSV file
        cleaned_df.to_csv(cleaned_df_file_path, index=False)

        # Now, you can use the updated DataFrame for further processing if needed

        
        
        
        total_questions_count += questions_count
        total_truncated_questions_count += truncated_questions
        total_truncated_answers_count += truncated_answers
        
        
        print(f"File: {csv_file}\n")
        print(f"Total undesirable questions: {questions_count}")
        print(f"Total Truncated Questions: {truncated_questions}")
        print(f"Total Truncated Answers: {truncated_answers}")
       # print(f"Original typo/error found: {original_error_count}")
        print(f"excessive comma occurence: {total_comma_count}")
        #print(f"Corrected typo/error count: {corrected_errors}")

        
        print(f"(undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence): {questions_count + truncated_questions + truncated_answers +  total_comma_count}\n")

    print(f"Total Questions Count: {total_questions_count}")
    print(f"Total Truncated Questions Count: {total_truncated_questions_count}")
    print(f"Total Truncated Answers Count: {total_truncated_answers_count}")
    print(f"Total (Questions + Truncated Questions + Truncated Answers): {total_questions_count + total_truncated_questions_count + total_truncated_answers_count}")

    end_time = time.time()
    
    elapsed_time_seconds = end_time - start_time
    elapsed_time_minutes = elapsed_time_seconds / 60

    print(f"Script ran for {elapsed_time_minutes:.2f} minutes.")
    
    
    
if __name__ == "__main__":
    cProfile.run("main()", sort='cumulative')
# Out:
#          5622187853 function calls (5535793107 primitive calls) in 4013.056 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000 4013.225 4013.225 {built-in method builtins.exec}
#         1    0.000    0.000 4013.225 4013.225 81310234.py:229(main)
#         1    0.000    0.000 4013.152 4013.152 series.py:4520(apply)
#         1    0.000    0.000 4013.152 4013.152 apply.py:1010(apply)
#         1    0.000    0.000 4013.152 4013.152 apply.py:1061(apply_standard)
#         1   15.334   15.334 4013.152 4013.152 {pandas._libs.lib.map_infer}
#      8480    0.108    0.000 3997.818    0.471 81310234.py:207(correct_truncated_start_word)
#      8480    0.044    0.000 3872.961    0.457 __init__.py:27(load)
#      8480    0.060    0.000 3872.916    0.457 util.py:433(load_model)
#      8480    0.045    0.000 3866.885    0.456 util.py:475(load_model_from_package)
#      8480    0.362    0.000 3866.382    0.456 __init__.py:9(load)
#      8480    0.303    0.000 3866.019    0.456 util.py:651(load_model_from_init_py)
#      8480    0.117    0.000 3855.509    0.455 util.py:504(load_model_from_path)
#      8480    0.216    0.000 2097.508    0.247 language.py:2103(from_disk)
# 76320/8480    5.461    0.000 2091.456    0.247 util.py:1383(from_disk)
#      8480    0.066    0.000 1713.977    0.202 util.py:550(load_model_from_config)
#      8480    0.765    0.000 1713.733    0.202 language.py:1726(from_config)
#    161120   17.296    0.000 1700.910    0.011 tokenizer.pyx:567(_load_special_cases)
#  22845120   70.631    0.000 1683.613    0.000 tokenizer.pyx:591(add_special_case)
#      8480    0.078    0.000  893.510    0.105 language.py:2141(<lambda>)
#      8480    0.686    0.000  893.432    0.105 tokenizer.pyx:758(from_disk)
#      8480    1.569    0.000  889.462    0.105 tokenizer.pyx:794(from_bytes)
#      8480    0.151    0.000  875.221    0.103 language.py:153(__init__)
#      8480    0.128    0.000  866.105    0.102 language.py:108(tokenizer_factory)
#      8480    0.085    0.000  864.921    0.102 tokenizer.pyx:31(__init__)
#     16960    1.743    0.000  855.468    0.050 tokenizer.pyx:117(__set__)
#     59360    0.492    0.000  738.471    0.012 language.py:757(add_pipe)
#     59360    1.063    0.000  722.063    0.012 language.py:645(create_pipe)
#    127200    0.663    0.000  696.180    0.005 __init__.py:775(_make)
# 610560/127200    9.779    0.000  692.798    0.005 __init__.py:822(_fill)
#  22845120  380.228    0.000  626.573    0.000 vocab.pyx:272(make_fused_token)
#     59360   17.169    0.000  617.916    0.010 language.py:2149(<lambda>)
#    483360    6.126    0.000  558.708    0.001 __init__.py:1041(make_promise_schema)
#    483360    4.474    0.000  530.050    0.001 main.py:952(create_model)
#    483360   23.550    0.000  516.358    0.001 main.py:122(__new__)
#      8480    0.030    0.000  514.894    0.061 language.py:2129(deserialize_vocab)
#      8480    0.022    0.000  514.408    0.061 {method 'from_disk' of 'spacy.vocab.Vocab' objects}
#      8480  344.886    0.041  514.386    0.061 vocab.pyx:489(from_disk)
#     67840    0.111    0.000  404.259    0.006 __init__.py:747(resolve)
#  13118985  143.566    0.000  388.496    0.000 vocab.pyx:181(_new_lexeme)
#     42400    0.714    0.000  379.298    0.009 model.py:628(from_bytes)
#   1085440    1.460    0.000  372.318    0.000 _msgpack_api.py:17(msgpack_loads)
#   1085440    2.213    0.000  370.616    0.000 __init__.py:70(unpackb)
#  22845120  354.734    0.000  354.734    0.000 tokenizer.pyx:573(_validate_special_case)
#   2077600    8.188    0.000  352.493    0.000 fields.py:485(infer)
#   6215839   51.313    0.000  327.207    0.000 tokenizer.pyx:156(_tokenize_affixes)
# 3137600/2255680    8.378    0.000  311.094    0.000 fields.py:394(__init__)
#     42400    7.065    0.000  293.697    0.007 model.py:649(from_dict)
# 3137600/2255680    4.352    0.000  293.669    0.000 fields.py:539(prepare)
#     59360    0.077    0.000  292.110    0.005 __init__.py:761(fill)
#  51287040   10.849    0.000  292.067    0.000 vocab.pyx:167(get_by_orth)
#   1127840  183.450    0.000  290.767    0.000 __init__.py:101(get_all)
#     25440    0.274    0.000  286.284    0.011 trainable_pipe.pyx:320(from_disk)
#     25440   26.762    0.001  272.865    0.011 trainable_pipe.pyx:331(load_model)
#   1000640    0.722    0.000  260.293    0.000 functools.py:883(wrapper)
#   1000640    0.470    0.000  258.648    0.000 model.py:843(deserialize_attr)
#   6383916    4.109    0.000  218.207    0.000 tokenizer.pyx:384(_tokenize)
#   3137600   12.719    0.000  213.973    0.000 fields.py:816(populate_validators)
#     16960    0.401    0.000  181.076    0.011 lookups.py:297(from_disk)
#     16960   49.739    0.003  172.061    0.010 lookups.py:267(from_bytes)
#     25440    0.256    0.000  143.056    0.006 __init__.py:404(from_str)
#   6383916   16.608    0.000  134.236    0.000 tokenizer.pyx:444(_attach_tokens)
#   6207360   34.974    0.000  118.115    0.000 phrasematcher.pyx:158(add)
#  14007188   10.215    0.000  117.493    0.000 vocab.pyx:148(get)
#   2645760    1.228    0.000  112.047    0.000 class_validators.py:281(prep_validators)
#   2645760    2.007    0.000  110.818    0.000 class_validators.py:282(<listcomp>)
#   3400480    1.943    0.000  110.367    0.000 inspect.py:3111(signature)
#   2433760   10.441    0.000  108.812    0.000 class_validators.py:242(make_generic_validator)
#   3400480    1.750    0.000  108.425    0.000 inspect.py:2859(from_callable)
#   3400480   15.890    0.000  106.675    0.000 inspect.py:2246(_signature_from_callable)
#      8480    0.053    0.000  105.078    0.012 lemmatizer.py:289(from_disk)
#     76320    0.605    0.000  104.888    0.001 _json_api.py:42(read_json)
#      8480    0.214    0.000  104.806    0.012 lemmatizer.py:302(<lambda>)
# 3375040/2255680   12.622    0.000   98.450    0.000 fields.py:583(_type_analysis)
#     16960    0.132    0.000   97.037    0.006 __init__.py:477(from_disk)
#   1085440   84.657    0.000   90.017    0.000 {srsly.msgpack._unpacker.unpackb}
#  32926385   84.923    0.000   88.422    0.000 tokenizer.pyx:553(find_suffix)
#      8480    0.287    0.000   83.662    0.010 language.py:1009(__call__)
#   4638560   15.263    0.000   83.555    0.000 validators.py:698(find_validators)
#   3400480   17.538    0.000   82.380    0.000 inspect.py:2152(_signature_from_function)
#      8480    0.071    0.000   75.885    0.009 __init__.py:222(interpolate)
#     76320   73.369    0.001   75.880    0.001 {built-in method srsly.ujson.ujson.load}
#   6383916   19.428    0.000   75.763    0.000 tokenizer.pyx:396(_split_affixes)
#     25440    7.169    0.000   69.654    0.003 __init__.py:230(interpret_config)
#  26175063   65.750    0.000   68.568    0.000 tokenizer.pyx:525(find_infix)
#     33920    0.172    0.000   66.725    0.002 lookups.py:64(__init__)
#     33920   44.015    0.001   66.202    0.002 {method 'update' of 'collections.OrderedDict' objects}
#     25440    0.214    0.000   65.538    0.003 configparser.py:720(read_string)
#     25440    0.145    0.000   65.324    0.003 configparser.py:705(read_file)
#     25440   22.881    0.001   65.179    0.003 configparser.py:996(_read)
# 229180503/229180502   28.610    0.000   60.876    0.000 {built-in method builtins.all}
# 881920/440960    1.979    0.000   60.662    0.000 fields.py:788(_create_sub_type)
#    186561    9.234    0.000   57.363    0.000 {built-in method io.open}
#   6215839   31.122    0.000   56.990    0.000 doc.pyx:202(__init__)
# 426478635/422815267   36.199    0.000   56.330    0.000 {built-in method builtins.isinstance}
#      8480    0.080    0.000   55.528    0.007 language.py:2136(<lambda>)
#     33916    6.468    0.000   53.401    0.002 trainable_pipe.pyx:40(__call__)
#    169600    0.290    0.000   53.334    0.000 pathlib.py:1246(open)
#   3883840   49.944    0.000   52.872    0.000 inspect.py:2781(__init__)
#   6207360    6.437    0.000   52.158    0.000 vocab.pyx:248(__getitem__)
# 28026400/42400   22.514    0.000   49.155    0.001 util.py:340(convert_recursive)
# 1780800/169600    4.768    0.000   48.157    0.000 util.py:361(<listcomp>)
#      8480    0.027    0.000   48.017    0.006 attributeruler.py:323(from_disk)
#      8480    0.328    0.000   47.858    0.006 attributeruler.py:335(load_patterns)
#    169600    0.159    0.000   47.530    0.000 pathlib.py:1118(_opener)
#    169600   47.288    0.000   47.370    0.000 {built-in method nt.open}
#  22997760   41.098    0.000   47.112    0.000 tokenizer.pyx:216(_flush_cache)
#  13118985   33.546    0.000   46.943    0.000 lex_attrs.py:117(word_shape)
#  23474337    3.713    0.000   44.985    0.000 {method 'join' of 'str' objects}
#    169600    0.405    0.000   44.744    0.000 fields.py:751(<listcomp>)
#     33916    0.273    0.000   44.468    0.001 model.py:330(predict)
# 460480960   44.115    0.000   44.115    0.000 __init__.py:112(<genexpr>)
#  13118985   29.356    0.000   44.010    0.000 lex_attrs.py:22(like_num)
#      8480    0.117    0.000   43.444    0.005 util.py:693(load_config)
# 1144665/67832    1.032    0.000   43.117    0.001 model.py:307(__call__)
#  35436470   38.293    0.000   42.059    0.000 tokenizer.pyx:539(find_prefix)
#  33351840   17.045    0.000   41.606    0.000 typing.py:111(get_origin)
# 398513/33916    1.222    0.000   41.460    0.001 chain.py:48(forward)
#       636    0.004    0.000   41.057    0.065 blob.py:599(correct)
#      1305    0.004    0.000   41.025    0.031 blob.py:608(<genexpr>)
#       669    0.003    0.000   41.019    0.061 blob.py:136(correct)
#       669    0.002    0.000   41.013    0.061 blob.py:125(spellcheck)
#       669    0.002    0.000   41.011    0.061 __init__.py:120(suggest)
#       669    0.012    0.000   41.009    0.061 _text.py:1383(suggest)
# 734215715/731849757   36.241    0.000   40.920    0.000 {built-in method builtins.len}
#       357    0.005    0.000   40.756    0.114 _text.py:1371(_edit2)
#     20883    5.673    0.000   40.730    0.002 _text.py:1376(<genexpr>)
#   2968000   35.837    0.000   39.432    0.000 validators.py:643(check)
#    483360    0.776    0.000   38.328    0.000 main.py:802(__try_update_forward_refs__)
#    322240    0.688    0.000   38.246    0.000 __init__.py:339(copy)
#     59353    0.170    0.000   38.053    0.001 with_array.py:32(forward)
#    483360    1.645    0.000   37.504    0.000 typing.py:535(update_model_forward_refs)
# 22862080/1746880   18.451    0.000   37.211    0.000 copy.py:128(deepcopy)
#    771680    2.379    0.000   36.669    0.000 main.py:427(dict)
#      8480    4.524    0.001   36.580    0.004 attributeruler.py:248(add_patterns)
#  12389282   36.394    0.000   36.394    0.000 {method 'keys' of 'dict' objects}
#   2959520    6.565    0.000   36.011    0.000 fields.py:441(_get_field_info)
#    551141    0.248    0.000   35.200    0.000 {built-in method builtins.next}
#    127200    0.450    0.000   34.642    0.000 __init__.py:351(merge)
#   8997280    8.609    0.000   34.290    0.000 main.py:823(_iter)
#   1534880    3.385    0.000   32.055    0.000 attributeruler.py:224(add)
#     16960    0.246    0.000   30.766    0.002 parser.py:14(build_tb_parser_model)
# 148114129/147876689   29.284    0.000   30.555    0.000 {built-in method builtins.getattr}
#    271330    0.160    0.000   29.632    0.000 contextlib.py:114(__enter__)
#     33920    0.050    0.000   29.153    0.001 __init__.py:123(use_ops)
#     16960    0.161    0.000   28.862    0.002 __init__.py:93(get_ops)
#    483360    6.537    0.000   28.647    0.000 utils.py:235(generate_model_signature)
#    322240    1.871    0.000   28.552    0.000 copy.py:258(_reconstruct)
#  35641148    9.124    0.000   28.291    0.000 _text.py:95(__contains__)
#    152640    6.066    0.000   28.259    0.000 tokenizer.pyx:226(_flush_specials)
# 12177280/9005760    8.951    0.000   28.090    0.000 configparser.py:765(get)
#    771680    1.577    0.000   27.691    0.000 main.py:332(__init__)
#   1594240   16.631    0.000   27.558    0.000 configparser.py:1243(__init__)
#  31036800   23.351    0.000   27.382    0.000 doc.pyx:431(has_annotation)
#  13118985   18.971    0.000   26.424    0.000 lex_attrs.py:89(like_url)
#   6215839    6.586    0.000   25.868    0.000 _dict_proxies.py:26(__init__)
#    619040   24.724    0.000   25.704    0.000 {built-in method nt.stat}
#    771680   10.668    0.000   25.619    0.000 main.py:1032(validate_model)
#   1000640    1.881    0.000   25.229    0.000 __init__.py:364(_sort)
#     25437    0.172    0.000   24.848    0.001 with_array.py:70(_list_forward)
#   1026628    2.683    0.000   24.787    0.000 {built-in method builtins.sorted}
# 3324160/2399840    5.426    0.000   24.184    0.000 copy.py:226(_deepcopy_dict)
#     42400    0.307    0.000   23.650    0.001 <frozen importlib._bootstrap>:1002(_find_and_load)
#   6894240    2.288    0.000   23.560    0.000 _collections_abc.py:849(__iter__)
#     16960    0.142    0.000   23.395    0.001 __init__.py:82(_import_extra_cpu_backends)
#    161120    0.533    0.000   23.332    0.000 phrasematcher.pyx:31(__init__)
# 19589332/13118985   11.523    0.000   23.141    0.000 util.py:1227(_get_attr_unless_lookup)
#     67832    0.274    0.000   22.649    0.000 residual.py:28(forward)
#     33920    0.116    0.000   22.321    0.001 <frozen importlib._bootstrap>:967(_find_and_load_unlocked)
#  29841120   12.859    0.000   22.186    0.000 lookups.py:81(__setitem__)
#     33920    0.668    0.000   22.170    0.001 <frozen importlib._bootstrap>:901(_find_spec)
#      8480    2.123    0.000   22.081    0.003 __init__.py:426(to_str)
#     16958    0.510    0.000   22.073    0.001 tb_framework.py:33(forward)
#      8479    0.044    0.000   21.470    0.003 tok2vec.py:113(predict)
# 154083779   20.817    0.000   20.817    0.000 {method 'startswith' of 'str' objects}
#     33920    0.049    0.000   20.811    0.001 <frozen importlib._bootstrap_external>:1415(find_spec)
#     33920    0.503    0.000   20.762    0.001 <frozen importlib._bootstrap_external>:1383(_get_spec)
#   5579840    4.731    0.000   20.635    0.000 __init__.py:372(<lambda>)
#    966720    1.739    0.000   20.565    0.000 __init__.py:188(__init__)
#    305280    2.107    0.000   19.886    0.000 <frozen importlib._bootstrap_external>:1514(find_spec)
#    135680    0.200    0.000   19.876    0.000 tokenizer.pyx:617(_reload_special_cases)
#    610560    1.179    0.000   19.811    0.000 main.py:517(parse_obj)
#      8480    0.032    0.000   19.731    0.002 util.py:1337(from_bytes)
#   6215839    3.828    0.000   19.282    0.000 __init__.py:1043(__init__)
#  35651572   13.918    0.000   19.175    0.000 _text.py:80(_lazy)
#     67840    0.733    0.000   18.881    0.000 language.py:1704(_link_components)
#   4502880    2.915    0.000   18.773    0.000 configparser.py:1255(__getitem__)
#   1534880    3.481    0.000   18.220    0.000 matcher.pyx:79(add)
#     84790    1.507    0.000   17.750    0.000 maxout.py:45(forward)
#     25440    0.185    0.000   17.540    0.001 tok2vec.py:281(MaxoutWindowEncoder)
#   3137600   12.670    0.000   17.444    0.000 fields.py:151(__init__)
#    720803   17.373    0.000   17.373    0.000 {method 'copy' of 'numpy.ndarray' objects}
#  33351840   11.228    0.000   16.673    0.000 typing.py:1522(get_origin)
#  28026400    8.139    0.000   16.215    0.000 util.py:112(is_xp_array)
#   6215839    5.730    0.000   15.455    0.000 _collections_abc.py:933(update)
#      8479    0.351    0.000   14.919    0.002 lemmatizer.py:121(__call__)
# 8802240/8225600    5.282    0.000   14.891    0.000 main.py:727(_get_value)
#     16960    0.163    0.000   14.669    0.001 _msgpack_api.py:43(read_msgpack)
#    127185   14.426    0.000   14.561    0.000 numpy_ops.pyx:92(gemm)
#     25440    0.139    0.000   14.522    0.001 clone.py:12(clone)
#    220760   13.115    0.000   14.486    0.000 lemmatizer.py:196(rule_lemmatize)
#   7055360    8.305    0.000   14.320    0.000 inspect.py:2498(__init__)
#     59360    0.051    0.000   14.087    0.000 model.py:478(copy)
#   5579840    6.672    0.000   14.077    0.000 __init__.py:491(_mask_positional_args)
# 474880/59360    2.351    0.000   14.036    0.000 model.py:486(_copy)
#    254400    0.195    0.000   14.022    0.000 pathlib.py:1227(stat)
#  13118985    9.061    0.000   13.992    0.000 lex_attrs.py:25(is_punct)
#     67840    0.150    0.000   13.826    0.000 util.py:1475(copy_config)
#    237440    0.319    0.000   13.809    0.000 pathlib.py:1419(exists)
# 5003200/3137600    3.489    0.000   13.483    0.000 typing.py:197(convert_generics)
#   1628158    6.878    0.000   13.199    0.000 model.py:85(__init__)
#     33916    0.117    0.000   12.960    0.000 with_array.py:87(_ragged_forward)
#   5206720    7.037    0.000   12.173    0.000 typing.py:443(is_typeddict)
#     25440    0.107    0.000   12.029    0.000 trainable_pipe.pyx:340(lambda8)
#     25440    0.180    0.000   11.923    0.000 pipe.pyx:147(deserialize_config)
#   1534880    2.189    0.000   11.430    0.000 matcher.pyx:818(_preprocess_pattern)
#   5206720    3.140    0.000   11.306    0.000 typing.py:509(is_finalvar)
#  13118985    7.978    0.000   11.252    0.000 lex_attrs.py:32(is_ascii)
#   3001920    1.510    0.000   10.838    0.000 __init__.py:82(before_get)
#     25440    0.344    0.000   10.823    0.000 tok2vec.py:126(MultiHashEmbed)
#    966720   10.137    0.000   10.755    0.000 config.py:169(inherit_config)
#   2433760    6.844    0.000   10.604    0.000 functools.py:35(update_wrapper)
#   2077600    1.635    0.000   10.501    0.000 schema.py:1002(get_annotation_from_field_info)
#    483360    2.065    0.000   10.493    0.000 typing.py:376(resolve_annotations)
# 3230880/2145440    2.509    0.000   10.376    0.000 fields.py:852(validate)
#  27230448   10.364    0.000   10.364    0.000 {method 'match' of 're.Pattern' objects}
#  25915410    7.189    0.000   10.349    0.000 lex_attrs.py:144(lower)
#  13118985    5.236    0.000   10.194    0.000 lex_attrs.py:85(like_email)
# 1373760/25440    4.867    0.000   10.059    0.000 __init__.py:278(replace_section_refs)
#    483360    5.655    0.000    9.870    0.000 main.py:148(<setcomp>)
#    305280    0.156    0.000    9.641    0.000 <frozen importlib._bootstrap_external>:135(_path_stat)
#    288320    0.644    0.000    9.505    0.000 typing.py:1141(__instancecheck__)
#     50880    0.127    0.000    9.431    0.000 fields.py:663(<listcomp>)
#     16960    0.122    0.000    9.338    0.001 __init__.py:58(unpack)
#      8480    0.036    0.000    9.300    0.001 util.py:922(get_model_meta)
#      8480    0.137    0.000    9.167    0.001 util.py:879(load_meta)
#     84790    1.192    0.000    9.136    0.000 layernorm.py:23(forward)
#   1534880    0.488    0.000    9.124    0.000 {spacy.tokens._retokenize.normalize_token_attrs}
#   3001920    3.265    0.000    9.113    0.000 __init__.py:88(interpolate)
# 103703663    8.914    0.000    8.914    0.000 {method 'get' of 'dict' objects}
#      8480    0.022    0.000    8.878    0.001 language.py:1115(_ensure_doc)
#   2077600    1.687    0.000    8.866    0.000 fields.py:190(get_constraints)
#      8479    0.039    0.000    8.853    0.001 language.py:1103(make_doc)
#      8479    0.022    0.000    8.812    0.001 tokenizer.pyx:143(__call__)
#   1534880    8.636    0.000    8.636    0.000 _retokenize.pyx:443(normalize_token_attrs)
#   2959520    5.448    0.000    8.381    0.000 config.py:117(get_field_info)
#   6868726    4.938    0.000    8.332    0.000 model.py:389(_walk_bfs)
#   5376320    1.718    0.000    8.156    0.000 typing.py:412(is_literal_type)
# 42306768/39728848    4.696    0.000    7.978    0.000 {built-in method builtins.issubclass}
#  12389280    5.465    0.000    7.771    0.000 <frozen importlib._bootstrap>:398(parent)
#  12177280    5.192    0.000    7.744    0.000 configparser.py:1142(_unify_values)
#   1526400    5.036    0.000    7.698    0.000 <frozen importlib._bootstrap_external>:91(_path_join)
#    483360    0.616    0.000    7.559    0.000 abc.py:105(__new__)
# 3442880/2357440    1.896    0.000    7.520    0.000 fields.py:1056(_validate_singleton)
#   6640265    4.361    0.000    7.394    0.000 lookups.py:119(__contains__)
#  37197567    7.302    0.000    7.302    0.000 {spacy.strings.get_string_id}
#     25440    0.061    0.000    7.194    0.000 tok2vec.py:174(<listcomp>)
#    127200    0.145    0.000    7.133    0.000 tok2vec.py:169(make_hash_embed)
# 3570080/2077600    2.797    0.000    7.039    0.000 typing.py:285(_eval_type)
#    127200    0.662    0.000    6.988    0.000 hashembed.py:15(HashEmbed)
#     84790    0.496    0.000    6.979    0.000 layernorm.py:72(_get_moments)
#     98535    1.642    0.000    6.971    0.000 _text.py:1357(_edit1)
#     25440    3.388    0.000    6.770    0.000 configparser.py:1118(_join_multiline_values)
#   4502880    2.030    0.000    6.768    0.000 __init__.py:293(_interpret_value)
#      8480    0.085    0.000    6.758    0.001 language.py:2121(deserialize_meta)
#    364640    1.299    0.000    6.746    0.000 chain.py:18(chain)
#   8423243    3.163    0.000    6.725    0.000 {built-in method builtins.any}
#  13118985    5.446    0.000    6.723    0.000 lex_attrs.py:180(is_stop)
#      8480    0.214    0.000    6.674    0.001 npyio.py:282(load)
#   2077600    4.557    0.000    6.589    0.000 fields.py:196(<setcomp>)
#  34191372    5.917    0.000    6.567    0.000 {built-in method builtins.hasattr}
#    517280    6.563    0.000    6.563    0.000 {built-in method builtins.dir}
#  11956793    3.613    0.000    6.497    0.000 typing.py:271(inner)
#  14153120    4.240    0.000    6.426    0.000 utils.py:180(lenient_issubclass)
#  13118985    4.898    0.000    6.315    0.000 lex_attrs.py:77(is_currency)
#  28085753    4.675    0.000    6.312    0.000 util.py:127(is_numpy_array)
#    576640    4.511    0.000    6.243    0.000 typing.py:1065(_get_protocol_attrs)
#   3129120    1.744    0.000    6.235    0.000 typing.py:457(is_typeddict_special)
#   2077600    1.712    0.000    6.217    0.000 typing.py:497(is_classvar)
#    220480    1.272    0.000    6.067    0.000 tok2vec.py:98(find_listeners)
#   2365920    0.509    0.000    6.033    0.000 _collections_abc.py:805(__len__)
#  22997760    6.014    0.000    6.014    0.000 tokenizer.pyx:219(_reset_cache)
#  67106579    6.006    0.000    6.006    0.000 {method 'append' of 'list' objects}
#      8480    0.029    0.000    5.963    0.001 util.py:932(is_package)
#   5944482    2.858    0.000    5.957    0.000 typing.py:848(__subclasscheck__)
#      8480    0.034    0.000    5.934    0.001 metadata.py:536(distribution)
#  36362240    4.838    0.000    5.930    0.000 _msgpack_numpy.py:65(decode_numpy)
#      8479    0.028    0.000    5.906    0.001 attributeruler.py:132(__call__)
#      8480    0.097    0.000    5.899    0.001 metadata.py:180(from_name)
#  52585459    5.802    0.000    5.802    0.000 {method 'lower' of 'str' objects}
#   3400480    3.698    0.000    5.778    0.000 inspect.py:494(unwrap)
#    729280    0.804    0.000    5.777    0.000 util.py:144(get)
# 3188480/2357440    1.179    0.000    5.698    0.000 typing.py:218(<genexpr>)
#    390080    0.326    0.000    5.631    0.000 configparser.py:1206(add_section)
#   1602720    2.840    0.000    5.485    0.000 matcher.pyx:1064(_get_extra_predicates)
#   3366562    1.605    0.000    5.431    0.000 typing.py:719(__instancecheck__)
#   1221120    0.682    0.000    5.397    0.000 utils.py:600(_coerce_items)
#    610560    0.705    0.000    5.344    0.000 utils.py:561(merge)
#   3510720    1.333    0.000    5.332    0.000 configparser.py:1278(_options)
#   2196320    3.065    0.000    5.322    0.000 typing.py:433(is_namedtuple)
#   2077600    0.748    0.000    5.314    0.000 fields.py:1255(is_finalvar_with_default_val)
#     67840    0.103    0.000    5.299    0.000 __init__.py:738(<genexpr>)
#     16958    0.104    0.000    5.275    0.000 concatenate.py:56(forward)
#    330720    0.273    0.000    5.273    0.000 pathlib.py:974(__truediv__)
#   7555680    3.865    0.000    5.268    0.000 enum.py:358(__call__)
#  13118985    3.699    0.000    5.224    0.000 lex_attrs.py:164(is_lower)
#     59360    0.138    0.000    5.173    0.000 __init__.py:630(search)
#  29841120    5.147    0.000    5.147    0.000 {method 'add' of 'preshed.bloom.BloomFilter' objects}
#   6673769    1.884    0.000    5.126    0.000 abc.py:117(__instancecheck__)
#   1247904    5.112    0.000    5.112    0.000 {built-in method __new__ of type object at 0x00007FFC3088DC60}
#  12177280    5.088    0.000    5.088    0.000 __init__.py:935(__getitem__)
#    390080    0.332    0.000    5.080    0.000 configparser.py:649(add_section)
#    118720    0.599    0.000    5.015    0.000 fields.py:901(_validate_sequence_like)
#   2696640    1.608    0.000    5.013    0.000 fields.py:1152(_apply_validators)
#    330720    0.876    0.000    5.000    0.000 pathlib.py:736(_make_child)
#  13118985    3.375    0.000    4.979    0.000 lex_attrs.py:156(is_alpha)
#  58990484    4.896    0.000    4.896    0.000 {method 'isalpha' of 'str' objects}
#  32265626    4.883    0.000    4.883    0.000 {method 'endswith' of 'str' objects}
#  79177779    4.862    0.000    4.862    0.000 {method 'pop' of 'dict' objects}
#   2340480    0.919    0.000    4.816    0.000 configparser.py:1272(__len__)
#    610560    3.930    0.000    4.776    0.000 __init__.py:946(_update_from_parsed)
#    178080    0.315    0.000    4.765    0.000 __init__.py:692(copy_model_field)
#    737760    1.264    0.000    4.715    0.000 __init__.py:82(get)
#      8479    0.053    0.000    4.651    0.001 attributeruler.py:148(match)
#     16958    0.070    0.000    4.616    0.000 concatenate.py:57(<listcomp>)
#  47420164    4.592    0.000    4.592    0.000 {method 'items' of 'dict' objects}
#   1221120    0.541    0.000    4.566    0.000 utils.py:614(_coerce_value)
#  13118985    3.027    0.000    4.422    0.000 lex_attrs.py:172(is_title)
#      8479    0.219    0.000    4.364    0.001 matcher.pyx:214(__call__)
#     16960    3.753    0.000    4.323    0.000 {srsly.msgpack._unpacker.unpack}
#  13118985    3.074    0.000    4.274    0.000 lex_attrs.py:160(is_digit)
#    288320    0.393    0.000    4.225    0.000 typing.py:1082(_is_callable_members_only)
#  13118985    2.937    0.000    4.193    0.000 lex_attrs.py:168(is_space)
#     93280    0.129    0.000    4.179    0.000 util.py:20(force_path)
# 2357440/1526400    2.735    0.000    4.153    0.000 typing.py:294(<genexpr>)
#      8479    0.410    0.000    4.133    0.000 matcher.pyx:352(find_matches)
#   1500960    1.103    0.000    4.125    0.000 configparser.py:1200(set)
#   6383916    4.100    0.000    4.100    0.000 tokenizer.pyx:504(_save_cached)
#  31036800    4.032    0.000    4.032    0.000 doc.pyx:472(genexpr)
#  30419222    4.030    0.000    4.030    0.000 {method 'replace' of 'str' objects}
#   9099040    2.590    0.000    4.020    0.000 fields.py:438(get_default)
#   3510720    2.692    0.000    3.999    0.000 configparser.py:670(options)
#     25440    0.030    0.000    3.977    0.000 tokenizer.pyx:93(__set__)
#  13118985    2.750    0.000    3.949    0.000 lex_attrs.py:176(is_upper)
#  29799657    3.909    0.000    3.909    0.000 {built-in method unicodedata.category}
#   4502880    1.470    0.000    3.907    0.000 __init__.py:505(try_load_json)
#   2086080    2.325    0.000    3.906    0.000 model.py:198(set_dim)
#     84790    1.309    0.000    3.887    0.000 hashembed.py:59(forward)
#   1628158    3.829    0.000    3.829    0.000 _param_server.py:16(__init__)
#   5215200    2.472    0.000    3.776    0.000 __init__.py:305(_get_section_ref)
#  70872940    3.766    0.000    3.766    0.000 tokenizer.pyx:90(__get__)
#   2213280    0.714    0.000    3.756    0.000 typing.py:408(is_callable_type)
#  13118985    3.739    0.000    3.739    0.000 lex_attrs.py:58(is_quote)
#   2840800    1.526    0.000    3.708    0.000 __init__.py:1004(is_promise)
#    347680    1.084    0.000    3.700    0.000 pathlib.py:682(_parse_args)
#   6020800    1.466    0.000    3.644    0.000 _json_api.py:30(json_loads)
#     25440    0.018    0.000    3.642    0.000 tokenizer.pyx:101(__set__)
#  50311696    3.640    0.000    3.640    0.000 {built-in method builtins.id}
#     25440    0.016    0.000    3.628    0.000 tokenizer.pyx:85(__set__)
#   3137600    1.585    0.000    3.614    0.000 fields.py:559(_set_default_and_type)
#     25440    0.019    0.000    3.593    0.000 tokenizer.pyx:109(__set__)
#    228471    0.918    0.000    3.530    0.000 matcher.pyx:430(transition_states)
#  65852770    3.499    0.000    3.499    0.000 tokenizer.pyx:98(__get__)
#  41568934    3.480    0.000    3.480    0.000 {method 'isdigit' of 'str' objects}
#     33920    0.175    0.000    3.473    0.000 __init__.py:172(get_configparser)
#  22505861    2.311    0.000    3.426    0.000 {method 'add' of 'set' objects}
#   2077600    0.693    0.000    3.407    0.000 typing.py:574(get_class)
#     84790    0.104    0.000    3.393    0.000 {method 'var' of 'numpy.ndarray' objects}
#  43597242    3.367    0.000    3.367    0.000 {method 'isupper' of 'str' objects}
#  35811106    3.322    0.000    3.322    0.000 {function Table.__contains__ at 0x000001C16C8B1A60}
#     33920    0.304    0.000    3.298    0.000 configparser.py:601(__init__)
#     84790    1.711    0.000    3.289    0.000 _methods.py:135(_var)
#  42683294    3.274    0.000    3.274    0.000 {built-in method builtins.ord}
#   6673769    3.242    0.000    3.242    0.000 {built-in method _abc._abc_instancecheck}
#   7682880    2.011    0.000    3.206    0.000 utils.py:696(is_valid_field)
#  13118985    3.188    0.000    3.188    0.000 lex_attrs.py:53(is_bracket)
#   2560960    0.964    0.000    3.116    0.000 class_validators.py:337(<lambda>)
#   6207360    2.732    0.000    3.098    0.000 phrasematcher.pyx:340(_convert_to_array)
#   1500960    1.087    0.000    3.095    0.000 __init__.py:513(try_dump_json)
#   2077600    0.978    0.000    3.027    0.000 dataclasses.py:443(is_builtin_dataclass)
#   8920960    1.907    0.000    3.018    0.000 utils.py:157(sequence_like)
#     50880    0.309    0.000    2.992    0.000 maxout.py:16(Maxout)
#  13118985    2.972    0.000    2.972    0.000 lex_attrs.py:65(is_left_punct)
#  13118985    2.964    0.000    2.964    0.000 lex_attrs.py:152(suffix)
#  12791949    2.924    0.000    2.924    0.000 {method 'count' of 'str' objects}
#   1594240    0.390    0.000    2.915    0.000 configparser.py:1362(__iter__)
#   3527680    1.826    0.000    2.907    0.000 typing.py:354(is_none_type)
#  35007985    2.900    0.000    2.900    0.000 {method 'strip' of 'str' objects}
#   4333280    2.251    0.000    2.886    0.000 copy.py:242(_keep_alive)
#   1602720    0.539    0.000    2.876    0.000 _json_api.py:10(json_dumps)
#    966720    1.277    0.000    2.863    0.000 __init__.py:1016(get_constructor)
#   5579840    2.254    0.000    2.840    0.000 typing.py:933(__hash__)
#  52350126    2.818    0.000    2.818    0.000 tokenizer.pyx:106(__get__)
#     16960    0.030    0.000    2.792    0.000 tokenizer.pyx:77(__set__)
#   2077600    2.141    0.000    2.783    0.000 class_validators.py:166(get_validators)
#   5121923    2.758    0.000    2.758    0.000 {method 'copy' of 'dict' objects}
# 534240/127200    1.467    0.000    2.756    0.000 __init__.py:534(deep_merge_configs)
#   7538720    2.724    0.000    2.724    0.000 {method 'search' of 're.Pattern' objects}
#   5605280    1.951    0.000    2.722    0.000 main.py:174(is_untouched)
#  12923521    2.710    0.000    2.710    0.000 {method 'update' of 'dict' objects}
#   2493120    1.011    0.000    2.690    0.000 typing.py:164(get_args)
#     59360    0.211    0.000    2.670    0.000 __init__.py:633(mtime)
#    186560    0.400    0.000    2.644    0.000 matcher.pyx:1110(_get_extra_predicates_dict)
#     33920    0.691    0.000    2.636    0.000 configparser.py:1320(__init__)
#   3884098    1.134    0.000    2.613    0.000 matcher.pyx:572(update_predicate_cache)
#     93308    0.222    0.000    2.585    0.000 codecs.py:319(decode)
#     84790    0.118    0.000    2.583    0.000 {method 'mean' of 'numpy.ndarray' objects}
#      8480    0.183    0.000    2.553    0.000 configparser.py:905(write)
#  12177280    2.552    0.000    2.552    0.000 __init__.py:925(__init__)
#   1611201    2.528    0.000    2.528    0.000 {built-in method builtins.iter}
#   7801600    1.969    0.000    2.477    0.000 inspect.py:2830(<genexpr>)
#     84790    0.847    0.000    2.465    0.000 _methods.py:101(_mean)
#  13118985    2.446    0.000    2.446    0.000 lex_attrs.py:72(is_right_punct)
#     98535    2.438    0.000    2.438    0.000 _text.py:1366(<listcomp>)
#    686880    0.804    0.000    2.399    0.000 copy.py:200(_deepcopy_list)
#   6673760    1.747    0.000    2.396    0.000 validators.py:644(<genexpr>)
#     84790    2.143    0.000    2.393    0.000 numpy_ops.pyx:166(__pyx_fuse_0maxout)
#    347680    1.472    0.000    2.383    0.000 pathlib.py:64(parse_parts)
#     98535    2.382    0.000    2.382    0.000 _text.py:1367(<listcomp>)
#   2433760    2.051    0.000    2.371    0.000 class_validators.py:322(_generic_validator_basic)
#     16960    0.011    0.000    2.367    0.000 tokenizer.pyx:129(__set__)
#    127200    2.364    0.000    2.364    0.000 {method '__exit__' of '_io._IOBase' objects}
#     93308    2.363    0.000    2.363    0.000 {built-in method _codecs.utf_8_decode}
#  12728480    2.356    0.000    2.356    0.000 {method 'rpartition' of 'str' objects}
#  14934741    2.354    0.000    2.354    0.000 {method 'split' of 'str' objects}
#    390080    1.436    0.000    2.327    0.000 configparser.py:925(_write_section)
#   8802240    1.506    0.000    2.314    0.000 main.py:298(__instancecheck__)
#  13118985    2.268    0.000    2.268    0.000 lex_attrs.py:148(prefix)
#   1500960    1.276    0.000    2.197    0.000 __init__.py:65(before_read)
#   1500960    0.935    0.000    2.191    0.000 configparser.py:891(set)
#  13118985    2.186    0.000    2.186    0.000 vocab.pyx:213(_add_lex_to_vocab)
#   6020800    2.178    0.000    2.178    0.000 {built-in method srsly.ujson.ujson.loads}
#    220479    0.690    0.000    2.177    0.000 language.py:346(pipeline)
#  20207836    2.163    0.000    2.163    0.000 {built-in method builtins.setattr}
#   1484000    2.158    0.000    2.158    0.000 {built-in method srsly.ujson.ujson.dumps}
#    474880    0.335    0.000    2.155    0.000 model.py:147(grad_names)
#  10413440    2.042    0.000    2.105    0.000 typing.py:487(_check_finalvar)
#   2077600    1.046    0.000    2.049    0.000 dataclasses.py:1047(is_dataclass)
#    610560    0.489    0.000    2.039    0.000 utils.py:489(__init__)
#    483360    2.037    0.000    2.037    0.000 {built-in method _abc._abc_init}
#   1170240    0.422    0.000    2.018    0.000 configparser.py:1275(__iter__)
#  22845120    2.000    0.000    2.000    0.000 tokenizer.pyx:126(__get__)
#    161120    0.302    0.000    1.997    0.000 matcher.pyx:948(__init__)
#     16961    0.018    0.000    1.989    0.000 __init__.py:639(lookup)
#     50880    1.986    0.000    1.986    0.000 {method 'read' of '_io.BufferedReader' objects}
#    737760    0.717    0.000    1.981    0.000 __init__.py:183(_get)
#     16961    0.141    0.000    1.970    0.000 __init__.py:645(__init__)
#   2077600    0.757    0.000    1.914    0.000 utils.py:161(validate_field_name)
#      8480    1.863    0.000    1.894    0.000 util.py:1356(from_dict)
#   6800960    1.432    0.000    1.848    0.000 inspect.py:159(isfunction)
#      8480    0.075    0.000    1.816    0.000 util.py:755(is_compatible_version)
#  27305600    1.812    0.000    1.812    0.000 util.py:117(is_cupy_array)
#    771680    1.030    0.000    1.804    0.000 main.py:880(_calculate_keys)
#    483360    1.262    0.000    1.802    0.000 class_validators.py:209(extract_root_validators)
#   1602720    1.776    0.000    1.776    0.000 matcher.pyx:851(_get_attr_values)
#    949760    0.359    0.000    1.747    0.000 model.py:142(param_names)
#      8480    0.128    0.000    1.741    0.000 format.py:738(read_array)
#   2654241    0.726    0.000    1.704    0.000 abc.py:121(__subclasscheck__)
#     16958    0.211    0.000    1.698    0.000 _precomputable_affine.py:19(forward)
#   2493120    1.308    0.000    1.680    0.000 typing.py:1545(get_args)
#   6775520    1.672    0.000    1.672    0.000 {method 'group' of 're.Match' objects}
#   1060000    1.087    0.000    1.642    0.000 __init__.py:1011(<listcomp>)
#   1874080    1.126    0.000    1.636    0.000 __init__.py:141(_get_entry_points)
#    644480    0.191    0.000    1.630    0.000 copy.py:263(<genexpr>)
#  26305810    1.629    0.000    1.629    0.000 vocab.pyx:93(__get__)
#   4502880    1.613    0.000    1.613    0.000 configparser.py:877(has_option)
#   1127840    0.678    0.000    1.611    0.000 __init__.py:118(get_entry_points)
#     16961    0.089    0.000    1.609    0.000 __init__.py:616(children)
#    915840    0.734    0.000    1.575    0.000 typing.py:706(__getattr__)
#    483360    1.311    0.000    1.569    0.000 class_validators.py:176(check_for_unused)
#    746240    0.863    0.000    1.566    0.000 __init__.py:128(get_entry_point)
#    483360    1.141    0.000    1.561    0.000 __init__.py:1027(parse_args)
#     42395    0.437    0.000    1.538    0.000 ops.py:364(unflatten)
#   2264160    1.069    0.000    1.535    0.000 utils.py:513(for_element)
#  13118985    1.525    0.000    1.525    0.000 {method 'islower' of 'str' objects}
#    619040    0.383    0.000    1.522    0.000 pathlib.py:752(__fspath__)
#   1679036    1.145    0.000    1.516    0.000 __init__.py:134(get_current_ops)
#    186560    0.172    0.000    1.513    0.000 matcher.pyx:887(_predicate_cache_key)
#     67832    0.064    0.000    1.506    0.000 expand_window.py:18(forward)
#    237440    0.439    0.000    1.492    0.000 util.py:205(has)
#     16960    0.089    0.000    1.468    0.000 specifiers.py:688(__init__)
#    254400    0.414    0.000    1.456    0.000 model.py:298(set_ref)
#     67832    0.184    0.000    1.434    0.000 expand_window.py:25(_expand_window_floats)
#   9099040    1.430    0.000    1.430    0.000 utils.py:675(smart_deepcopy)
#    483360    0.844    0.000    1.425    0.000 class_validators.py:195(extract_validators)
#    695360    0.474    0.000    1.406    0.000 main.py:778(<genexpr>)
#    966720    0.855    0.000    1.406    0.000 __init__.py:1018(<listcomp>)
#    262853    1.404    0.000    1.404    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   7555680    1.403    0.000    1.403    0.000 enum.py:670(__new__)
#  13119531    1.396    0.000    1.396    0.000 {method 'istitle' of 'str' objects}
#     84790    1.340    0.000    1.395    0.000 numpy_ops.pyx:461(__pyx_fuse_0_1gather_add)
#     76320    1.393    0.000    1.393    0.000 {built-in method builtins.compile}
#  14033821    1.349    0.000    1.382    0.000 doc.pyx:945(__pyx_fuse_0push_back)
#      8480    0.231    0.000    1.378    0.000 language.py:226(meta)
#    483360    0.874    0.000    1.374    0.000 types.py:100(prepare_class)
#   2077600    0.893    0.000    1.371    0.000 utils.py:201(is_valid_identifier)
#    483360    0.532    0.000    1.371    0.000 inspect.py:2564(replace)
#   1602720    1.353    0.000    1.353    0.000 matcher.pyx:1169(_get_operators)
#    983680    0.408    0.000    1.351    0.000 typing.py:1149(<genexpr>)
#     16958    0.367    0.000    1.336    0.000 model.py:868(set_dropout_rate)
#    483360    0.624    0.000    1.321    0.000 config.py:186(prepare_config)
#   3400480    0.831    0.000    1.290    0.000 inspect.py:514(_is_wrapper)
#  12711522    1.288    0.000    1.288    0.000 {method 'values' of 'dict' objects}
#     76320    0.569    0.000    1.282    0.000 version.py:184(__init__)
# 2959520/2077600    1.279    0.000    1.279    0.000 typing.py:513(update_field_forward_refs)
#    924320    1.050    0.000    1.270    0.000 validators.py:127(int_validator)
#   1534880    1.258    0.000    1.258    0.000 matcher.pyx:769(init_pattern)
#   1500960    0.714    0.000    1.256    0.000 configparser.py:459(before_set)
#  13118985    1.256    0.000    1.256    0.000 {method 'isspace' of 'str' objects}
#      8480    0.220    0.000    1.243    0.000 language.py:268(config)
#     67832    0.470    0.000    1.229    0.000 numpy_ops.pyx:229(seq2col)
#      8479    0.494    0.000    1.223    0.000 attributeruler.py:157(set_annotations)
#   2628813    1.222    0.000    1.222    0.000 {method 'format' of 'str' objects}
#  13135945    1.184    0.000    1.184    0.000 lex_attrs.py:184(get_lang)
#  18346622    1.175    0.000    1.175    0.000 tokenizer.pyx:74(__get__)
#     93280    0.284    0.000    1.166    0.000 with_array.py:15(with_array)
#    186560    0.298    0.000    1.166    0.000 __init__.py:183(dumps)
#    636000    0.657    0.000    1.165    0.000 pathlib.py:742(__str__)
#  12165109    1.151    0.000    1.161    0.000 tokenizer.pyx:355(_try_specials_and_cache)
#   1679013    1.139    0.000    1.139    0.000 numpy_ops.pyx:66(asarray)
#   3655627    1.130    0.000    1.130    0.000 matcher.pyx:973(__call__)
#    279840    0.300    0.000    1.122    0.000 __init__.py:287(<listcomp>)
#     67840    0.138    0.000    1.119    0.000 typing.py:524(__init__)
#   7173942    1.117    0.000    1.117    0.000 model.py:124(layers)
#     67840    0.116    0.000    1.116    0.000 _json_api.py:179(is_json_serializable)
#     33920    0.036    0.000    1.114    0.000 specifiers.py:338(__hash__)
#   9132960    1.105    0.000    1.105    0.000 {method 'isidentifier' of 'str' objects}
#  18528800    1.098    0.000    1.098    0.000 copy.py:182(_deepcopy_atomic)
#    237440    0.493    0.000    1.096    0.000 dataclasses.py:320(new_init)
#   3375040    0.857    0.000    1.090    0.000 typing.py:467(is_new_type)
#   4155200    1.044    0.000    1.088    0.000 typing.py:480(_check_classvar)
#  13601921    1.080    0.000    1.080    0.000 {method 'rstrip' of 'str' objects}
#    576572    0.644    0.000    1.078    0.000 model.py:230(get_param)
#      8479    0.061    0.000    1.078    0.000 tagger.pyx:124(predict)
#     33920    0.048    0.000    1.070    0.000 specifiers.py:330(_canonical_spec)
#     16960    0.110    0.000    1.069    0.000 tagger.py:10(build_tagger_model)
#   1891040    0.755    0.000    1.054    0.000 configparser.py:1169(_validate_value_types)
#    330720    0.573    0.000    1.050    0.000 errors.py:7(__getattribute__)
#    364640    0.604    0.000    1.043    0.000 __init__.py:43(__contains__)
#     16962    1.033    0.000    1.033    0.000 {built-in method nt.listdir}
#  11210560    1.027    0.000    1.027    0.000 inspect.py:2548(name)
#    720800    0.649    0.000    1.023    0.000 model.py:244(set_param)
#     33920    0.191    0.000    1.022    0.000 utils.py:38(canonicalize_version)
#   3052800    0.741    0.000    0.999    0.000 typing_extensions.py:339(__eq__)
#   2654241    0.978    0.000    0.978    0.000 {built-in method _abc._abc_subclasscheck}
#     84790    0.642    0.000    0.964    0.000 layernorm.py:58(_begin_update_scale_shift)
#    127200    0.127    0.000    0.937    0.000 array_getitem.py:30(ints_getitem)
#      8480    0.144    0.000    0.931    0.000 format.py:587(_read_array_header)
#   1000640    0.470    0.000    0.924    0.000 functools.py:817(dispatch)
#     67840    0.198    0.000    0.911    0.000 typing.py:539(_evaluate)
#   2433760    0.907    0.000    0.907    0.000 functools.py:65(wraps)
#  12768752    0.894    0.000    0.894    0.000 doc.pyx:520(__len__)
#    271360    0.497    0.000    0.893    0.000 inspect.py:1878(_signature_is_functionlike)
#     50880    0.081    0.000    0.887    0.000 layernorm.py:12(LayerNorm)
#   1526400    0.667    0.000    0.884    0.000 <frozen importlib._bootstrap_external>:114(<listcomp>)
#   6258240    0.847    0.000    0.847    0.000 typing.py:453(_check_typeddict_special)
#   6518271    0.838    0.000    0.838    0.000 {method 'extend' of 'list' objects}
#   1110835    0.753    0.000    0.753    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#    915840    0.423    0.000    0.742    0.000 typing.py:665(_is_dunder)
#     25440    0.090    0.000    0.733    0.000 tok2vec.py:105(build_Tok2Vec_model)
#     42395    0.072    0.000    0.725    0.000 shape_base.py:791(split)
#   9616201    0.719    0.000    0.719    0.000 typing.py:1375(cast)
#   2951040    0.581    0.000    0.718    0.000 __init__.py:190(<genexpr>)
#    483360    0.539    0.000    0.716    0.000 utils.py:285(<listcomp>)
#    186560    0.230    0.000    0.715    0.000 encoder.py:182(encode)
#    347680    0.467    0.000    0.709    0.000 pathlib.py:715(_from_parsed_parts)
#  11510502    0.707    0.000    0.707    0.000 tokenizer.pyx:82(__get__)
#    211620    0.301    0.000    0.705    0.000 lemmatizer.py:8(is_base_form)
#     16958    0.056    0.000    0.705    0.000 ragged2list.py:17(forward)
#   5961440    0.697    0.000    0.697    0.000 fields.py:535(alt_alias)
#   1534880    0.696    0.000    0.696    0.000 {method 'add' of 'spacy.strings.StringStore' objects}
#   2959520    0.693    0.000    0.693    0.000 __init__.py:681(alias_generator)
#     42400    0.067    0.000    0.692    0.000 <frozen importlib._bootstrap>:156(__enter__)
#     59353    0.505    0.000    0.691    0.000 ops.py:319(flatten)
#     16958    0.159    0.000    0.679    0.000 linear.py:35(forward)
#    127837    0.605    0.000    0.662    0.000 re.py:289(_compile)
#    610560    0.535    0.000    0.657    0.000 main.py:903(<setcomp>)
# 1635772/1635253    0.410    0.000    0.656    0.000 doc.pyx:474(__getitem__)
#     84800    0.248    0.000    0.653    0.000 language.py:336(component_names)
#   3883840    0.652    0.000    0.652    0.000 model.py:205(<genexpr>)
#     85437    0.062    0.000    0.649    0.000 re.py:250(compile)
#      8480    0.043    0.000    0.647    0.000 utils.py:1027(safe_eval)
#   6817920    0.643    0.000    0.643    0.000 configparser.py:1023(<dictcomp>)
#    483360    0.394    0.000    0.642    0.000 __init__.py:1053(<listcomp>)
#      8480    0.012    0.000    0.641    0.000 specifiers.py:853(__contains__)
#     42395    0.412    0.000    0.639    0.000 shape_base.py:731(array_split)
#   6673767    0.636    0.000    0.636    0.000 {built-in method builtins.callable}
#   2959520    0.632    0.000    0.632    0.000 fields.py:217(_validate)
#    339160    0.631    0.000    0.631    0.000 numpy_ops.pyx:83(alloc)
#      8480    0.021    0.000    0.629    0.000 specifiers.py:874(contains)
#    483360    0.509    0.000    0.625    0.000 types.py:79(resolve_bases)
#      8480    0.064    0.000    0.610    0.000 util.py:781(is_unconstrained_version)
#    127185    0.154    0.000    0.609    0.000 ops.py:707(asarray1i)
#    271330    0.229    0.000    0.606    0.000 contextlib.py:123(__exit__)
#      8480    0.045    0.000    0.604    0.000 ast.py:54(literal_eval)
#   5639228    0.601    0.000    0.601    0.000 {built-in method builtins.hash}
#    720800    0.600    0.000    0.600    0.000 {built-in method numpy.frombuffer}
#   3010400    0.599    0.000    0.599    0.000 {method 'keys' of 'mappingproxy' objects}
#     16960    0.524    0.000    0.596    0.000 {method 'read' of '_io.TextIOWrapper' objects}
#     16960    0.034    0.000    0.595    0.000 pathlib.py:1450(is_file)
#     16958    0.108    0.000    0.595    0.000 featureextractor.py:14(forward)
#    924320    0.352    0.000    0.594    0.000 validators.py:59(str_validator)
#   1195680    0.363    0.000    0.587    0.000 __init__.py:237(<lambda>)
#     25440    0.020    0.000    0.587    0.000 specifiers.py:929(<genexpr>)
#   1195680    0.418    0.000    0.584    0.000 _collections_abc.py:779(items)
#      8480    0.025    0.000    0.569    0.000 {spacy.vocab.create_vocab}
#     16960    0.060    0.000    0.567    0.000 specifiers.py:535(contains)
#    449440    0.345    0.000    0.566    0.000 __init__.py:552(<listcomp>)
#    271330    0.196    0.000    0.561    0.000 contextlib.py:261(helper)
#     16958    0.109    0.000    0.549    0.000 list2ragged.py:20(forward)
#     50880    0.212    0.000    0.547    0.000 <frozen importlib._bootstrap>:166(_get_module_lock)
#      8480    0.094    0.000    0.544    0.000 vocab.pyx:24(create_vocab)
#     16958    0.095    0.000    0.544    0.000 concatenate.py:69(_array_forward)
#   1602720    0.543    0.000    0.543    0.000 matcher.pyx:1206(_get_extensions)
#   4706400    0.532    0.000    0.532    0.000 utils.py:620(is_true)
#   3417292    0.529    0.000    0.529    0.000 model.py:135(attrs)
#     16960    0.055    0.000    0.527    0.000 pathlib.py:1079(__new__)
#    432480    0.512    0.000    0.519    0.000 pathlib.py:155(splitroot)
#    237440    0.380    0.000    0.512    0.000 dataclasses.py:283(handle_extra_init)
#    262880    0.362    0.000    0.508    0.000 pathlib.py:725(_format_parsed_parts)
#     84790    0.119    0.000    0.502    0.000 ops.py:699(asarray_f)
#    771680    0.427    0.000    0.496    0.000 main.py:421(_init_private_attributes)
# ...
#         2    0.000    0.000    0.000    0.000 indexing.py:2609(check_dict_or_set_indexers)
#         9    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         6    0.000    0.000    0.000    0.000 common.py:1389(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:273(is_fsspec_url)
#         2    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         4    0.000    0.000    0.000    0.000 common.py:1077(needs_i8_conversion)
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#        11    0.000    0.000    0.000    0.000 common.py:1322(is_1d_only_ea_dtype)
#         4    0.000    0.000    0.000    0.000 config.py:578(_select_options)
#         2    0.000    0.000    0.000    0.000 common.py:112(ensure_python_int)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1365(_validate_parse_dates_arg)
#         4    0.000    0.000    0.000    0.000 common.py:150(cast_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 common.py:186(all_none)
#         4    0.000    0.000    0.000    0.000 config.py:637(_translate_key)
#         2    0.000    0.000    0.000    0.000 base.py:5414(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:342(_maybe_make_multi_index_columns)
#         1    0.000    0.000    0.000    0.000 common.py:551(is_dtype_equal)
#         1    0.000    0.000    0.000    0.000 apply.py:103(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         2    0.000    0.000    0.000    0.000 parse.py:122(_coerce_args)
#         2    0.000    0.000    0.000    0.000 inference.py:99(is_file_like)
#         4    0.000    0.000    0.000    0.000 base.py:809(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base_parser.py:271(_extract_multi_indexer_columns)
#         5    0.000    0.000    0.000    0.000 c_parser_wrapper.py:382(<setcomp>)
#         3    0.000    0.000    0.000    0.000 base.py:565(_ensure_array)
#         1    0.000    0.000    0.000    0.000 base.py:450(_engine_type)
#         3    0.000    0.000    0.000    0.000 base.py:583(_dtype_to_subclass)
#         3    0.000    0.000    0.000    0.000 common.py:367(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 missing.py:949(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 frame.py:4240(_clear_item_cache)
#         2    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         7    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         6    0.000    0.000    0.000    0.000 generic.py:338(attrs)
#         8    0.000    0.000    0.000    0.000 common.py:1240(<lambda>)
#        10    0.000    0.000    0.000    0.000 concat.py:80(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:426(__init__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1211(_process_date_conversion)
#         1    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         4    0.000    0.000    0.000    0.000 construction.py:636(_sanitize_non_ordered)
#         1    0.000    0.000    0.000    0.000 numpy_.py:135(__array__)
#         1    0.000    0.000    0.000    0.000 generic.py:4176(_check_setitem_copy)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         5    0.000    0.000    0.000    0.000 concat.py:72(<setcomp>)
#         1    0.000    0.000    0.000    0.000 frame.py:1489(__len__)
#         6    0.000    0.000    0.000    0.000 managers.py:1944(_block)
#         1    0.000    0.000    0.000    0.000 construction.py:476(<listcomp>)
#         4    0.000    0.000    0.000    0.000 common.py:1215(<genexpr>)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:405(ensure_dtype_objs)
#         1    0.000    0.000    0.000    0.000 frame.py:4203(_ensure_valid_index)
#         4    0.000    0.000    0.000    0.000 series.py:574(_constructor)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1099(_make_date_converter)
#         2    0.000    0.000    0.000    0.000 blocks.py:892(iget)
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.000    0.000    0.000    0.000 base_parser.py:876(_check_data_length)
#         6    0.000    0.000    0.000    0.000 flags.py:53(allows_duplicate_labels)
#        12    0.000    0.000    0.000    0.000 generic.py:359(flags)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:72(<dictcomp>)
#        11    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         1    0.000    0.000    0.000    0.000 nanops.py:353(_na_ok_dtype)
#         2    0.000    0.000    0.000    0.000 generic.py:509(_get_axis_number)
#         1    0.000    0.000    0.000    0.000 managers.py:1195(value_getitem)
#         1    0.000    0.000    0.000    0.000 common.py:1103(_maybe_memory_map)
#         3    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         1    0.000    0.000    0.000    0.000 dtypes.py:1324(__init__)
#         5    0.000    0.000    0.000    0.000 concat.py:71(<setcomp>)
#         4    0.000    0.000    0.000    0.000 blocks.py:479(dtype)
#         5    0.000    0.000    0.000    0.000 concat.py:79(<setcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:599(_info_axis)
#         1    0.000    0.000    0.000    0.000 readers.py:1806(_clean_na_values)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:212(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _validators.py:224(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 range.py:485(equals)
#         5    0.000    0.000    0.000    0.000 blocks.py:205(mgr_locs)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#         1    0.000    0.000    0.000    0.000 {method 'has_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#         5    0.000    0.000    0.000    0.000 base.py:326(ndim)
#         3    0.000    0.000    0.000    0.000 managers.py:233(items)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         1    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         1    0.000    0.000    0.000    0.000 base.py:778(is_)
#         2    0.000    0.000    0.000    0.000 blocks.py:258(__len__)
#         6    0.000    0.000    0.000    0.000 series.py:1323(_clear_item_cache)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         2    0.000    0.000    0.000    0.000 common.py:498(is_string_or_object_np_dtype)
#         3    0.000    0.000    0.000    0.000 managers.py:333(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:197(mgr_to_mgr)
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:213(<listcomp>)
#         5    0.000    0.000    0.000    0.000 base.py:4937(_values)
#         1    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'title' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         5    0.000    0.000    0.000    0.000 multiarray.py:669(result_type)
#         1    0.000    0.000    0.000    0.000 readers.py:2109(_validate_skipfooter)
#         3    0.000    0.000    0.000    0.000 base_parser.py:1387(is_index_col)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:332(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 common.py:190(<genexpr>)
#         1    0.000    0.000    0.000    0.000 nanops.py:198(_get_fill_value)
#         2    0.000    0.000    0.000    0.000 base.py:530(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:931(dtype)
#         3    0.000    0.000    0.000    0.000 base.py:6354(_maybe_cast_indexer)
#         2    0.000    0.000    0.000    0.000 blocks.py:888(shape)
#         3    0.000    0.000    0.000    0.000 managers.py:183(blklocs)
#         2    0.000    0.000    0.000    0.000 managers.py:1838(ndim)
#         5    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         1    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#         2    0.000    0.000    0.000    0.000 readers.py:486(validate_integer)
#         1    0.000    0.000    0.000    0.000 readers.py:2011(_extract_dialect)
#         1    0.000    0.000    0.000    0.000 base_parser.py:242(_has_complex_date_col)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:328(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#         2    0.000    0.000    0.000    0.000 parse.py:111(_noop)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2416(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 base_parser.py:222(<setcomp>)
#         1    0.000    0.000    0.000    0.000 _validators.py:445(check_dtype_backend)
#         1    0.000    0.000    0.000    0.000 function.py:60(__call__)
#         1    0.000    0.000    0.000    0.000 missing.py:121(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 base.py:159(_freeze)
#         2    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 readers.py:1735(__enter__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:966(_validate_usecols_arg)
#         2    0.000    0.000    0.000    0.000 base.py:1582(name)
#         1    0.000    0.000    0.000    0.000 range.py:181(_validate_dtype)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 parse.py:427(_checknetloc)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2687(_max_dispatcher)
#         1    0.000    0.000    0.000    0.000 multiarray.py:1131(putmask)
#         1    0.000    0.000    0.000    0.000 readers.py:516(_validate_names)
#         1    0.000    0.000    0.000    0.000 managers.py:982(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#         1    0.000    0.000    0.000    0.000 base_parser.py:234(<listcomp>)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 326
#     321     print(f"Script ran for {elapsed_time_minutes:.2f} minutes.")
#     325 if __name__ == "__main__":
# --> 326     cProfile.run("main()", sort='cumulative')
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\cProfile.py:17, in run(statement, filename, sort)
#      16 def run(statement, filename=None, sort=-1):
# ---> 17     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\profile.py:54, in _Utils.run(self, statement, filename, sort)
#      52 prof = self.profiler()
#      53 try:
# ---> 54     prof.run(statement)
#      55 except SystemExit:
#      56     pass
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\cProfile.py:96, in Profile.run(self, cmd)
#      94 import __main__
#      95 dict = __main__.__dict__
# ---> 96 return self.runctx(cmd, dict, dict)
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\cProfile.py:101, in Profile.runctx(self, cmd, globals, locals)
#      99 self.enable()
#     100 try:
# --> 101     exec(cmd, globals, locals)
#     102 finally:
#     103     self.disable()
#
# File <string>:1
#
# Cell In[18], line 262, in main()
#     259  df['Answer'] = df['Answer'].str.replace(r'^[\.\:\- ]*', '', regex=True)     # regex to replace the punctuations from the start of the answer
#     261  # Correcting answers that are truncated in the start of the answer
# --> 262  df['Answer'] = df['Answer'].apply(correct_truncated_start_word)
#     265 # corrected_file_path = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_corrected.csv'))
#     266  #remaining_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_remaining_data.csv'))
#     267  filtered_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_filtered_questions.csv'))
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[18], line 211, in correct_truncated_start_word(text)
#     207 def correct_truncated_start_word(text: str) -> str:
#     208
#     209     # Load the spaCy English model
#     210     nlp = spacy.load("en_core_web_sm")
# --> 211     doc = nlp(text)
#     213     # Checking if the start token is capitalized or not
#     214     if doc[0].is_title == False:
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\site-packages\spacy\language.py:1030, in Language.__call__(self, text, disable, component_cfg)
#    1009 def __call__(
#    1010     self,
#    1011     text: Union[str, Doc],
#    (...)
#    1014     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#    1015 ) -> Doc:
#    1016     """Apply the pipeline to some text. The text can span multiple sentences,
#    1017     and can contain arbitrary whitespace. Alignment into the original string
#    1018     is preserved.
#    (...)
#    1028     DOCS: https://spacy.io/api/language#call
#    1029     """
# -> 1030     doc = self._ensure_doc(text)
#    1031     if component_cfg is None:
#    1032         component_cfg = {}
#
# File c:\Users\Mathews\miniconda3\envs\tf\lib\site-packages\spacy\language.py:1124, in Language._ensure_doc(self, doc_like)
#    1122 if isinstance(doc_like, bytes):
#    1123     return Doc(self.vocab).from_bytes(doc_like)
# -> 1124 raise ValueError(Errors.E1041.format(type=type(doc_like)))
#
# ValueError: [E1041] Expected a string, Doc, or bytes as input, but got: <class 'float'>
